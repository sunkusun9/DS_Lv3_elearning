# %% [markdown]
# ## 3-7. 차원 축소

# %% [markdown]
# ### 1. 차원 축소(Dimension Reduction)
#
# #### 데이터의 정보량과 구조적 특성을 최대한 보존하며 더 낮은 차원 공간으로 변환하는 과정
#
# - 목적
# 1. 차원의 저주(Curse of Dimensionality)완화를 통한 성능 향상
# 2. 노이즈 제거
# 3. 계산 효율성 증가
# 4. 시각화

# %% [markdown]
# ### 2. 주성분 분석(PCA)
#
# #### 주성분 분석(Principal Component Analysis, PCA)
# - 관점: 분산은 하나의 변수가 설명하는 정보량
# $\Rightarrow$ 공분산: 두 변수가 공통으로 지닌 정보량
# - 변수 간 공분산이 0 이 되도록 하는 선형 변환 유도
# $\Rightarrow$ 공분산이 0: 두 변수 간에 중복되는 정보가 없음을 의미
# - 성분(Component): 원래 변수를 선형 변환함으로써 만들어진 새로운 축
# $\Rightarrow$ 성분의 분산: 성분이 설명하는 정보량
# - 각 성분의 분산의 합과 원래 변수의 분산의 합이 같도록 유도
# $\Rightarrow$ 원래 데이터와 변환의 데이터가 나타내는 정보량 동일

# %% [markdown]
# ###$ 주성분 분석 유도 과정 I
#
# - 데이터 행렬을 중심 평균화함
# - 각 열에 임의의 수를 더해도 정보량(분산)은 변하지 않음
#
# **Equation 4.1**
# $$
# 𝑋=𝑥11⋯𝑥1𝑚⋮⋱⋮𝑥𝑛1⋯𝑥𝑛𝑚
# $$
#
# **Equation 4.2**
# $$
# 𝐶𝑜𝑣𝑋=𝐶𝑜𝑣𝑋𝑐=1𝑛−1𝐱𝟏′,𝐱𝟏′⋯𝐱𝟏′,𝐱𝒎′⋮⋱⋮𝐱𝒎′,𝐱𝟏′⋯𝐱𝒎′,𝐱𝒎′=𝑋𝑐𝑇𝑋𝑐𝑛−1
# $$
#
# **Equation 4.3**
# $$
# 𝐱𝑖′=𝑥1𝑖−𝐱𝑖…𝑥𝑛𝑖−𝐱𝑖
# $$
#
# **Equation 4.4**
# $$
# 𝑋𝑐=𝐱1′…𝐱𝑚′
# $$
#
# **Equation 4.5**
# $$
# 𝑋=𝑥11⋯𝑥1𝑚⋮⋱⋮𝑥𝑛1⋯𝑥𝑛𝑚
# $$
#
# **Equation 4.6**
# $$
# 𝐶𝑜𝑣𝑋=𝐶𝑜𝑣𝑋𝑐=1𝑛−1𝐱𝟏′,𝐱𝟏′⋯𝐱𝟏′,𝐱𝒎′⋮⋱⋮𝐱𝒎′,𝐱𝟏′⋯𝐱𝒎′,𝐱𝒎′=𝑋𝑐𝑇𝑋𝑐𝑛−1
# $$
#
# **Equation 4.7**
# $$
# 𝐱𝑖′=𝑥1𝑖−𝐱𝑖…𝑥𝑛𝑖−𝐱𝑖
# $$
#
# **Equation 4.8**
# $$
# 𝑋𝑐=𝐱1′…𝐱𝑚′
# $$
#
# ![slide4-image1](data:image/png;base64,...)
# ![slide4-image2](data:image/png;base64,...)
# ![slide4-image3](data:image/png;base64,...)
# ![slide4-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 5: (Untitled)
#
# - 주성분 분석(PCA)
# - 2
# - 주성분 분석 유도 과정 II
# - W 로 선형 변환한 데이터 행렬 Z 의 각 열의 평균: 0
# - 아래 식을 만족시키는 W 찾기
#
# **Equation 5.1**
# $$
# 𝐶𝑜𝑣𝑋𝑐=𝑋𝑐𝑇𝑋𝑐𝑛−1=𝐴
# $$
#
# **Equation 5.2**
# $$
# 𝑍=𝑋𝑐𝑊
# $$
#
# **Equation 5.3**
# $$
# 𝐶𝑜𝑣𝑍=𝑋𝑐𝑊𝑇𝑋𝑐𝑊𝑛−1=𝑊𝑇𝑋𝑐𝑇𝑋𝐶𝑊𝑛−1=𝑊𝑇𝐴𝑊
# $$
#
# **Equation 5.4**
# $$
# 𝐶𝑜𝑣𝑍=𝑊𝑇𝐴𝑊=𝜆1⋯0⋮⋱⋮0⋯𝜆𝑚
# $$
#
# **Equation 5.5**
# $$
# 𝐶𝑜𝑣𝑋𝑐=𝑋𝑐𝑇𝑋𝑐𝑛−1=𝐴
# $$
#
# **Equation 5.6**
# $$
# 𝑍=𝑋𝑐𝑊
# $$
#
# **Equation 5.7**
# $$
# 𝐶𝑜𝑣𝑍=𝑋𝑐𝑊𝑇𝑋𝑐𝑊𝑛−1=𝑊𝑇𝑋𝑐𝑇𝑋𝐶𝑊𝑛−1=𝑊𝑇𝐴𝑊
# $$
#
# **Equation 5.8**
# $$
# 𝐶𝑜𝑣𝑍=𝑊𝑇𝐴𝑊=𝜆1⋯0⋮⋱⋮0⋯𝜆𝑚
# $$
#
# ![slide5-image1](data:image/png;base64,...)
# ![slide5-image2](data:image/png;base64,...)
# ![slide5-image3](data:image/png;base64,...)
# ![slide5-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 6: (Untitled)
#
# - 주성분 분석(PCA)
# - 2
# - 주성분 분석 유도 과정 III
# - trace(행렬 대각요소의 합) 순환 법칙
# - 각 성분의 분산의 합과 원래 변수의 분산의 합이 같음
# - 주성분 변환은 공분산행렬의 고윳값 분해
# - 정규 직교(Orthonormal)
#
# **Equation 6.1**
# $$
# Λ=Λ𝑇
# $$
#
# **Equation 6.2**
# $$
# A=𝐴𝑇
# $$
#
# **Equation 6.3**
# $$
# WΛW−1=W−1TΛWT
# $$
#
# **Equation 6.4**
# $$
# 𝑊−1𝐴𝑊=Λ
# $$
#
# **Equation 6.5**
# $$
# 𝐴𝑊=𝑊Λ
# $$
#
# **Equation 6.6**
# $$
# 𝑡𝑟𝑎𝑐𝑒(𝐴𝐵)=𝑡𝑟𝑎𝑐𝑒(𝐵𝐴)
# $$
#
# **Equation 6.7**
# $$
# 𝑡𝑟𝑎𝑐𝑒𝑊−1𝐴𝑊=𝑡𝑟𝑎𝑐𝑒(𝐴𝑊𝑊−1)
# $$
#
# **Equation 6.8**
# $$
# 𝑡𝑟𝑎𝑐𝑒Λ=𝑡𝑟𝑎𝑐𝑒(𝐴)
# $$
#
# **Equation 6.9**
# $$
# WT=W−1
# $$
#
# **Equation 6.10**
# $$
# 𝐶𝑜𝑣𝑍=𝑊𝑇𝐴𝑊=𝜆1⋯0⋮⋱⋮0⋯𝜆𝑚
# $$
#
# **Equation 6.11**
# $$
# Λ=𝜆1⋯0⋮⋱⋮0⋯𝜆𝑚
# $$
#
# **Equation 6.12**
# $$
# 𝑊𝑇𝐴𝑊=Λ
# $$
#
# **Equation 6.13**
# $$
# 𝐴=WT−1ΛW−1
# $$
#
# **Equation 6.14**
# $$
# 𝐴𝑇=WΛW−1T
# $$
#
# **Equation 6.15**
# $$
# 𝐴𝑇=W−1TΛ𝑇𝑊𝑇
# $$
#
# **Equation 6.16**
# $$
# Λ=Λ𝑇
# $$
#
# **Equation 6.17**
# $$
# A=𝐴𝑇
# $$
#
# **Equation 6.18**
# $$
# WΛW−1=W−1TΛWT
# $$
#
# **Equation 6.19**
# $$
# 𝑊−1𝐴𝑊=Λ
# $$
#
# **Equation 6.20**
# $$
# 𝐴𝑊=𝑊Λ
# $$
#
# **Equation 6.21**
# $$
# 𝑡𝑟𝑎𝑐𝑒(𝐴𝐵)=𝑡𝑟𝑎𝑐𝑒(𝐵𝐴)
# $$
#
# **Equation 6.22**
# $$
# 𝑡𝑟𝑎𝑐𝑒𝑊−1𝐴𝑊=𝑡𝑟𝑎𝑐𝑒(𝐴𝑊𝑊−1)
# $$
#
# **Equation 6.23**
# $$
# 𝑡𝑟𝑎𝑐𝑒Λ=𝑡𝑟𝑎𝑐𝑒(𝐴)
# $$
#
# **Equation 6.24**
# $$
# WT=W−1
# $$
#
# **Equation 6.25**
# $$
# 𝐶𝑜𝑣𝑍=𝑊𝑇𝐴𝑊=𝜆1⋯0⋮⋱⋮0⋯𝜆𝑚
# $$
#
# **Equation 6.26**
# $$
# Λ=𝜆1⋯0⋮⋱⋮0⋯𝜆𝑚
# $$
#
# **Equation 6.27**
# $$
# 𝑊𝑇𝐴𝑊=Λ
# $$
#
# **Equation 6.28**
# $$
# 𝐴=WT−1ΛW−1
# $$
#
# **Equation 6.29**
# $$
# 𝐴𝑇=WΛW−1T
# $$
#
# **Equation 6.30**
# $$
# 𝐴𝑇=W−1TΛ𝑇𝑊𝑇
# $$
#
# ![slide6-image1](data:image/png;base64,...)
# ![slide6-image2](data:image/png;base64,...)
# ![slide6-image3](data:image/png;base64,...)
# ![slide6-image4](data:image/png;base64,...)
# ![slide6-image5](data:image/png;base64,...)
# ![slide6-image6](data:image/png;base64,...)
# ![slide6-image7](data:image/png;base64,...)
# ![slide6-image8](data:image/png;base64,...)
# ![slide6-image9](data:image/png;base64,...)
# ![slide6-image10](data:image/png;base64,...)
# ![slide6-image11](data:image/png;base64,...)
# ![slide6-image12](data:image/png;base64,...)
# ![slide6-image13](data:image/png;base64,...)
# ![slide6-image14](data:image/png;base64,...)
# ![slide6-image15](data:image/png;base64,...)

# %% [markdown]
# ### Slide 7: (Untitled)
#
# - 주성분 분석(PCA)
# - 2
# - 주성분 분석의 효과
#
# ![slide7-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 8: (Untitled)
#
# - 주성분 분석(PCA)
# - 고윳값
# - 고유벡터
# - 2
# - 분석
# - 고윳값
# - 고윳값 비율
#
# **Equation 8.1**
# $$
# 𝑍=𝑋𝑐𝑊
# $$
#
# **Equation 8.2**
# $$
# 𝑊𝑇𝑋𝑐𝑇𝑋𝐶𝑊𝑛−1=𝜆1⋯0⋮⋱⋮0⋯𝜆𝑚
# $$
#
# **Equation 8.3**
# $$
# 𝑍=𝑋𝑐𝑊
# $$
#
# **Equation 8.4**
# $$
# 𝑊𝑇𝑋𝑐𝑇𝑋𝐶𝑊𝑛−1=𝜆1⋯0⋮⋱⋮0⋯𝜆𝑚
# $$
#
# ![slide8-image1](data:image/png;base64,...)
# ![slide8-image2](data:image/png;base64,...)
# ![slide8-image3](data:image/png;base64,...)
# ![slide8-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 9: (Untitled)
#
# - 특이값 분해
# - 𝑉: 우측 특이 행렬
# - 𝑈: 좌측 특이 행렬
# - 3
# - 출처: https://en.wikipedia.org/wiki/Singular_value_decomposition
# - 대각 요소는 음수가 아니고,
# - 나머지는 모두 0 인 행렬
# - : 특이값 행렬
# - 특이값 분해(Singular Value Decomposition)
# - : m×n 행렬 M 을 3 개의 행렬 의 곱으로 분해
# - T
# - T
# - T
#
# **Equation 9.1**
# $$
# 𝑀=𝑈Σ𝑉𝑇
# $$
#
# **Equation 9.2**
# $$
# Σ
# $$
#
# **Equation 9.3**
# $$
# 𝑈,Σ,𝑉𝑇
# $$
#
# **Equation 9.4**
# $$
# 𝑀=𝑈Σ𝑉𝑇
# $$
#
# ![slide9-image1](data:image/png;base64,...)
# ![slide9-image2](data:image/png;base64,...)
# ![slide9-image3](data:image/png;base64,...)
# ![slide9-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 10: (Untitled)
#
# - 특이값 분해
# - 는 의 고유벡터로 구성
# - 는 의 고유벡터로 구성
# - 3
# - 𝑈,𝑉는 정규 직교(Orthonormal) 행렬
#
# **Equation 10.1**
# $$
# 𝑀𝑀𝑇=𝑈Σ𝑉𝑇VΣT𝑈𝑇
# $$
#
# **Equation 10.2**
# $$
# 𝑀𝑇𝑀=𝑉ΣT𝑈𝑇UΣ𝑉𝑇
# $$
#
# **Equation 10.3**
# $$
# 𝑈
# $$
#
# **Equation 10.4**
# $$
# 𝑀𝑀𝑇
# $$
#
# **Equation 10.5**
# $$
# 𝑉
# $$
#
# **Equation 10.6**
# $$
# 𝑀𝑀𝑇
# $$
#
# **Equation 10.7**
# $$
# 𝑉−1=𝑉𝑇
# $$
#
# **Equation 10.8**
# $$
# 𝑉𝑉−1=𝐼
# $$
#
# **Equation 10.9**
# $$
# 𝑈−1=𝑈𝑇
# $$
#
# **Equation 10.10**
# $$
# 𝑈𝑈−1=𝐼
# $$
#
# **Equation 10.11**
# $$
# 𝑀𝑀𝑇=𝑈ΣΣT𝑈𝑇
# $$
#
# **Equation 10.12**
# $$
# 𝑀𝑇𝑀=𝑉ΣTΣ𝑉𝑇
# $$
#
# **Equation 10.13**
# $$
# 𝑀=𝑈Σ𝑉𝑇
# $$
#
# **Equation 10.14**
# $$
# 𝑀𝑀𝑇=𝑈Σ𝑉𝑇VΣT𝑈𝑇
# $$
#
# **Equation 10.15**
# $$
# 𝑀𝑇𝑀=𝑉ΣT𝑈𝑇UΣ𝑉𝑇
# $$
#
# **Equation 10.16**
# $$
# 𝑉−1=𝑉𝑇
# $$
#
# **Equation 10.17**
# $$
# 𝑉𝑉−1=𝐼
# $$
#
# **Equation 10.18**
# $$
# 𝑈−1=𝑈𝑇
# $$
#
# **Equation 10.19**
# $$
# 𝑈𝑈−1=𝐼
# $$
#
# **Equation 10.20**
# $$
# 𝑀𝑀𝑇=𝑈ΣΣT𝑈𝑇
# $$
#
# **Equation 10.21**
# $$
# 𝑀𝑇𝑀=𝑉ΣTΣ𝑉𝑇
# $$
#
# **Equation 10.22**
# $$
# 𝑀=𝑈Σ𝑉𝑇
# $$
#
# ![slide10-image1](data:image/png;base64,...)
# ![slide10-image2](data:image/png;base64,...)
# ![slide10-image3](data:image/png;base64,...)
# ![slide10-image4](data:image/png;base64,...)
# ![slide10-image5](data:image/png;base64,...)
# ![slide10-image6](data:image/png;base64,...)
# ![slide10-image7](data:image/png;base64,...)
# ![slide10-image8](data:image/png;base64,...)
# ![slide10-image9](data:image/png;base64,...)
# ![slide10-image10](data:image/png;base64,...)
# ![slide10-image11](data:image/png;base64,...)

# %% [markdown]
# ### Slide 11: (Untitled)
#
# - 특이값 분해
# - 공분산 행렬의 고윳값 분해
# - 중심 평균화
# - 3
# - 주성분 분석(Principal Component Analysis) 유도
#
# **Equation 11.1**
# $$
# 𝑋𝑐𝑇𝑋𝑐=𝑉Σ𝑇𝑈𝑇𝑈Σ𝑉𝑇=𝑉Σ𝑇ΣVT
# $$
#
# **Equation 11.2**
# $$
# 𝑋𝑐𝑇𝑋𝑐𝑛−1=𝑉Λ𝑉𝑇
# $$
#
# **Equation 11.3**
# $$
# 𝑋𝑐=𝑈Σ𝑉𝑇
# $$
#
# **Equation 11.4**
# $$
# 𝑋𝑐𝑇𝑋𝑐𝑛−1=𝑉Σ𝑇Σ𝑛−1VT
# $$
#
# **Equation 11.5**
# $$
# Λ=Σ𝑇Σ𝑛−1
# $$
#
# **Equation 11.6**
# $$
# 𝑋𝑐=𝑋−𝑋
# $$
#
# **Equation 11.7**
# $$
# 𝑋
# $$
#
# **Equation 11.8**
# $$
# 𝑋𝑐𝑇𝑋𝑐=𝑉Σ𝑇𝑈𝑇𝑈Σ𝑉𝑇=𝑉Σ𝑇ΣVT
# $$
#
# **Equation 11.9**
# $$
# 𝑋𝑐𝑇𝑋𝑐𝑛−1=𝑉Λ𝑉𝑇
# $$
#
# **Equation 11.10**
# $$
# 𝑋𝑐=𝑈Σ𝑉𝑇
# $$
#
# **Equation 11.11**
# $$
# 𝑋𝑐𝑇𝑋𝑐𝑛−1=𝑉Σ𝑇Σ𝑛−1VT
# $$
#
# **Equation 11.12**
# $$
# Λ=Σ𝑇Σ𝑛−1
# $$
#
# **Equation 11.13**
# $$
# 𝑋𝑐=𝑋−𝑋
# $$
#
# ![slide11-image1](data:image/png;base64,...)
# ![slide11-image2](data:image/png;base64,...)
# ![slide11-image3](data:image/png;base64,...)
# ![slide11-image4](data:image/png;base64,...)
# ![slide11-image5](data:image/png;base64,...)
# ![slide11-image6](data:image/png;base64,...)
# ![slide11-image7](data:image/png;base64,...)

# %% [markdown]
# ### Slide 12: (Untitled)
#
# - 특이값 분해
# - 종류
# - 정의 및 구조
# - 특징
# - Full SVD
# - 모든 특이값 및 기저 포함
# - 수학적 분석
# - 완전 복원 가능
# - Reduced(Thin) SVD
# - r: rank
# - 특이값이 0 인 기저 제외
# - 완전 복원 가능
# - 랭크(Rank): 특이값 행렬의 크기
# - Truncated SVD
# - k < r
# - 특이값의 크기가 상위 k 인 기저만 유지
# - 완전 복원 불가능
# - 차원 축소 목적
# - 종류
# - 정의 및 구조
# - 특징
# - Full SVD
# - 모든 특이값 및 기저 포함
# - 수학적 분석
# - 완전 복원 가능
# - Reduced(Thin) SVD
# - 특이값이 0 인 기저 제외
# - 완전 복원 가능
# - 랭크(Rank): 특이값 행렬의 크기
# - Truncated SVD
# - 특이값의 크기가 상위 k 인 기저만 유지
# - 완전 복원 불가능
# - 차원 축소 목적
# - 3
# - 특이값 분해 종류
#
# **Table 12.1**
# | 종류 | 정의 및 구조 | 특징 |
# | --- | --- | --- |
# | Full SVD |   | 모든 특이값 및 기저 포함
# 수학적 분석
# 완전 복원 가능 |
# | Reduced(Thin) SVD | r: rank | 특이값이 0 인 기저 제외
# 완전 복원 가능
# 랭크(Rank): 특이값 행렬의 크기 |
# | Truncated SVD | k < r | 특이값의 크기가 상위 k 인 기저만 유지
# 완전 복원 불가능
# 차원 축소 목적 |
#
# **Table 12.2**
# | 종류 | 정의 및 구조 | 특징 |
# | --- | --- | --- |
# | Full SVD |   | 모든 특이값 및 기저 포함
# 수학적 분석
# 완전 복원 가능 |
# | Reduced(Thin) SVD |   | 특이값이 0 인 기저 제외
# 완전 복원 가능
# 랭크(Rank): 특이값 행렬의 크기 |
# | Truncated SVD |   | 특이값의 크기가 상위 k 인 기저만 유지
# 완전 복원 불가능
# 차원 축소 목적 |
#
# **Equation 12.1**
# $$
# 𝑀=𝑈𝛴𝑉𝑇
# $$
#
# **Equation 12.2**
# $$
# 𝑈∈𝑅𝑚×𝑚,Σ∈𝑅𝑚×𝑛,𝑉∈𝑅𝑛×𝑛
# $$
#
# **Equation 12.3**
# $$
# 𝑀=𝑈𝑟𝛴𝑟𝑉𝑟𝑇
# $$
#
# **Equation 12.4**
# $$
# 𝑈𝑟∈𝑅𝑚×𝑟,Σ𝑟∈𝑅𝑟×𝑟,𝑉𝑟∈𝑅𝑟×𝑛
# $$
#
# **Equation 12.5**
# $$
# 𝑀≈𝑈𝑘𝛴𝑘𝑉𝑘𝑇
# $$
#
# **Equation 12.6**
# $$
# 𝑈𝑘∈𝑅𝑚×𝑘,Σ𝑘∈𝑅𝑘𝑚×𝑘,𝑉∈𝑅𝑘𝑛×𝑘
# $$
#
# **Equation 12.7**
# $$
# 𝑀=𝑈𝛴𝑉𝑇
# $$
#
# **Equation 12.8**
# $$
# 𝑈∈𝑅𝑚×𝑚,Σ∈𝑅𝑚×𝑛,𝑉∈𝑅𝑛×𝑛
# $$
#
# **Equation 12.9**
# $$
# 𝑀=𝑈𝑟𝛴𝑟𝑉𝑟𝑇
# $$
#
# **Equation 12.10**
# $$
# 𝑈𝑟∈𝑅𝑚×𝑟,Σ𝑟∈𝑅𝑟×𝑟,𝑉𝑟∈𝑅𝑟×𝑛
# $$
#
# **Equation 12.11**
# $$
# 𝑀≈𝑈𝑘𝛴𝑘𝑉𝑘𝑇
# $$
#
# **Equation 12.12**
# $$
# 𝑈𝑘∈𝑅𝑚×𝑘,Σ𝑘∈𝑅𝑘𝑚×𝑘,𝑉∈𝑅𝑘𝑛×𝑘
# $$
#
# ![slide12-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 13: (Untitled)
#
# - 특이값 분해
# - 3
# - 특이값 분해
#
# ![slide13-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 14: (Untitled)
#
# - 다차원 척도법
# - 고전적 다차원 척도법(Classical Multi-Dimensional Scaling)
# - : 데이터 포인트 간의 유클리드 거리를 유지하는 방향으로 차원 축소
# - 4
# - 다차원 척도법(Multi-Dimensional Scaling, MDS)
# - : 데이터 포인트 간의 유사도 또는 거리를 유지하면서 차원 축소
# - 의 다차원 척도값은 의 특이값 분해를 통해 도출
# - 를 중심 평균화
# - 를 기준으로 차원 축소
# - 고윳값 분해를 통해 구할 수 있음
# - 또 한 의 PCA 변환값과 동치
#
# **Equation 14.1**
# $$
# 𝑋𝑐𝑋𝑐𝑇=𝑈Λ𝑈𝑇
# $$
#
# **Equation 14.2**
# $$
# 𝑋
# $$
#
# **Equation 14.3**
# $$
# 𝑋𝑐
# $$
#
# **Equation 14.4**
# $$
# 𝑋𝑐=𝑋−𝑋
# $$
#
# **Equation 14.5**
# $$
# 𝑋
# $$
#
# **Equation 14.6**
# $$
# 𝑋𝑐=𝑈Σ𝑉𝑇
# $$
#
# **Equation 14.7**
# $$
# 𝑈Σ=𝑋𝑐𝑉
# $$
#
# **Equation 14.8**
# $$
# Σ
# $$
#
# **Equation 14.9**
# $$
# 𝑋𝑐𝑋𝑐𝑇
# $$
#
# **Equation 14.10**
# $$
# 𝑋
# $$
#
# **Equation 14.11**
# $$
# 𝑋𝑐𝑋𝑐𝑇=𝑈Λ𝑈𝑇
# $$
#
# **Equation 14.12**
# $$
# 𝑋𝑐=𝑋−𝑋
# $$
#
# **Equation 14.13**
# $$
# 𝑋𝑐=𝑈Σ𝑉𝑇
# $$
#
# **Equation 14.14**
# $$
# 𝑈Σ=𝑋𝑐𝑉
# $$
#
# ![slide14-image1](data:image/png;base64,...)
# ![slide14-image2](data:image/png;base64,...)
# ![slide14-image3](data:image/png;base64,...)
# ![slide14-image4](data:image/png;base64,...)
# ![slide14-image5](data:image/png;base64,...)
# ![slide14-image6](data:image/png;base64,...)
# ![slide14-image7](data:image/png;base64,...)
# ![slide14-image8](data:image/png;base64,...)
# ![slide14-image9](data:image/png;base64,...)

# %% [markdown]
# ### Slide 15: (Untitled)
#
# - 다차원 척도법
# - 유클리드 거리의 제곱
# - 중심화 행렬
# - 고전적 다차원 척도법 의미
# - 4
#
# **Equation 15.1**
# $$
# 𝑋=𝑥11⋯𝑥1𝑚⋮⋱⋮𝑥𝑛1⋯𝑥𝑛𝑚
# $$
#
# **Equation 15.2**
# $$
# 𝐱𝑖=𝑥𝑖1…𝑥𝑖𝑚
# $$
#
# **Equation 15.3**
# $$
# 𝐻=𝐼−1𝑛11𝑇
# $$
#
# **Equation 15.4**
# $$
# 𝐵=𝑋𝑋𝑇=𝑏112⋯𝑏1𝑛2⋮⋱⋮𝑏𝑛12⋯𝑏𝑛𝑛2
# $$
#
# **Equation 15.5**
# $$
# 𝐷2=𝑑112⋯𝑑1𝑛2⋮⋱⋮𝑑𝑛12⋯𝑑𝑛𝑛2
# $$
#
# **Equation 15.6**
# $$
# 𝑑𝑖𝑗2=𝐱𝑖−𝐱𝑗𝐱𝑖−𝐱𝑗T
# $$
#
# **Equation 15.7**
# $$
# =𝐱𝑖𝐱𝑖𝑇+𝐱𝑗𝐱𝑗𝑇−2𝐱𝑖𝐱𝑗𝑇
# $$
#
# **Equation 15.8**
# $$
# 𝑑𝑖𝑗2=𝐵𝑖𝑖+𝐵𝑗𝑗−2𝐵𝑖𝑗
# $$
#
# **Equation 15.9**
# $$
# 𝐻𝐷2𝐻=𝐻𝑑𝑖𝑎𝑔𝐵1𝑇+𝑑𝑖𝑎𝑔𝐵𝑇1−2𝐵𝐻
# $$
#
# **Equation 15.10**
# $$
# 𝐻𝐷2𝐻=−2𝐻𝐵𝐻
# $$
#
# **Equation 15.11**
# $$
# 𝐷2=𝑑𝑖𝑎𝑔𝐵𝟏𝑇+𝟏𝑑𝑖𝑎𝑔𝐵𝑇−2𝐵
# $$
#
# **Equation 15.12**
# $$
# 𝑋=𝑥11⋯𝑥1𝑚⋮⋱⋮𝑥𝑛1⋯𝑥𝑛𝑚
# $$
#
# **Equation 15.13**
# $$
# 𝐱𝑖=𝑥𝑖1…𝑥𝑖𝑚
# $$
#
# **Equation 15.14**
# $$
# 𝐻=𝐼−1𝑛11𝑇
# $$
#
# **Equation 15.15**
# $$
# 𝐵=𝑋𝑋𝑇=𝑏112⋯𝑏1𝑛2⋮⋱⋮𝑏𝑛12⋯𝑏𝑛𝑛2
# $$
#
# **Equation 15.16**
# $$
# 𝐷2=𝑑112⋯𝑑1𝑛2⋮⋱⋮𝑑𝑛12⋯𝑑𝑛𝑛2
# $$
#
# **Equation 15.17**
# $$
# 𝑑𝑖𝑗2=𝐱𝑖−𝐱𝑗𝐱𝑖−𝐱𝑗T
# $$
#
# **Equation 15.18**
# $$
# =𝐱𝑖𝐱𝑖𝑇+𝐱𝑗𝐱𝑗𝑇−2𝐱𝑖𝐱𝑗𝑇
# $$
#
# **Equation 15.19**
# $$
# 𝑑𝑖𝑗2=𝐵𝑖𝑖+𝐵𝑗𝑗−2𝐵𝑖𝑗
# $$
#
# **Equation 15.20**
# $$
# 𝐻𝐷2𝐻=𝐻𝑑𝑖𝑎𝑔𝐵1𝑇+𝑑𝑖𝑎𝑔𝐵𝑇1−2𝐵𝐻
# $$
#
# **Equation 15.21**
# $$
# 𝐻𝐷2𝐻=−2𝐻𝐵𝐻
# $$
#
# **Equation 15.22**
# $$
# 𝐷2=𝑑𝑖𝑎𝑔𝐵𝟏𝑇+𝟏𝑑𝑖𝑎𝑔𝐵𝑇−2𝐵
# $$
#
# ![slide15-image1](data:image/png;base64,...)
# ![slide15-image2](data:image/png;base64,...)
# ![slide15-image3](data:image/png;base64,...)
# ![slide15-image4](data:image/png;base64,...)
# ![slide15-image5](data:image/png;base64,...)
# ![slide15-image6](data:image/png;base64,...)
# ![slide15-image7](data:image/png;base64,...)
# ![slide15-image8](data:image/png;base64,...)
# ![slide15-image9](data:image/png;base64,...)
# ![slide15-image10](data:image/png;base64,...)
# ![slide15-image11](data:image/png;base64,...)

# %% [markdown]
# ### Slide 16: (Untitled)
#
# - 다차원 척도법
# - 4
# - 고전적 다차원 척도법
# - 를 중심 평균화
# - 유클리디언 거리로 된 거리행렬만 주어졌을 때 활용
#
# **Equation 16.1**
# $$
# 𝐻𝐷2𝐻=−2𝐻𝐵𝐻
# $$
#
# **Equation 16.2**
# $$
# 𝐻𝐵𝐻=−𝐻𝐷2𝐻2
# $$
#
# **Equation 16.3**
# $$
# 𝐻𝐵𝐻=𝐻𝑋𝑋𝑇𝐻=𝑋𝑐𝑋𝑐𝑇
# $$
#
# **Equation 16.4**
# $$
# 𝑋𝑐=𝑋−𝑋
# $$
#
# **Equation 16.5**
# $$
# 𝑋
# $$
#
# **Equation 16.6**
# $$
# 𝑋𝑐𝑋𝑐𝑇=−𝐻𝐷2𝐻2
# $$
#
# **Equation 16.7**
# $$
# 𝐻𝐷2𝐻=−2𝐻𝐵𝐻
# $$
#
# **Equation 16.8**
# $$
# 𝐻𝐵𝐻=−𝐻𝐷2𝐻2
# $$
#
# **Equation 16.9**
# $$
# 𝐻𝐵𝐻=𝐻𝑋𝑋𝑇𝐻=𝑋𝑐𝑋𝑐𝑇
# $$
#
# **Equation 16.10**
# $$
# 𝑋𝑐=𝑋−𝑋
# $$
#
# **Equation 16.11**
# $$
# 𝑋𝑐𝑋𝑐𝑇=−𝐻𝐷2𝐻2
# $$
#
# ![slide16-image1](data:image/png;base64,...)
# ![slide16-image2](data:image/png;base64,...)
# ![slide16-image3](data:image/png;base64,...)
# ![slide16-image4](data:image/png;base64,...)
# ![slide16-image5](data:image/png;base64,...)
# ![slide16-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 17: (Untitled)
#
# - 다차원 척도법
# - Metric MDS and Non-Metric MDS
# - 4
# - Stress 함수를 최소화하는 저차원의 값 찾기
# - Metric MDS
# - Non-metric MDS
# - 거리
# - Metric 거리
# - 유사도 관계
# - Stress 함수
# - 특징
# - 크기 정보(비율, 간격) 자체가 의미 있음
# - 거리 값이 연속적이고 수치적 의미가 있는 경우에 적합
# - 입력 거리의 순위 정보만 중요
# - 심리학, 사회학 등 주관적 유사도 기반 분석에 유용
# - Metric MDS
# - Non-metric MDS
# - 거리
# - Metric 거리
# - 유사도 관계
# - Stress 함수
# - 특징
# - 크기 정보(비율, 간격) 자체가 의미 있음
# - 거리 값이 연속적이고 수치적 의미가 있는 경우에 적합
# - 입력 거리의 순위 정보만 중요
# - 심리학, 사회학 등 주관적 유사도 기반 분석에 유용
# - : 원래 데이터 포인트 의 거리
# - : 축소된 차원의 데이터 포인트 의 거리
# - : 원래 데이터 포인트의 거리 순위
# - : 축소된 차원의 데이터 포인트 의 거리 순위
# - 단조 증가 함수
#
# **Table 17.1**
# |   | Metric MDS | Non-metric MDS |
# | --- | --- | --- |
# | 거리 | Metric 거리 | 유사도 관계 |
# | Stress 함수 |   |   |
# | 특징 | 크기 정보(비율, 간격) 자체가 의미 있음
# 거리 값이 연속적이고 수치적 의미가 있는 경우에 적합 | 입력 거리의 순위 정보만 중요
# 심리학, 사회학 등 주관적 유사도 기반 분석에 유용 |
#
# **Table 17.2**
# |   | Metric MDS | Non-metric MDS |
# | --- | --- | --- |
# | 거리 | Metric 거리 | 유사도 관계 |
# | Stress 함수 |   |   |
# | 특징 | 크기 정보(비율, 간격) 자체가 의미 있음
# 거리 값이 연속적이고 수치적 의미가 있는 경우에 적합 | 입력 거리의 순위 정보만 중요
# 심리학, 사회학 등 주관적 유사도 기반 분석에 유용 |
#
# **Equation 17.1**
# $$
# 𝑖<𝑗𝑑𝑖𝑗−𝛿𝑖𝑗2
# $$
#
# **Equation 17.2**
# $$
# 𝑖<𝑗𝑓(𝑑𝑖𝑗)−𝛿𝑖𝑗2
# $$
#
# **Equation 17.3**
# $$
# 𝑑𝑖𝑗
# $$
#
# **Equation 17.4**
# $$
# 𝑖,𝑗
# $$
#
# **Equation 17.5**
# $$
# 𝛿𝑖𝑗
# $$
#
# **Equation 17.6**
# $$
# 𝑖,𝑗
# $$
#
# **Equation 17.7**
# $$
# 𝑑𝑖𝑗
# $$
#
# **Equation 17.8**
# $$
# 𝛿𝑖𝑗
# $$
#
# **Equation 17.9**
# $$
# 𝑖,𝑗
# $$
#
# **Equation 17.10**
# $$
# 𝑓(𝑥) :
# $$
#
# **Equation 17.11**
# $$
# 𝑖<𝑗𝑑𝑖𝑗−𝛿𝑖𝑗2
# $$
#
# **Equation 17.12**
# $$
# 𝑖<𝑗𝑓(𝑑𝑖𝑗)−𝛿𝑖𝑗2
# $$
#
# ![slide17-image1](data:image/png;base64,...)
# ![slide17-image2](data:image/png;base64,...)
# ![slide17-image3](data:image/png;base64,...)
# ![slide17-image4](data:image/png;base64,...)
# ![slide17-image5](data:image/png;base64,...)
# ![slide17-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 18: (Untitled)
#
# - 다차원 척도법
# - 4
# - MNIST 손글씨 데이터 시각화
#
# ![slide18-image1](data:image/png;base64,...)
# ![slide18-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 19: (Untitled)
#
# - t-확률적 이웃 임베딩
# - : 원래 공간에서 데이터 포인트 가 이웃일 확률
# - : 가우시안 분포를 기반으로 계산
# - : perplexity 값을 기준으로 데이터 포인트마다
# - 이진 탐색을 통해 자동 산출
# - 5
# - t-확률적 이웃 임베딩(t-Distributed Stochastic Neighbor Embedding)
# - : 국소적인 구조를 보존하며 2, 3 차원으로 축소
# - 차원 축소 과정
#
# **Equation 19.1**
# $$
# 𝑝𝑖𝑗
# $$
#
# **Equation 19.2**
# $$
# 𝑖,𝑗
# $$
#
# **Equation 19.3**
# $$
# 𝑝𝑖𝑗
# $$
#
# **Equation 19.4**
# $$
# 𝑝𝑗|𝑖=exp−𝐱𝑖−𝐱𝑗22𝜎𝑖2𝑘≠𝑖exp−𝐱𝑖−𝐱𝑘22𝜎𝑖2
# $$
#
# **Equation 19.5**
# $$
# 𝑝𝑖𝑗=𝑝𝑗|𝑖+𝑝𝑖|𝑗2𝑛
# $$
#
# **Equation 19.6**
# $$
# 𝜎𝑖2
# $$
#
# **Equation 19.7**
# $$
# 𝑖
# $$
#
# **Equation 19.8**
# $$
# 𝑝𝑗|𝑖=exp−𝐱𝑖−𝐱𝑗22𝜎𝑖2𝑘≠𝑖exp−𝐱𝑖−𝐱𝑘22𝜎𝑖2
# $$
#
# **Equation 19.9**
# $$
# 𝑝𝑖𝑗=𝑝𝑗|𝑖+𝑝𝑖|𝑗2𝑛
# $$
#
# ![slide19-image1](data:image/png;base64,...)
# ![slide19-image2](data:image/png;base64,...)
# ![slide19-image3](data:image/png;base64,...)
# ![slide19-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 20: (Untitled)
#
# - t-확률적 이웃 임베딩
# - 5
# - t-확률적 이웃 임베딩(t-Distributed Stochastic Neighbor Embedding)
# - 국소적인 구조를 잘 보존하면서 2, 3 차원으로 축소
# - : 축소 공간에서 데이터 포인트 I, j I 점에서 j 점을 선택할 확률
# - : 자유도가 1 인 Student-t 분포를 기반으로 계산. 양쪽 꼬리가 두터워 멀리 있는 점까지 구분 효과
# - t-분포 확률 밀도 함수
#
# **Equation 20.1**
# $$
# 𝑞𝑖𝑗
# $$
#
# **Equation 20.2**
# $$
# 𝑞𝑖𝑗=1+𝑦𝑖−𝑦𝑗2−1𝑘≠𝑙1+𝑦𝑘−𝑦𝑙2−1
# $$
#
# **Equation 20.3**
# $$
# 𝑓𝜈(𝑡)=Γ𝜈+12𝜈𝜋Γ𝜈21+𝑡2𝜈−𝜈+12
# $$
#
# **Equation 20.4**
# $$
# 𝑞𝑖𝑗=1+𝑦𝑖−𝑦𝑗2−1𝑘≠𝑙1+𝑦𝑘−𝑦𝑙2−1
# $$
#
# **Equation 20.5**
# $$
# 𝑓𝜈(𝑡)=Γ𝜈+12𝜈𝜋Γ𝜈21+𝑡2𝜈−𝜈+12
# $$
#
# ![slide20-image1](data:image/png;base64,...)
# ![slide20-image2](data:image/png;base64,...)
# ![slide20-image3](data:image/png;base64,...)

# %% [markdown]
# ### Slide 21: (Untitled)
#
# - t-확률적 이웃 임베딩
# - 경사하강법으로 값 도출
# - 실 함수: Kullback Leibler Divergence
# - 5
# - 학습 방법
#
# **Equation 21.1**
# $$
# 𝐾𝐿(𝑃|𝑄=𝑖≠𝑗𝑝𝑖𝑗log𝑝𝑖𝑗𝑞𝑖𝑗
# $$
#
# **Equation 21.2**
# $$
# 𝐿=𝑖≠𝑗𝑝𝑖𝑗log𝑝𝑖𝑗−𝑖≠𝑗𝑝𝑖𝑗log𝑞𝑖𝑗
# $$
#
# **Equation 21.3**
# $$
# 𝜕𝐿𝜕𝑦𝑖=4𝑗𝑝𝑖𝑗−𝑞𝑖𝑗𝑦𝑖−𝑦𝑗1+𝑦𝑖−𝑦𝑗2−1
# $$
#
# **Equation 21.4**
# $$
# 손
# $$
#
# **Equation 21.5**
# $$
# 𝐾𝐿(𝑃|𝑄=𝑖≠𝑗𝑝𝑖𝑗log𝑝𝑖𝑗𝑞𝑖𝑗
# $$
#
# **Equation 21.6**
# $$
# 𝐿=𝑖≠𝑗𝑝𝑖𝑗log𝑝𝑖𝑗−𝑖≠𝑗𝑝𝑖𝑗log𝑞𝑖𝑗
# $$
#
# **Equation 21.7**
# $$
# 𝜕𝐿𝜕𝑦𝑖=4𝑗𝑝𝑖𝑗−𝑞𝑖𝑗𝑦𝑖−𝑦𝑗1+𝑦𝑖−𝑦𝑗2−1
# $$
#
# ![slide21-image1](data:image/png;base64,...)
# ![slide21-image2](data:image/png;base64,...)
# ![slide21-image3](data:image/png;base64,...)
# ![slide21-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 22: (Untitled)
#
# - t-확률적 이웃 임베딩
# - 5
# - MNIST 손글씨 데이터 시각화
#
# ![slide22-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 23: (Untitled)
#
# - t-확률적 이웃 임베딩
# - 5
# - 장점
# - 단점
# - 클러스터 구조가 잘 드러남
# - 비선형 구조를 잘 잡아냄
# - 복잡한 데이터 구조를 시각적으로 명확하게 구분하게 함
# - 하이퍼 파라미터에 민감
# - 재현성 낮음(초기값에 따라 결과가 달라짐)
# - 계산 비용이 높음

# %% [markdown]
# ### Slide 24: (Untitled)
#
# - 선형판별분석
# - : k 클래스의 데이터 포인트의 평균점
# - : 데이터 포인트의 평균점
# - : 클래스의 수
# - 6
# - 선형판별분석(Linear Discriminant Analysis)
# - : 클래스 간 분리도를 최대로 유지한 차원 축소
# - 클래스 간의 분산은 최대화
# - 클래스 내부의 분산은 최소화
#
# **Equation 24.1**
# $$
# 𝑆𝐵=𝑘=1𝐾𝑁𝑘𝛍𝐤−𝛍𝛍𝐤−𝛍𝑇
# $$
#
# **Equation 24.2**
# $$
# 𝛍𝐤
# $$
#
# **Equation 24.3**
# $$
# 𝛍
# $$
#
# **Equation 24.4**
# $$
# 𝐾
# $$
#
# **Equation 24.5**
# $$
# 𝑆𝐵=𝑘=1𝐾𝐱∈𝐶𝑘𝐱−𝛍𝐊𝒙−𝛍𝐤𝑇
# $$
#
# **Equation 24.6**
# $$
# Ck=𝐱𝐱는 k군집의 데이터 포인트}
# $$
#
# **Equation 24.7**
# $$
# 𝑆𝐵=𝑘=1𝐾𝑁𝑘𝛍𝐤−𝛍𝛍𝐤−𝛍𝑇
# $$
#
# **Equation 24.8**
# $$
# 𝑆𝐵=𝑘=1𝐾𝐱∈𝐶𝑘𝐱−𝛍𝐊𝒙−𝛍𝐤𝑇
# $$
#
# **Equation 24.9**
# $$
# Ck=𝐱𝐱는 k군집의 데이터 포인트}
# $$
#
# ![slide24-image1](data:image/png;base64,...)
# ![slide24-image2](data:image/png;base64,...)
# ![slide24-image3](data:image/png;base64,...)
# ![slide24-image4](data:image/png;base64,...)
# ![slide24-image5](data:image/png;base64,...)
# ![slide24-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 25: (Untitled)
#
# - 선형판별분석
# - : 투영 벡터(선형 판별 벡터)
# - Fisher Criterion
# - 일반화된 고윳값 문제로 도출
# - 6
# - 변환 유도 과정
# - min(k-1, W 의 차원) 개의 선형 판별 벡터 도출 가능
# - 의 고윳값 분해
#
# **Equation 25.1**
# $$
# 𝐽(𝐰)=𝐰𝐓𝐒𝐵𝐰𝐰𝐓𝐒𝑊𝐰
# $$
#
# **Equation 25.2**
# $$
# 𝐰
# $$
#
# **Equation 25.3**
# $$
# 𝑆𝐵𝑊=𝑆𝑊𝑊𝚲
# $$
#
# **Equation 25.4**
# $$
# 𝑆𝑊−1𝑆𝐵𝑊=𝑊𝚲
# $$
#
# **Equation 25.5**
# $$
# 𝑆𝐵𝑆𝑊−1
# $$
#
# **Equation 25.6**
# $$
# 𝐽(𝐰)=𝐰𝐓𝐒𝐵𝐰𝐰𝐓𝐒𝑊𝐰
# $$
#
# **Equation 25.7**
# $$
# 𝑆𝐵𝑊=𝑆𝑊𝑊𝚲
# $$
#
# **Equation 25.8**
# $$
# 𝑆𝑊−1𝑆𝐵𝑊=𝑊𝚲
# $$
#
# ![slide25-image1](data:image/png;base64,...)
# ![slide25-image2](data:image/png;base64,...)
# ![slide25-image3](data:image/png;base64,...)
# ![slide25-image4](data:image/png;base64,...)
# ![slide25-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 26: (Untitled)
#
# - 선형판별분석
# - Explained Variance: 47.17%
# - 6
# - MNIST 손글씨 데이터 시각화
#
# ![slide26-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 27: (Untitled)
#
# - 부분 최소 제곱 회귀
# - 7
# - 부분 최소 제곱 회귀(Partial Least Squares Regression, PLS)
# - 수치형 입력 변수 X 에서 Y 를 예측력을 최대한 유지하는 선형 변환을 유도하여 축소
# - : PLS 의 성분수
# - ,
# - : X 의 score, 성분 행렬
# - : Y 의 score
# - : loading 행렬
# - : 잔차 행렬
# - 의 공분산 행렬을 최대화
#
# **Equation 27.1**
# $$
# 𝑋∈𝑅𝑛×𝑚
# $$
#
# **Equation 27.2**
# $$
# 𝑌∈𝑅𝑛×𝑝
# $$
#
# **Equation 27.3**
# $$
# 𝑋=𝑇𝑃𝑇+𝐸
# $$
#
# **Equation 27.4**
# $$
# 𝑌=𝑈𝑄𝑇+𝐹
# $$
#
# **Equation 27.5**
# $$
# 𝑙
# $$
#
# **Equation 27.6**
# $$
# 𝑇, 𝑈∈𝑅𝑛×𝑙
# $$
#
# **Equation 27.7**
# $$
# 𝑃∈𝑅𝑚×𝑙
# $$
#
# **Equation 27.8**
# $$
# 𝑄∈𝑅𝑝×𝑙
# $$
#
# **Equation 27.9**
# $$
# 𝑇
# $$
#
# **Equation 27.10**
# $$
# 𝑈
# $$
#
# **Equation 27.11**
# $$
# 𝑃, 𝑄
# $$
#
# **Equation 27.12**
# $$
# 𝐸∈𝑅𝑛×𝑚,𝐹∈𝑅𝑛×𝑚
# $$
#
# **Equation 27.13**
# $$
# 𝐸, 𝐹
# $$
#
# **Equation 27.14**
# $$
# 𝑇, 𝑈
# $$
#
# **Equation 27.15**
# $$
# 𝑋∈𝑅𝑛×𝑚
# $$
#
# **Equation 27.16**
# $$
# 𝑌∈𝑅𝑛×𝑝
# $$
#
# **Equation 27.17**
# $$
# 𝑋=𝑇𝑃𝑇+𝐸
# $$
#
# **Equation 27.18**
# $$
# 𝑌=𝑈𝑄𝑇+𝐹
# $$
#
# **Equation 27.19**
# $$
# 𝑇, 𝑈∈𝑅𝑛×𝑙
# $$
#
# **Equation 27.20**
# $$
# 𝐸∈𝑅𝑛×𝑚,𝐹∈𝑅𝑛×𝑚
# $$
#
# ![slide27-image1](data:image/png;base64,...)
# ![slide27-image2](data:image/png;base64,...)
# ![slide27-image3](data:image/png;base64,...)
# ![slide27-image4](data:image/png;base64,...)
# ![slide27-image5](data:image/png;base64,...)
# ![slide27-image6](data:image/png;base64,...)
# ![slide27-image7](data:image/png;base64,...)
# ![slide27-image8](data:image/png;base64,...)
# ![slide27-image9](data:image/png;base64,...)
# ![slide27-image10](data:image/png;base64,...)
# ![slide27-image11](data:image/png;base64,...)
# ![slide27-image12](data:image/png;base64,...)
# ![slide27-image13](data:image/png;base64,...)

# %% [markdown]
# ### Slide 28: (Untitled)
#
# - 부분 최소 제곱 회귀
# - PLS2: 다변량(𝑝≥2)회귀 문제 성분 추정
# - 7
# - X, Y 의 공분산을 최대화 하는 방향의 w, c 를 찾기 위해,
# - X 에서 와 Y 에서 를 추출
# - 1. 중심 평균화
#
# **Equation 28.1**
# $$
# 𝑡=𝑋𝑝
# $$
#
# **Equation 28.2**
# $$
# u=𝑌𝑞
# $$
#
# **Equation 28.3**
# $$
# 𝑋𝑐=𝑋−𝑋
# $$
#
# **Equation 28.4**
# $$
# 𝑌𝑐=𝑌−𝑌
# $$
#
# **Equation 28.5**
# $$
# 𝑋=𝑇𝑃𝑇+𝐸
# $$
#
# **Equation 28.6**
# $$
# 𝑌=𝑈𝑄𝑇+𝐹
# $$
#
# **Equation 28.7**
# $$
# 𝑋,𝑌
# $$
#
# **Equation 28.8**
# $$
# 𝑋𝑐=𝑋−𝑋
# $$
#
# **Equation 28.9**
# $$
# 𝑌𝑐=𝑌−𝑌
# $$
#
# **Equation 28.10**
# $$
# 𝑋=𝑇𝑃𝑇+𝐸
# $$
#
# **Equation 28.11**
# $$
# 𝑌=𝑈𝑄𝑇+𝐹
# $$
#
# ![slide28-image1](data:image/png;base64,...)
# ![slide28-image2](data:image/png;base64,...)
# ![slide28-image3](data:image/png;base64,...)
# ![slide28-image4](data:image/png;base64,...)
# ![slide28-image5](data:image/png;base64,...)
# ![slide28-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 29: (Untitled)
#
# - 부분 최소 제곱 회귀
# - PLS2: 다변량(𝑝≥2)회귀 문제 성분 추정
# - 7
# - 를 최대화
# - 에서,
# - : Y 의 첫 번째 주성분으로 초기화
# - 증명: 다음 페이지
# - Y 를 t 로 예측하는 회귀 계수
# - 수렴할 때까지 반복
# - 2. 성분 추출
#
# **Equation 29.1**
# $$
# 𝐶𝑜𝑣𝑋𝑐𝐰,𝐮=𝑋𝑐𝐰𝐮𝑛
# $$
#
# **Equation 29.2**
# $$
# 𝑋𝑐𝐰𝐮2
# $$
#
# **Equation 29.3**
# $$
# 𝐰=1
# $$
#
# **Equation 29.4**
# $$
# 𝐮
# $$
#
# **Equation 29.5**
# $$
# 𝐮∈𝑅𝑛
# $$
#
# **Equation 29.6**
# $$
# 𝐰∈𝑅𝑚
# $$
#
# **Equation 29.7**
# $$
# 𝐜∈𝑅𝑝
# $$
#
# **Equation 29.8**
# $$
# 𝐰=𝑋𝑐𝑇𝐮𝑋𝑐𝑇𝐮2
# $$
#
# **Equation 29.9**
# $$
# 𝐜=𝑌𝑐𝑇𝐭𝐭T𝐭
# $$
#
# **Equation 29.10**
# $$
# 𝐭=𝑋𝑐𝐰
# $$
#
# **Equation 29.11**
# $$
# 𝐮=𝑌𝑐𝐜
# $$
#
# **Equation 29.12**
# $$
# 𝐶𝑜𝑣𝑋𝑐𝐰,𝐮=𝑋𝑐𝐰𝐮𝑛
# $$
#
# **Equation 29.13**
# $$
# 𝐮∈𝑅𝑛
# $$
#
# **Equation 29.14**
# $$
# 𝐰∈𝑅𝑚
# $$
#
# **Equation 29.15**
# $$
# 𝐜∈𝑅𝑝
# $$
#
# **Equation 29.16**
# $$
# 𝐰=𝑋𝑐𝑇𝐮𝑋𝑐𝑇𝐮2
# $$
#
# **Equation 29.17**
# $$
# 𝐜=𝑌𝑐𝑇𝐭𝐭T𝐭
# $$
#
# **Equation 29.18**
# $$
# 𝐭=𝑋𝑐𝐰
# $$
#
# **Equation 29.19**
# $$
# 𝐮=𝑌𝑐𝐜
# $$
#
# ![slide29-image1](data:image/png;base64,...)
# ![slide29-image2](data:image/png;base64,...)
# ![slide29-image3](data:image/png;base64,...)
# ![slide29-image4](data:image/png;base64,...)
# ![slide29-image5](data:image/png;base64,...)
# ![slide29-image6](data:image/png;base64,...)
# ![slide29-image7](data:image/png;base64,...)
# ![slide29-image8](data:image/png;base64,...)
# ![slide29-image9](data:image/png;base64,...)
# ![slide29-image10](data:image/png;base64,...)
# ![slide29-image11](data:image/png;base64,...)

# %% [markdown]
# ### Slide 30: (Untitled)
#
# - 부분 최소 제곱 회귀
# - 을 증명
# - 7
# - PLS2: 다변량(𝑝≥2)회귀 문제 성분 추정
# - w 의 l2-norm 이 1 로 제약이 걸려 있는 상황에서
# - 위 식이 최대가 되려면, w 는 평행한 벡터
#
# **Equation 30.1**
# $$
# w=𝑋𝐜𝐓𝐮𝑋𝒄𝑻𝐮𝟐
# $$
#
# **Equation 30.2**
# $$
# 𝐰=𝛼X𝑐𝑇𝐮
# $$
#
# **Equation 30.3**
# $$
# 𝑋𝑐𝐰𝐮=𝐰TX𝑐𝑇𝐮
# $$
#
# **Equation 30.4**
# $$
# X𝑐𝑇𝐮와
# $$
#
# **Equation 30.5**
# $$
# 𝒘=𝑿𝐜𝐓𝐮𝑿𝒄𝑻𝐮𝟐
# $$
#
# **Equation 30.6**
# $$
# maxw2=1𝑋𝑐𝐰𝐮
# $$
#
# **Equation 30.7**
# $$
# 𝐰=𝛼X𝑐𝑇𝐮
# $$
#
# **Equation 30.8**
# $$
# 𝑋𝑐𝐰𝐮=𝐰TX𝑐𝑇𝐮
# $$
#
# **Equation 30.9**
# $$
# 𝒘=𝑿𝐜𝐓𝐮𝑿𝒄𝑻𝐮𝟐
# $$
#
# **Equation 30.10**
# $$
# maxw2=1𝑋𝑐𝐰𝐮
# $$
#
# ![slide30-image1](data:image/png;base64,...)
# ![slide30-image2](data:image/png;base64,...)
# ![slide30-image3](data:image/png;base64,...)
# ![slide30-image4](data:image/png;base64,...)
# ![slide30-image5](data:image/png;base64,...)
# ![slide30-image6](data:image/png;base64,...)
# ![slide30-image7](data:image/png;base64,...)

# %% [markdown]
# ### Slide 31: (Untitled)
#
# - 부분 최소 제곱 회귀
# - 7
# - PLS2: 다변량(𝑝≥2)회귀 문제 성분 추정
# - 3. 𝐩, 𝐪 도출
# - t 벡터로 X 를 예측하는 정규방정식의 해
# - t 벡터로 Y 를 예측하는 정규방정식의 해
#
# **Equation 31.1**
# $$
# 𝑋𝑐=𝑇𝑃𝑇+𝐸
# $$
#
# **Equation 31.2**
# $$
# 𝑌𝑐=𝑈𝑄𝑇+𝐹
# $$
#
# **Equation 31.3**
# $$
# p=𝑋𝑐TttTt
# $$
#
# **Equation 31.4**
# $$
# q=𝑌𝑐TttTt
# $$
#
# **Equation 31.5**
# $$
# 𝑈≈𝑇
# $$
#
# **Equation 31.6**
# $$
# 𝑋𝑐=𝑇𝑃𝑇+𝐸
# $$
#
# **Equation 31.7**
# $$
# 𝑌𝑐=𝑈𝑄𝑇+𝐹
# $$
#
# **Equation 31.8**
# $$
# p=𝑋𝑐TttTt
# $$
#
# **Equation 31.9**
# $$
# q=𝑌𝑐TttTt
# $$
#
# **Equation 31.10**
# $$
# 𝑈≈𝑇
# $$
#
# ![slide31-image1](data:image/png;base64,...)
# ![slide31-image2](data:image/png;base64,...)
# ![slide31-image3](data:image/png;base64,...)
# ![slide31-image4](data:image/png;base64,...)
# ![slide31-image5](data:image/png;base64,...)
# ![slide31-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 32: (Untitled)
#
# - 부분 최소 제곱 회귀
# - 7
# - PLS2: 다변량(𝑝≥2)회귀 문제 성분 추정
# - 4. 𝑋, 𝑌 에서 성분에 의해 설명되는 양 제거(Deflation)
# - 지정한 성분 수가 뽑힐 때까지 2 단계 부터 반복
# - : 각 단계 w 로 구성된 행렬
# - : 각 단계 p 로 구성된 행렬
# - : 각 단계 q 로 구성된 행렬
# - 의 유도
#
# **Equation 32.1**
# $$
# 𝑋←𝑋−tp𝑡
# $$
#
# **Equation 32.2**
# $$
# 𝑌←𝑌−tq𝑡
# $$
#
# **Equation 32.3**
# $$
# 𝑊
# $$
#
# **Equation 32.4**
# $$
# 𝑃
# $$
#
# **Equation 32.5**
# $$
# 𝑄
# $$
#
# **Equation 32.6**
# $$
# 𝑌𝑐=𝑋𝐶𝐵
# $$
#
# **Equation 32.7**
# $$
# 𝑋𝑐=𝑇𝑃𝑇
# $$
#
# **Equation 32.8**
# $$
# 𝑌=𝑇𝑄𝑇
# $$
#
# **Equation 32.9**
# $$
# 𝑋𝑐≈𝑇𝑃𝑇
# $$
#
# **Equation 32.10**
# $$
# 𝑇≈𝑋𝑐𝑊𝑃𝑇𝑊−1
# $$
#
# **Equation 32.11**
# $$
# 𝑌
# $$
#
# **Equation 32.12**
# $$
# 𝑋𝑐≈𝑋𝑐
# $$
#
# **Equation 32.13**
# $$
# 𝑋𝑐𝑊≈𝑇𝑃𝑇𝑊
# $$
#
# **Equation 32.14**
# $$
# 𝐵=𝑊𝑃𝑇𝑊−1𝑄𝑇
# $$
#
# **Equation 32.15**
# $$
# 𝑋←𝑋−tp𝑡
# $$
#
# **Equation 32.16**
# $$
# 𝑌←𝑌−tq𝑡
# $$
#
# **Equation 32.17**
# $$
# 𝑌𝑐=𝑋𝐶𝐵
# $$
#
# **Equation 32.18**
# $$
# 𝑋𝑐=𝑇𝑃𝑇
# $$
#
# **Equation 32.19**
# $$
# 𝑌=𝑇𝑄𝑇
# $$
#
# **Equation 32.20**
# $$
# 𝑋𝑐≈𝑇𝑃𝑇
# $$
#
# **Equation 32.21**
# $$
# 𝑇≈𝑋𝑐𝑊𝑃𝑇𝑊−1
# $$
#
# **Equation 32.22**
# $$
# 𝑋𝑐≈𝑋𝑐
# $$
#
# **Equation 32.23**
# $$
# 𝑋𝑐𝑊≈𝑇𝑃𝑇𝑊
# $$
#
# **Equation 32.24**
# $$
# 𝐵=𝑊𝑃𝑇𝑊−1𝑄𝑇
# $$
#
# ![slide32-image1](data:image/png;base64,...)
# ![slide32-image2](data:image/png;base64,...)
# ![slide32-image3](data:image/png;base64,...)
# ![slide32-image4](data:image/png;base64,...)
# ![slide32-image5](data:image/png;base64,...)
# ![slide32-image6](data:image/png;base64,...)
# ![slide32-image7](data:image/png;base64,...)
# ![slide32-image8](data:image/png;base64,...)
# ![slide32-image9](data:image/png;base64,...)
# ![slide32-image10](data:image/png;base64,...)
# ![slide32-image11](data:image/png;base64,...)
# ![slide32-image12](data:image/png;base64,...)
# ![slide32-image13](data:image/png;base64,...)
# ![slide32-image14](data:image/png;base64,...)
# ![slide32-image15](data:image/png;base64,...)

# %% [markdown]
# ### Slide 33: (Untitled)
#
# - 부분 최소 제곱 회귀
# - PLS1: 단일변량(𝑝=1) PLS2 에서 step2 변경
# - 7
# - 를 최대화하 는 단위벡터 𝐰 를 도출
# - 를 최대화
# - 에서,
#
# **Equation 33.1**
# $$
# 𝑐𝑜𝑣𝑋𝐰, 𝑦2
# $$
#
# **Equation 33.2**
# $$
# 𝐶𝑜𝑣𝑋𝑐w,y=𝑋𝑐wy𝑛
# $$
#
# **Equation 33.3**
# $$
# 𝑋𝑐wy
# $$
#
# **Equation 33.4**
# $$
# w=1
# $$
#
# **Equation 33.5**
# $$
# w=𝑋cT𝑦𝑋𝑐𝑇𝑦2
# $$
#
# **Equation 33.6**
# $$
# t=𝑋𝑐w
# $$
#
# **Equation 33.7**
# $$
# 𝐶𝑜𝑣𝑋𝑐w,y=𝑋𝑐wy𝑛
# $$
#
# **Equation 33.8**
# $$
# w=𝑋cT𝑦𝑋𝑐𝑇𝑦2
# $$
#
# **Equation 33.9**
# $$
# t=𝑋𝑐w
# $$
#
# ![slide33-image1](data:image/png;base64,...)
# ![slide33-image2](data:image/png;base64,...)
# ![slide33-image3](data:image/png;base64,...)
# ![slide33-image4](data:image/png;base64,...)
# ![slide33-image5](data:image/png;base64,...)
# ![slide33-image6](data:image/png;base64,...)
# ![slide33-image7](data:image/png;base64,...)

# %% [markdown]
# ### Slide 34: (Untitled)
#
# - 정리
# - 8
# - 보존 구조
# - 장점
# - 단점
# - 주성분 분석
# - (PCA)
# - 전체 분산
# - 빠른 속도와 선형 구조 보존
# - 노이즈 제거 효과
# - 해석 가능
# - 비선형 구조 표현 제한적
# - 특이값 분해
# - (SVD)
# - 행렬의 저차원 근사화
# - PCA 일반화를 통한 모든 행렬 적용 가능
# - 잠재 요소 추출 특화
# - 노이즈 민감
# - 선형 판별 분석
# - (LDA)
# - 클래스 간 분산
# - 클래스 내 분산 비율
# - 클래스 분리 최대화
# - 표현의 제한(클래스 수 – 1 차원)
# - t-SNE
# - 지역 구조
# - 고차원 데이터 시각화 특화
# - 비선형 구조 반영
# - 전체 구조 보존 불가능
# - 결과 불안정
# - 높은 계산 비용
# - 다차원 척도법
# - (MDS)
# - 거리 행렬(유사도)
# - 거리 기반 구조 재현
# - Non-metric 즉 대소 관계로 수행 가능
# - 고전적: 선형 구조만 반영
# - Metric: 높은 계산 비용, 높은 수치 해석 난이도
# - Non-metric: 순서 정보 사용으로 인한 기존 수치 의미 손실
# - 부분 최소 제곱법
# - (PLS)
# - X 와 Y 간의 공분산
# - 다중 공선성의 대응책
# - 높은 해석 난이도
#
# **Table 34.1**
# |   | 보존 구조 | 장점 | 단점 |
# | --- | --- | --- | --- |
# | 주성분 분석
# (PCA) | 전체 분산 | 빠른 속도와 선형 구조 보존
# 노이즈 제거 효과
# 해석 가능 | 비선형 구조 표현 제한적 |
# | 특이값 분해
# (SVD) | 행렬의 저차원 근사화 | PCA 일반화를 통한 모든 행렬 적용 가능
# 잠재 요소 추출 특화 | 노이즈 민감 |
# | 선형 판별 분석
# (LDA) | 클래스 간 분산
# 클래스 내 분산 비율 | 클래스 분리 최대화 | 표현의 제한(클래스 수 – 1 차원) |
# | t-SNE | 지역 구조 | 고차원 데이터 시각화 특화
# 비선형 구조 반영 | 전체 구조 보존 불가능
# 결과 불안정
# 높은 계산 비용 |
# | 다차원 척도법
# (MDS) | 거리 행렬(유사도) | 거리 기반 구조 재현
# Non-metric 즉 대소 관계로 수행 가능 | 고전적: 선형 구조만 반영
# Metric: 높은 계산 비용, 높은 수치 해석 난이도
# Non-metric: 순서 정보 사용으로 인한 기존 수치 의미 손실 |
# | 부분 최소 제곱법
# (PLS) | X 와 Y 간의 공분산 | 다중 공선성의 대응책 | 높은 해석 난이도 |

# %% [markdown]
# ### Slide 35: (Untitled)
#
# - 9
# - 문제 풀이
# - PCA 는 공분산 행렬의 고윳값을 차원 축소의 기준으로 활용한다.
# - 1
# - SVD 를 통해서도 PCA 와 완전히 동일한 결과를 얻을 수 있다.
# - 2
# - t-SNE 는 축소한 차원의 거리 관계의 변별성 부여를 위해 표준정규분포를 사용한다.
# - 3
# - PLS 는 입력 변수에 다중 공선성이 클 경우에 효과적이다.
# - 4
# - Q1. 다음 차원 축소에 대한 설명으로 틀린 것은?

# %% [markdown]
# ### Slide 36: (Untitled)
#
# - 9
# - 문제 풀이
# - Q1. 다음 차원 축소에 대한 설명으로 틀린 것은?
# - t-SNE 는 축소한 차원의 거리 관계의 변별성 부여를 위해 양쪽 꼬리 면적이 표준정규분포보다 두터운 자유도가 1 인 t 분포를 사용하여 거리의 격차가 있어도 차이가 나도록 합니다.
# - PCA 는 공분산 행렬의 고윳값을 차원 축소의 기준으로 활용한다.
# - 1
# - SVD 를 통해서도 PCA 와 완전히 동일한 결과를 얻을 수 있다.
# - 2
# - 3
# - t-SNE 는 축소한 차원의 거리 관계의 변별성 부여를 위해 표준정규분포를 사용한다.
# - PLS 는 입력 변수에 다중 공선성이 클 경우에 효과적이다.
# - 4

# %% [markdown]
# ### Slide 37: (Untitled)
#
# - 9
# - 문제 풀이
# - 두 개의 주성분으로 전체 분산에서 99% 이상을 설명할 수 있다.
# - 1
# - 첫 번째 주성분에서 두 번째로 영향력이 큰 변수는 ShellWeight 이다.
# - 2
# - 전체 분산은 0.3212 이다.
# - 3
# - 첫 번째 주성분만을 선택하면, 전체 정보 중 약 1.61%의 손실이 발생한다.
# - 4
# - Q2. 다음 주성분 분석의 결과에 대한 설명 틀린 것은?
# - 성분별 고윳값과 비율
# - 성분별 고유벡터
# - 고윳값
# - 고윳값 비율
#
# ![slide37-image1](data:image/png;base64,...)
# ![slide37-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 38: (Untitled)
#
# - 9
# - 문제 풀이
# - 영향도는 주성분에 해당하는 벡터에 변수별 절대값으로 파악 가며 높을수록 영향도가 높습니다.
# - Q2. 다음 주성분 분석의 결과에 대한 설명 틀린 것은?
# - 두 개의 주성분으로 전체 분산에서 99% 이상을 설명할 수 있다.
# - 1
# - 2
# - 첫 번째 주성분에서 두 번째로 영향력이 큰 변수는 ShellWeight 이다.
# - 전체 분산은 0.3212 이다.
# - 3
# - 첫 번째 주성분만을 선택하면, 전체 정보 중 약 1.61%의 손실이 발생한다.
# - 4
# - 성분별 고윳값과 비율
# - 성분별 고유벡터
# - 고윳값
# - 고윳값 비율
#
# ![slide38-image1](data:image/png;base64,...)
# ![slide38-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 39: (Untitled)
#
# - 9
# - 문제 풀이
# - 선형 관계를 지닌 고차원 속성 행렬을 축소하여 시각화 → PCA
# - 1
# - 거리 행렬의 순위 관계를 최대한 반영한 차원 축소 → Non-Metric MDS
# - 3
# - 거리 관계를 최대한 유지하여 차원 축소를 통한 예측력 강화 → t-SNE
# - 4
# - Q3. 상황별 차원 축소법으로 부적합한 것은 무엇인가?
# - 2
# - 클래스를 최대한 구분해주는 공간으로 축소 → LDA

# %% [markdown]
# ### Slide 40: (Untitled)
#
# - 9
# - 문제 풀이
# - Q3. 상황별 차원 축소법으로 부적합한 것은 무엇인가?
# - t-SNE 는 주어진 변수에서만 차원 축소가 가능하며 새로운 값으로 변환할 수 없습니다.
# - 선형 관계를 지닌 고차원 속성 행렬을 축소하여 시각화 → PCA
# - 1
# - 거리 행렬의 순위 관계를 최대한 반영한 차원 축소 → Non-Metric MDS
# - 3
# - 4
# - 거리 관계를 최대한 유지하여 차원 축소를 통한 예측력 강화 → t-SNE
# - 2
# - 클래스를 최대한 구분해주는 공간으로 축소 → LDA
