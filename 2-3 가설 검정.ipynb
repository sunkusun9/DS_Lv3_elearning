# %% [markdown]
# # PPT → Markdown (v3: Better Text Joining + Tables + Equations)
#
# **Source**: `[6차시] LV3_2-3 가설 검정_0825_수정.pptx`
#
# 개선 사항:
# - **폰트/스타일로 분리된 run들을 문장 단위로 매끄럽게 연결**
# - 줄바꿈(br) 보존, 불필요한 공백 정리, 소프트 하이픈 제거
# - bullet(기본) 감지 후 접두사 적용
# - 기존 이미지/테이블/수식/헤더 로직 그대로 유지

# %% [markdown]
# ### Slide 1: (Untitled)
#
# - 06. 가설 검정

# %% [markdown]
# ### Slide 2: (Untitled)
#
# - 1
# - 가설 검정
# - 배타적 관계 형성
# - 가설 검정
# - 두 가설 중에서 어떤 주장을 받아들일지 증거 를 통해 판단하는 추론 방법
# - 대립 가설을 채택하기 위해서는
# - 귀무 가설의 절대성 에 반하는 강력한 증거 가 필요
# - 귀무 가설(Null Hypothesis, H0)
# - 원래의 기준이 되는 가설
# - 기본 입장
# - 대립 가설(Alternative Hypothesis, H1)
# - 귀무 가설에 반하는 가설
# - 대안적 주장
#
# ![slide2-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 3: (Untitled)
#
# - 1
# - 가설 검정
# - 모집단에 대한 가설 검정
# - Ex) OO 우유 200ml 의 용량은 200ml 가 아니라, 그보다 작다.
# - H 0:
# - H 1:
# - 판단 기준 필요
# - 모집단의 대해 가설을 설정하고 표본을 통해 가설의 타당성을 판단
# - 모집단의 특성(모수)을 검증: 평균, 분산, 비율…
#
# **Equation 3.1**
# $$
# 𝝁=𝟐𝟎𝟎
# $$
#
# **Equation 3.2**
# $$
# 𝝁<𝟐𝟎𝟎
# $$
#
# ![slide3-image1](data:image/png;base64,...)
# ![slide3-image2](data:image/png;base64,...)
# ![slide3-image3](data:image/png;base64,...)

# %% [markdown]
# ### Slide 4: (Untitled)
#
# - 1
# - 가설 검정
# - 가설 검정의 기준
# - H 0
# - H 1
# - H 0
# - True Negative
# - False Negative
# - Type II Error(2 종 오류)
# - H 1
# - False Positive
# - Type I Error(1 종 오류)
# - True Positive
# - 결론
# - 사실
# - 귀무 가설을 기각한 결정이 잘못될 확률의 최대값을 기준으로 함
#
# **Table 4.1**
# |   | H 0 | H 1 |
# | --- | --- | --- |
# | H 0 | True Negative | False Negative
# Type II Error(2 종 오류) |
# | H 1 | False Positive
# Type I Error(1 종 오류) | True Positive |
#
# **Equation 4.1**
# $$
# 𝒑−𝒗𝒂𝒍𝒖𝒆=max𝜃∈𝛩𝑃𝜃(𝑅𝑒𝑗𝑒𝑐𝑡 𝐻0|𝐻0 𝑖𝑠 𝑇𝑟𝑢𝑒)
# $$
#
# **Equation 4.2**
# $$
# 𝒑−𝒗𝒂𝒍𝒖𝒆=max𝜃∈𝛩𝑃𝜃(𝑅𝑒𝑗𝑒𝑐𝑡 𝐻0|𝐻0 𝑖𝑠 𝑇𝑟𝑢𝑒)
# $$
#
# ![slide4-image1](data:image/png;base64,...)
# ![slide4-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 5: (Untitled)
#
# - 1
# - 가설 검정
# - p-value 의 계산
# - ‘귀무 가설이 맞다’라는 가정에서 시작
# - Ex) OO 우유 200ml 의 용량이 200ml 가 아니라, 그보다 작다.
# - H 0:
# - H 1:
# - 𝝁=𝟐𝟎𝟎
# - ‘귀무 가설이 맞다’라는 것을 가정 할 수 있음
#
# **Equation 5.1**
# $$
# 𝝁=𝟐𝟎𝟎
# $$
#
# **Equation 5.2**
# $$
# 𝝁<𝟐𝟎𝟎
# $$
#
# **Equation 5.3**
# $$
# 𝑝−𝑣𝑎𝑙𝑢𝑒=𝑃(𝑅𝑒𝑗𝑒𝑐𝑡 𝐻0|𝐻0 𝑖𝑠 𝑇𝑟𝑢𝑒)
# $$
#
# **Equation 5.4**
# $$
# 𝑝−𝑣𝑎𝑙𝑢𝑒=𝑃(𝑅𝑒𝑗𝑒𝑐𝑡 𝐻0|𝐻0 𝑖𝑠 𝑇𝑟𝑢𝑒)
# $$
#
# ![slide5-image1](data:image/png;base64,...)
# ![slide5-image2](data:image/png;base64,...)
# ![slide5-image3](data:image/png;base64,...)
# ![slide5-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 6: (Untitled)
#
# - 1
# - 가설 검정
# - p-value 의 계산
# - 전제
# - OO 우유 용량은 정규분포를 따른다.
# - OO 우유의 용량의 분산은 4 이다.
# - 표본은 서로 독립
# - 수집된 우유의 용량
# - 205, 202, 195, 193, 197, 201, 197, 199
# - Ex) OO 우유 200ml 의 용량이 200ml 가 아니라, 그보다 작다.
# - H 0:
# - H 1:
# - ‘귀무 가설이 맞다’라는 가정에서,
# - 𝝁=𝟐𝟎𝟎, 𝑿 ~ 𝑵(𝟐𝟎𝟎, 𝟒)
# - 확률변수 X: 전제 에서,
# - 𝑿 ~ 𝑵(𝝁, 𝟒)
#
# **Equation 6.1**
# $$
# 𝝁=𝟐𝟎𝟎
# $$
#
# **Equation 6.2**
# $$
# 𝝁<𝟐𝟎𝟎
# $$
#
# ![slide6-image1](data:image/png;base64,...)
# ![slide6-image2](data:image/png;base64,...)
# ![slide6-image3](data:image/png;base64,...)

# %% [markdown]
# ### Slide 7: (Untitled)
#
# - 1
# - 가설 검정
# - p-value 의 계산
# - 표본 평균의 모평균 = 모평균
# - 표본 평균의 모분산 = 모분산/표본수
# - 평균으로 대표값 을 만들어,
# - 검정 결과를 보다 쉽게 유도
# - H 0:
# - H 1:
# - 관측된 표본 평균
# - 수집된 우유의 용량
# - 205, 202, 195, 193, 197, 201, 197, 199
#
# **Equation 7.1**
# $$
# 𝝁=𝟐𝟎𝟎
# $$
#
# **Equation 7.2**
# $$
# 𝝁<𝟐𝟎𝟎
# $$
#
# **Equation 7.3**
# $$
# 𝑿 ~ 𝑵(𝟐𝟎𝟎, 𝟒)
# $$
#
# **Equation 7.4**
# $$
# =205+202+195+193+197+201+197+1998=198.625
# $$
#
# **Equation 7.5**
# $$
# 𝑿 ~ 𝑵(𝟐𝟎𝟎,𝟒𝟖)
# $$
#
# **Equation 7.6**
# $$
# 𝑿 ~ 𝑵(𝟐𝟎𝟎, 𝟒)
# $$
#
# **Equation 7.7**
# $$
# 𝑿 ~ 𝑵(𝟐𝟎𝟎,𝟒𝟖)
# $$
#
# ![slide7-image1](data:image/png;base64,...)
# ![slide7-image2](data:image/png;base64,...)
# ![slide7-image3](data:image/png;base64,...)
# ![slide7-image4](data:image/png;base64,...)
# ![slide7-image5](data:image/png;base64,...)
# ![slide7-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 8: (Untitled)
#
# - 1
# - 가설 검정
# - p-value 의 계산
# - 대립 가설을 지지하는 영역
# - 증거보다 작은 값의 해당 영역
# - 분포상 좌측 꼬리
# - 증거: 표본 평균
# - p-value: 0.0259
# - H 0:
# - H 1:
# - 주어진 통계량에서 귀무 가설을 기각하는 것은 그보다 대립 가설에 더 유리한 통계량 또한 기각한다는 것
# - 분포상 통계량보다 대립 가설을 지지하는 영역의 확률이 바로 p-value
#
# **Equation 8.1**
# $$
# 𝑵(𝟐𝟎𝟎,𝟒𝟖)
# $$
#
# **Equation 8.2**
# $$
# 𝜇=200
# $$
#
# **Equation 8.3**
# $$
# 𝜇<200
# $$
#
# **Equation 8.4**
# $$
# 𝑵(𝟐𝟎𝟎,𝟒𝟖)
# $$
#
# ![slide8-image1](data:image/png;base64,...)
# ![slide8-image2](data:image/png;base64,...)
# ![slide8-image3](data:image/png;base64,...)
# ![slide8-image4](data:image/png;base64,...)
# ![slide8-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 9: (Untitled)
#
# - 1
# - 가설 검정
# - 검정 통계량
# - 판단의 근거 자료로 사용
# - 가설 검정을 위해 표본에서 구한 통계 수치
# - 표준 정규 분포 (N(0, 1))을 사용한다면
# - =-1.9445
# - 수집된 우유의 용량
# - 205, 202, 195, 193, 197, 201, 197, 199
# - 관측된 표본 평균
#
# **Equation 9.1**
# $$
# 𝑋 ~ 𝑁200,48
# $$
#
# **Equation 9.2**
# $$
# 𝑍=198.625 −2000.5
# $$
#
# **Equation 9.3**
# $$
# 𝐇𝟎: 𝜇=200
# $$
#
# **Equation 9.4**
# $$
# 𝐇𝟏: 𝜇<200
# $$
#
# **Equation 9.5**
# $$
# =205+202+195+193+197+201+197+1998=198.625
# $$
#
# **Equation 9.6**
# $$
# 𝑋 ~ 𝑁200,48
# $$
#
# **Equation 9.7**
# $$
# 𝐇𝟎: 𝜇=200
# $$
#
# **Equation 9.8**
# $$
# 𝐇𝟏: 𝜇<200
# $$
#
# ![slide9-image1](data:image/png;base64,...)
# ![slide9-image2](data:image/png;base64,...)
# ![slide9-image3](data:image/png;base64,...)
# ![slide9-image4](data:image/png;base64,...)
# ![slide9-image5](data:image/png;base64,...)
# ![slide9-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 10: (Untitled)
#
# - 1
# - 가설 검정
# - 유의 수준(Significance Level)
# - 보통 5% 기준
# - p-value ≥ 유의 수준 → 귀무 가설 채택
# - p-value < 유의 수준 → 대립 가설 채택
# - 귀무 가설 채택과 기각의 기준점
# - 귀무 가설을 기각했을 때의 위험성에 따라 높이거나 낮춤
#
# ![slide10-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 11: (Untitled)
#
# - 1
# - 가설 검정
# - 기각역
# - p-value 가 5%인
# - 기각역의 경계점
# - 유의 수준을 기준으로, 검정 통계량의 분포를 이용해 계산
# - 귀무 가설이 기각되는 검정 통계량의 영역
# - 8 개 표본의 표본 평균이 검정 통계량
# - 유의 수준: 5%
#
# **Equation 11.1**
# $$
# 𝑋 ~ 𝑁200,48
# $$
#
# **Equation 11.2**
# $$
# 𝐇𝟎: 𝜇=200
# $$
#
# **Equation 11.3**
# $$
# 𝐇𝟏: 𝜇<200
# $$
#
# **Equation 11.4**
# $$
# 𝑵(𝟐𝟎𝟎,𝟒𝟖)
# $$
#
# **Equation 11.5**
# $$
# 𝑋 ~ 𝑁200,48
# $$
#
# **Equation 11.6**
# $$
# 𝐇𝟎: 𝜇=200
# $$
#
# **Equation 11.7**
# $$
# 𝐇𝟏: 𝜇<200
# $$
#
# ![slide11-image1](data:image/png;base64,...)
# ![slide11-image2](data:image/png;base64,...)
# ![slide11-image3](data:image/png;base64,...)
# ![slide11-image4](data:image/png;base64,...)
# ![slide11-image5](data:image/png;base64,...)
# ![slide11-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 12: (Untitled)
#
# - 1
# - 가설 검정
# - 가설 검정의 과정 I
# - ② 유의 수준 설정
# - ③ 검정 방법 선정
# - ④ 검정 통계량 계산
# - ⑤ p-value 계산
# - ⑥ 결론
# - ① H 0 과 H 1 을 설정
# - 수집된 우유의 용량
# - 205, 202, 195, 193, 197, 201, 197, 199
# - 유의 수준: 5%
# - p-value = 0.02591
# - Ex) OO 우유 200ml 의 용량이 200ml 가 아니라, 그보다 작다.
#
# **Equation 12.1**
# $$
# 𝑋 ~ 𝑁200,48
# $$
#
# **Equation 12.2**
# $$
# 𝐇𝟎: 𝜇=200
# $$
#
# **Equation 12.3**
# $$
# 𝐇𝟏: 𝜇<200
# $$
#
# **Equation 12.4**
# $$
# 𝑋 ~ 𝑁200,48
# $$
#
# **Equation 12.5**
# $$
# 𝐇𝟎: 𝜇=200
# $$
#
# **Equation 12.6**
# $$
# 𝐇𝟏: 𝜇<200
# $$
#
# ![slide12-image1](data:image/png;base64,...)
# ![slide12-image2](data:image/png;base64,...)
# ![slide12-image3](data:image/png;base64,...)
# ![slide12-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 13: (Untitled)
#
# - 유의 수준: 5%
# - Ex) OO 우유 200ml 의 용량이 200ml 가 아니라, 그보다 작다.
# - 1
# - 가설 검정
# - 가설 검정의 과정 II
# - ② 유의 수준 설정
# - ③ 검정 방법 선정
# - ④ 기각역 계산
# - ⑤ 검정 통계량 계산
# - ⑥ 결론
# - ① H 0 과 H 1 을 설정
# - 8 개 표본의 표본 평균이 검정 통계량
# - 누적분포함수의 역함수
#
# **Equation 13.1**
# $$
# 𝐇𝟎: 𝜇=200
# $$
#
# **Equation 13.2**
# $$
# 𝐇𝟏: 𝜇<200
# $$
#
# **Equation 13.3**
# $$
# 𝑭−𝟏𝟎.𝟎𝟓;𝟐𝟎𝟎,𝟒𝟖
# $$
#
# **Equation 13.4**
# $$
# 𝑋 ~ 𝑁200,48
# $$
#
# **Equation 13.5**
# $$
# 𝑭−𝟏𝒙;𝟐𝟎𝟎,𝟒𝟖 : 𝑵𝟐𝟎𝟎,𝟒𝟖
# $$
#
# **Equation 13.6**
# $$
# 𝐇𝟎: 𝜇=200
# $$
#
# **Equation 13.7**
# $$
# 𝐇𝟏: 𝜇<200
# $$
#
# **Equation 13.8**
# $$
# 𝑭−𝟏𝟎.𝟎𝟓;𝟐𝟎𝟎,𝟒𝟖
# $$
#
# **Equation 13.9**
# $$
# 𝑋 ~ 𝑁200,48
# $$
#
# ![slide13-image1](data:image/png;base64,...)
# ![slide13-image2](data:image/png;base64,...)
# ![slide13-image3](data:image/png;base64,...)
# ![slide13-image4](data:image/png;base64,...)
# ![slide13-image5](data:image/png;base64,...)
# ![slide13-image6](data:image/png;base64,...)
# ![slide13-image7](data:image/png;base64,...)

# %% [markdown]
# ### Slide 14: (Untitled)
#
# - 2
# - 대립 가설의 종류
# - 검정 종류
# - 양측 꼬리 검정
# - Two-sided
# - 좌측 꼬리 검정
# - Left-sided
# - 우측 꼬리 검정
# - Right-sided
# - 기각역
# - 검정 종류
# - 양측 꼬리 검정
# - Two-sided
# - 좌측 꼬리 검정
# - Left-sided
# - 우측 꼬리 검정
# - Right-sided
# - 기각역
# - H 0: /
#
# **Table 14.1**
# |   |   |   |   |
# | --- | --- | --- | --- |
# | 검정 종류 | 양측 꼬리 검정
# Two-sided | 좌측 꼬리 검정
# Left-sided | 우측 꼬리 검정
# Right-sided |
# | 기각역 |   |   |   |
#
# **Table 14.2**
# |   |   |   |   |
# | --- | --- | --- | --- |
# | 검정 종류 | 양측 꼬리 검정
# Two-sided | 좌측 꼬리 검정
# Left-sided | 우측 꼬리 검정
# Right-sided |
# | 기각역 |   |   |   |
#
# **Equation 14.1**
# $$
# 𝑯𝟏: 𝜽≠𝜽𝟎
# $$
#
# **Equation 14.2**
# $$
# 𝑯𝟏: 𝜽𝟏≠𝜽𝟐
# $$
#
# **Equation 14.3**
# $$
# 𝑯𝟏: 𝜽<𝜽𝟎
# $$
#
# **Equation 14.4**
# $$
# 𝑯𝟏: 𝜽𝟏<𝜽𝟐
# $$
#
# **Equation 14.5**
# $$
# 𝑯𝟏:𝜽>𝜽𝟎
# $$
#
# **Equation 14.6**
# $$
# 𝑯𝟏: 𝜽𝟏>𝜽𝟐
# $$
#
# **Equation 14.7**
# $$
# 𝜽=𝜽𝟎
# $$
#
# **Equation 14.8**
# $$
# 𝜽𝟏=𝜽𝟐
# $$
#
# **Equation 14.9**
# $$
# 𝑯𝟏: 𝜽𝟏<𝜽𝟐
# $$
#
# **Equation 14.10**
# $$
# 𝑯𝟏: 𝜽𝟏>𝜽𝟐
# $$
#
# ![slide14-image1](data:image/png;base64,...)
# ![slide14-image2](data:image/png;base64,...)
# ![slide14-image3](data:image/png;base64,...)
# ![slide14-image4](data:image/png;base64,...)
# ![slide14-image5](data:image/png;base64,...)
# ![slide14-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 15: (Untitled)
#
# - 대칭 분포에서의 양측 꼬리 검정
# - 2
# - 대립 가설의 종류
# - 분포상 중앙을 기준으로 반대쪽에 동일 크기의 대립 가설을 지지하는 영역 형성
# - 𝑝−𝑣𝑎𝑙𝑢𝑒=한쪽 꼬리 면적×2
# - 표준 정규 분포나 t-분포와 같이, 0 을 기준으로 대칭인 분포는 통계량의 절대값에 음수를 취함
# - 𝑝−𝑣𝑎𝑙𝑢𝑒=𝑃(𝑋<−|통계량|)×2
#
# ![slide15-image1](data:image/png;base64,...)
# ![slide15-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 16: (Untitled)
#
# - 반대쪽에 해당하는 통계량을 구할 수가 없어, 아래와 같이 어림잡아 구함
# - 𝑝−𝑣𝑎𝑙𝑢𝑒≈min(𝑃(𝑋<|통계량|),𝑃(𝑋>|통계량|))×2
# - 비대칭 분포에서의 양측 꼬리 검정
# - 2
# - 대립 가설의 종류
#
# ![slide16-image1](data:image/png;base64,...)
# ![slide16-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 17: (Untitled)
#
# - 모분산()을 알고 있을 경우
# - 모집단이 정규 분포 를 따르거나
# - 중심극한정리(Central Limit Theorem)를 따를 만큼 표본수가 충분할 때
# - 3
# - 모평균 검정: 단일 모집단
# - 검정 통계량:
# - 표본 평균
#
# **Equation 17.1**
# $$
# 𝜎2
# $$
#
# **Equation 17.2**
# $$
# 𝑯𝟎:𝝁=𝝁𝟎
# $$
#
# **Equation 17.3**
# $$
# ~𝑁𝜇0,𝜎2𝑛
# $$
#
# **Equation 17.4**
# $$
# 𝒁=𝑿−𝝁𝟎𝝈𝒏
# $$
#
# **Equation 17.5**
# $$
# 𝑯𝟎:𝝁=𝝁𝟎
# $$
#
# **Equation 17.6**
# $$
# ~𝑁𝜇0,𝜎2𝑛
# $$
#
# ![slide17-image1](data:image/png;base64,...)
# ![slide17-image2](data:image/png;base64,...)
# ![slide17-image3](data:image/png;base64,...)
# ![slide17-image4](data:image/png;base64,...)
# ![slide17-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 18: (Untitled)
#
# - 모분산()을 모를 경우
# - 모집단이 정규 분포 를 따른다면,
# - 3
# - 모평균 검정: 단일 모집단
# - 검정 통계량:
#
# **Equation 18.1**
# $$
# 𝜎2
# $$
#
# **Equation 18.2**
# $$
# 𝑯𝟎:𝝁=𝝁𝟎
# $$
#
# **Equation 18.3**
# $$
# 𝑡~𝑡(𝑛−1)
# $$
#
# **Equation 18.4**
# $$
# 𝑡=𝑋−𝜇0 𝑆𝑛
# $$
#
# **Equation 18.5**
# $$
# 𝑯𝟎:𝝁=𝝁𝟎
# $$
#
# **Equation 18.6**
# $$
# 𝑡~𝑡(𝑛−1)
# $$
#
# ![slide18-image1](data:image/png;base64,...)
# ![slide18-image2](data:image/png;base64,...)
# ![slide18-image3](data:image/png;base64,...)
# ![slide18-image4](data:image/png;base64,...)
# ![slide18-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 19: (Untitled)
#
# - 모분산()를 알고 있을 경우
# - 두 표본이 독립 이고, 모집단이 정규 분포 를 따른다면,
# - 검정 통계량
# - 4
# - 모평균 검정: 두 개의 모집단
#
# **Equation 19.1**
# $$
# 𝜎12,𝜎22
# $$
#
# **Equation 19.2**
# $$
# 𝑍=𝑋1−𝑋2𝜎12𝑛1+𝜎22𝑛2
# $$
#
# **Equation 19.3**
# $$
# 𝑯𝟎:𝝁𝟏=𝝁𝟐
# $$
#
# **Equation 19.4**
# $$
# 𝑍=𝑋1−𝑋2𝜎12𝑛1+𝜎22𝑛2
# $$
#
# **Equation 19.5**
# $$
# 𝑯𝟎:𝝁𝟏=𝝁𝟐
# $$
#
# ![slide19-image1](data:image/png;base64,...)
# ![slide19-image2](data:image/png;base64,...)
# ![slide19-image3](data:image/png;base64,...)
# ![slide19-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 20: (Untitled)
#
# - 4
# - 모평균 검정: 두 개의 모집단
# - 모분산()를 모를 경우
# - 두 표본이 독립 이고, 두 모집단이 정규 분포 를 따른다면,
# - 두 모집단이 등분산
# - 두 모집단이 이분산
# - 검정 통계량
# - 자유도
# - 두 모집단이 등분산
# - 두 모집단이 이분산
# - 검정 통계량
# - 자유도
#
# **Table 20.1**
# |   | 두 모집단이 등분산 | 두 모집단이 이분산 |
# | --- | --- | --- |
# | 검정 통계량 |   |   |
# | 자유도 |   |   |
#
# **Table 20.2**
# |   | 두 모집단이 등분산 | 두 모집단이 이분산 |
# | --- | --- | --- |
# | 검정 통계량 |   |   |
# | 자유도 |   |   |
#
# **Equation 20.1**
# $$
# 𝑯𝟎:𝝁𝟏=𝝁𝟐
# $$
#
# **Equation 20.2**
# $$
# 𝜎12,𝜎22
# $$
#
# **Equation 20.3**
# $$
# 𝑡=𝑋1−𝑋2𝑠12𝑛1+𝑠22𝑛2
# $$
#
# **Equation 20.4**
# $$
# 𝑛1+𝑛2−2
# $$
#
# **Equation 20.5**
# $$
# 𝑠12𝑛1+𝑠22𝑛22𝑠12/𝑛12𝑛1−1+𝑠22/𝑛22𝑛2−1
# $$
#
# **Equation 20.6**
# $$
# 𝑡=𝑋1−𝑋2𝑆𝑝21𝑛1+1𝑛2
# $$
#
# **Equation 20.7**
# $$
# 𝑆𝑝2=𝑛1−1𝑠12+𝑛2−1𝑠22𝑛1+𝑛2−2
# $$
#
# **Equation 20.8**
# $$
# 𝑯𝟎:𝝁𝟏=𝝁𝟐
# $$
#
# **Equation 20.9**
# $$
# 𝑡=𝑋1−𝑋2𝑠12𝑛1+𝑠22𝑛2
# $$
#
# **Equation 20.10**
# $$
# 𝑛1+𝑛2−2
# $$
#
# **Equation 20.11**
# $$
# 𝑠12𝑛1+𝑠22𝑛22𝑠12/𝑛12𝑛1−1+𝑠22/𝑛22𝑛2−1
# $$
#
# **Equation 20.12**
# $$
# 𝑡=𝑋1−𝑋2𝑆𝑝21𝑛1+1𝑛2
# $$
#
# **Equation 20.13**
# $$
# 𝑆𝑝2=𝑛1−1𝑠12+𝑛2−1𝑠22𝑛1+𝑛2−2
# $$
#
# ![slide20-image1](data:image/png;base64,...)
# ![slide20-image2](data:image/png;base64,...)
# ![slide20-image3](data:image/png;base64,...)
# ![slide20-image4](data:image/png;base64,...)
# ![slide20-image5](data:image/png;base64,...)
# ![slide20-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 21: (Untitled)
#
# - 5
# - 모평균 검정: 대응 관계인 두 개의 모집단
# - 검정 통계량
# - D 의 모집단이 정규 분포 를 따른다면,
#
# **Equation 21.1**
# $$
# 𝑯𝟎:𝝁𝟏=𝝁𝟏′
# $$
#
# **Equation 21.2**
# $$
# 𝑡=𝐷𝑆𝑑𝑛~𝑡(𝑛−1)
# $$
#
# **Equation 21.3**
# $$
# 𝐷=𝑋1−𝑋1′
# $$
#
# **Equation 21.4**
# $$
# 𝑯𝟎:𝝁𝟏=𝝁𝟏′
# $$
#
# **Equation 21.5**
# $$
# 𝑡=𝐷𝑆𝑑𝑛~𝑡(𝑛−1)
# $$
#
# **Equation 21.6**
# $$
# 𝐷=𝑋1−𝑋1′
# $$
#
# ![slide21-image1](data:image/png;base64,...)
# ![slide21-image2](data:image/png;base64,...)
# ![slide21-image3](data:image/png;base64,...)
# ![slide21-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 22: (Untitled)
#
# - 6
# - 모비율 검정: 단일 모집단
# - Positive(Success)의 수, n: 표본수
# - 표본수가 충분하여, 𝑝 ̂가 중심극한정리에 의해 정규분포를 따른다고 할 수 있을 때
# - 검정통계량
#
# **Equation 22.1**
# $$
# 𝑯𝟎:𝒑=𝒑𝟎
# $$
#
# **Equation 22.2**
# $$
# 𝑝=𝑥𝑛, 𝑥:
# $$
#
# **Equation 22.3**
# $$
# 𝑍=𝑝−𝑝0𝑝0(1−𝑝0)𝑛
# $$
#
# **Equation 22.4**
# $$
# 𝑯𝟎:𝒑=𝒑𝟎
# $$
#
# ![slide22-image1](data:image/png;base64,...)
# ![slide22-image2](data:image/png;base64,...)
# ![slide22-image3](data:image/png;base64,...)
# ![slide22-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 23: (Untitled)
#
# - 7
# - 모분산 검정: 단일 모집단
# - 검정 통계량
# - 모집단이 정규 분포 를 따를 경우
#
# **Equation 23.1**
# $$
# 𝑯𝟎:𝝈𝟐= 𝝈𝟎𝟐
# $$
#
# **Equation 23.2**
# $$
# 𝜒2=𝑛−1𝑆2𝜎02~𝜒(𝑛−1)
# $$
#
# **Equation 23.3**
# $$
# 𝑯𝟎:𝝈𝟐= 𝝈𝟎𝟐
# $$
#
# ![slide23-image1](data:image/png;base64,...)
# ![slide23-image2](data:image/png;base64,...)
# ![slide23-image3](data:image/png;base64,...)

# %% [markdown]
# ### Slide 24: (Untitled)
#
# - 두 모집단이 정규 분포 를 따를 경우
# - 8
# - 모분산 검정: 두 개의 모집단
# - 검정통계량
#
# **Equation 24.1**
# $$
# 𝑯𝟎:𝝈𝟏𝟐= 𝝈𝟐𝟐
# $$
#
# **Equation 24.2**
# $$
# 𝑑1=𝑛1−1, 𝑑2=𝑛2−1
# $$
#
# **Equation 24.3**
# $$
# 𝐹=𝑆12𝑆22~𝐹(𝑑1,𝑑2)
# $$
#
# **Equation 24.4**
# $$
# 𝑯𝟎:𝝈𝟏𝟐= 𝝈𝟐𝟐
# $$
#
# **Equation 24.5**
# $$
# 𝑑1=𝑛1−1, 𝑑2=𝑛2−1
# $$
#
# ![slide24-image1](data:image/png;base64,...)
# ![slide24-image2](data:image/png;base64,...)
# ![slide24-image3](data:image/png;base64,...)
# ![slide24-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 25: (Untitled)
#
# - 문제 풀이
# - 9
# - Type II 오류는 귀무 가설이 틀렸음에도 채택한 것을 의미한다.
# - 1
# - p-value 는 Type I 오류일 확률이다.
# - 2
# - 귀무 가설(Null Hypothesis, H0)은 연구자가 새롭게 입증하고자 하는 가설을 의미한다.
# - 3
# - 귀무 가설을 기각하게 되는 검정 통계량의 범위를 기각역(Critical Region)이라고 한다.
# - 4
# - Q1. 다음 설명 중 틀린 것은?

# %% [markdown]
# ### Slide 26: (Untitled)
#
# - 문제 풀이
# - 9
# - Type II 오류는 귀무 가설이 틀렸음에도 채택한 것을 의미한다.
# - 1
# - p-value 는 Type I 오류일 확률이다.
# - 2
# - 귀무 가설(Null Hypothesis, H0)은 연구자가 새롭게 입증하고자 하는 가설을 의미한다.
# - 3
# - 귀무 가설을 기각하게 되는 검정 통계량의 범위를 기각역(Critical Region)이라고 한다.
# - 4
# - Q1. 다음 설명 중 틀린 것은?
# - 3)은 대립 가설(Alternative Hypothesis, H1)에 대한 내용입니다.
#
# ![slide26-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 27: (Untitled)
#
# - 문제 풀이
# - 9
# - 모집단이 정규 분포를 따르고 모분산을 모를 때,
# - 모평균에 대한 검정
# - 1
# - 두 모집단이 정규 분포를 따르고 등분산일 때,
# - 두 모평균에 대한 검정
# - 2
# - 모집단이 정규 분포를 따를 때,
# - 모분산에 대한 검정
# - 3
# - 표본수가 충분할 때의 모비율에 대한 검정
# - 4
# - Q2. 모수에 대한 가설 검정의 검정 통계량과 분포를 잘못 제시한 것은?
#
# **Equation 27.1**
# $$
# 𝑋−𝜇0 𝑆2𝑛~𝑡(𝑛−1)
# $$
#
# **Equation 27.2**
# $$
# 𝑆𝑝2=𝑛1−1𝑠12+𝑛2−1𝑠22𝑛1+𝑛2−2
# $$
#
# **Equation 27.3**
# $$
# 𝑋−𝜇 𝑆𝑝21𝑛1+1𝑛2~𝑡(𝑛1+𝑛2−2)
# $$
#
# **Equation 27.4**
# $$
# 𝑛−1𝑆2𝜎02~𝜒(𝑛−1)
# $$
#
# **Equation 27.5**
# $$
# 𝑋−𝑝0 𝑝01−𝑝0𝑛~𝑡(𝑛−1)
# $$
#
# **Equation 27.6**
# $$
# 𝑆𝑝2=𝑛1−1𝑠12+𝑛2−1𝑠22𝑛1+𝑛2−2
# $$
#
# ![slide27-image1](data:image/png;base64,...)
# ![slide27-image2](data:image/png;base64,...)
# ![slide27-image3](data:image/png;base64,...)
# ![slide27-image4](data:image/png;base64,...)
# ![slide27-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 28: (Untitled)
#
# - 문제 풀이
# - 9
# - 4
# - Q2. 모수에 대한 가설 검정의 검정 통계량과 분포를 잘못 제시한 것은?
# - 모집단이 정규 분포를 따르고 모분산을 모를 때,
# - 모평균에 대한 검정
# - 1
# - 두 모집단이 정규 분포를 따르고 등분산일 때,
# - 두 모평균에 대한 검정
# - 2
# - 모집단이 정규 분포를 따를 때,
# - 모분산에 대한 검정
# - 3
# - 표본수가 충분할 때의 모비율에 대한 검정
#
# **Equation 28.1**
# $$
# 𝑿−𝑝0 𝒑𝟎𝟏−𝒑𝟎𝒏~𝑵(𝟎, 𝟏𝟐)
# $$
#
# **Equation 28.2**
# $$
# 𝑋−𝜇0 𝑆2𝑛~𝑡(𝑛−1)
# $$
#
# **Equation 28.3**
# $$
# 𝑆𝑝2=𝑛1−1𝑠12+𝑛2−1𝑠22𝑛1+𝑛2−2
# $$
#
# **Equation 28.4**
# $$
# 𝑋−𝜇 𝑆𝑝21𝑛1+1𝑛2~𝑡(𝑛1+𝑛2−2)
# $$
#
# **Equation 28.5**
# $$
# 𝑛−1𝑆2𝜎02~𝜒(𝑛−1)
# $$
#
# **Equation 28.6**
# $$
# 𝑋−𝑝0 𝑝01−𝑝0𝑛~𝑡(𝑛−1)
# $$
#
# **Equation 28.7**
# $$
# 𝑿−𝑝0 𝒑𝟎𝟏−𝒑𝟎𝒏~𝑵(𝟎, 𝟏𝟐)
# $$
#
# **Equation 28.8**
# $$
# 𝑆𝑝2=𝑛1−1𝑠12+𝑛2−1𝑠22𝑛1+𝑛2−2
# $$
#
# ![slide28-image1](data:image/png;base64,...)
# ![slide28-image2](data:image/png;base64,...)
# ![slide28-image3](data:image/png;base64,...)
# ![slide28-image4](data:image/png;base64,...)
# ![slide28-image5](data:image/png;base64,...)
# ![slide28-image6](data:image/png;base64,...)
# ![slide28-image7](data:image/png;base64,...)

# %% [markdown]
# ### Slide 29: (Untitled)
#
# - 의 누적분포함수의 역함수
# - 문제 풀이
# - 9
# - Q3. 어느 맥주 공장은 한 통에서 생산되는 맥주의 알코올 도수 평균을 5%로 유지하고 있다.
# - 이보다 크거나 작으면 품질 검사에서 떨어진다. 품질 검사에선 총 10 번의 표본을 채취하고,
# - 채취할 때마다 통을 잘 흔들어 측정치 간에 연관이 없게 한다. 유의 수준을 5%로 할 때,
# - 품질검사에서 떨어지게 되는 표본 평균의 구간은?
# - or
# - 1
# - or
# - 2
# - or
# - 3
# - 4
# - or
#
# **Equation 29.1**
# $$
# 𝑭−𝟏𝒙;𝝂 : 𝒕(𝝂)
# $$
#
# **Equation 29.2**
# $$
# 𝑋<5.0−𝑆9𝐹−10.95, 9
# $$
#
# **Equation 29.3**
# $$
# 𝑋>5.0+𝑆9𝐹−10.95, 9
# $$
#
# **Equation 29.4**
# $$
# 𝑋<5.0−𝑆10𝐹−10.95, 10
# $$
#
# **Equation 29.5**
# $$
# 𝑋>5.0+𝑆10𝐹−10.95, 10
# $$
#
# **Equation 29.6**
# $$
# 𝑋<5.0−𝑆9𝐹−10.975, 10
# $$
#
# **Equation 29.7**
# $$
# 𝑋>5.0+𝑆9𝐹−10.975, 10
# $$
#
# **Equation 29.8**
# $$
# 𝑋<5.0−𝑆10𝐹−10.975, 9
# $$
#
# **Equation 29.9**
# $$
# 𝑋>5.0+𝑆10𝐹−10.975, 9
# $$
#
# ![slide29-image1](data:image/png;base64,...)
# ![slide29-image2](data:image/png;base64,...)
# ![slide29-image3](data:image/png;base64,...)
# ![slide29-image4](data:image/png;base64,...)
# ![slide29-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 30: (Untitled)
#
# - or
# - 1
# - or
# - 2
# - or
# - 3
# - 4
# - or
# - Q3. 어느 맥주 공장은 한 통에서 생산되는 맥주의 알코올 도수 평균을 5%로 유지하고 있다.
# - 이보다 크거나 작으면 품질 검사에서 떨어진다. 품질 검사에선 총 10 번의 표본을 채취하고,
# - 채취할 때마다 통을 잘 흔들어 측정치 간에 연관이 없게 한다. 유의 수준을 5%로 할 때,
# - 품질검사에서 떨어지게 되는 표본 평균의 구간은?
# - 문제 풀이
# - 9
# - 는 자유도가 9 인 t-분포를 따릅니다. 양측 꼬리에 동일한 크기의 구간이 생기므로, 0.975 에 해당하는 지점을 구해야 합니다.
# - 의 누적분포함수의 역함수
#
# **Equation 30.1**
# $$
# 𝑋<5.0−𝑆9𝐹−10.95, 9
# $$
#
# **Equation 30.2**
# $$
# 𝑋>5.0+𝑆9𝐹−10.95, 9
# $$
#
# **Equation 30.3**
# $$
# 𝑋<5.0−𝑆10𝐹−10.95, 10
# $$
#
# **Equation 30.4**
# $$
# 𝑋>5.0+𝑆10𝐹−10.95, 10
# $$
#
# **Equation 30.5**
# $$
# 𝑋<5.0−𝑆9𝐹−10.975, 10
# $$
#
# **Equation 30.6**
# $$
# 𝑋>5.0+𝑆9𝐹−10.975, 10
# $$
#
# **Equation 30.7**
# $$
# 𝑋<5.0−𝑆10𝐹−10.975, 9
# $$
#
# **Equation 30.8**
# $$
# 𝑋>5.0+𝑆10𝐹−10.975, 9
# $$
#
# **Equation 30.9**
# $$
# 𝑡=𝑋−5 𝑠/10
# $$
#
# **Equation 30.10**
# $$
# 𝑭−𝟏𝒙;𝝂 : 𝒕(𝝂)
# $$
#
# ![slide30-image1](data:image/png;base64,...)
# ![slide30-image2](data:image/png;base64,...)
# ![slide30-image3](data:image/png;base64,...)
# ![slide30-image4](data:image/png;base64,...)
# ![slide30-image5](data:image/png;base64,...)
# ![slide30-image6](data:image/png;base64,...)
# ![slide30-image7](data:image/png;base64,...)

# %% [markdown]
# ### Slide 31: (Untitled)
#
# - # 귀무가설, 대립가설
# - # p-value, 기각역
# # 양측 꼬리, 좌측 꼬리, 우측꼬리
# - # 모평균, 모비율, 모분산 검정
# - 추후 디자인하여 PSD 로 편집될 영역입니다.
