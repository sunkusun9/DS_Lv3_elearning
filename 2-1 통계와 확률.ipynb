# %% [markdown]
# # PPT → Markdown (v3: Better Text Joining + Tables + Equations)
#
# **Source**: `[4차시] LV3_2-1 통계와 확률_0825_수정.pptx`
#
# 개선 사항:
# - **폰트/스타일로 분리된 run들을 문장 단위로 매끄럽게 연결**
# - 줄바꿈(br) 보존, 불필요한 공백 정리, 소프트 하이픈 제거
# - bullet(기본) 감지 후 접두사 적용
# - 기존 이미지/테이블/수식/헤더 로직 그대로 유지

# %% [markdown]
# ### Slide 1: (Untitled)
#
# - 04. 통계와 확률

# %% [markdown]
# ### Slide 2: (Untitled)
#
# - 데이터를 수집, 정리, 분석, 해석하여 결론을 도출하는 학문
# - 1
# - 통계
# - 통계
# - 분류
# - 기술 통계(Descriptive Statistics): 데이터를 요약하고 정리
# - 추론 통계(Inferential Statistics): 일부의 데이터로 전체에 대한 결론을 추론
#
# ![slide2-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 3: (Untitled)
#
# - 표본(Sample): 모집단의 성질을 추측하기 위한 모집단의 일부
# - 통계 분석의 과정
# - 1
# - 통계
# - 모집단과 표본
# - 분석
# - 모집단
# - 통계 분석 방법을 적용할 관심 대상의 전체 집합
# - 표본 추출
# - (Sampling)
# - 조사
# - 표본
# - 직접적인
# 조사 대상이 된
# 모집단의 일부
# - 모집단(Population): 정보를 얻고자 하는 관심 대상의 전체 집합
#
# ![slide3-image1](data:image/jpeg;base64,...)
# ![slide3-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 4: (Untitled)
#
# - 2
# - 표본 추출(Sampling)
# - 표본 추출(Sampling): 모집단에서 표본을 선택하는 과정
# - 표본 추출 오차(Sampling Bias, Sampling Error)
# - 과잉 대표: 반복과 중복된 데이터에 의해 모집단의 성질 왜곡
# - 최소 대표: 대표성이 떨어지는 데이터에 의해 모집단의 성질 왜곡
#
# ![slide4-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 5: (Untitled)
#
# - 단순 무작위 추출
# - (Simple Random Sampling)
# - 계통 추출
# - (Systematic Sampling)
# - 층화 추출
# - (Stratified Sampling)
# - 집락 추출
# - (Cluster Sampling)
# - 특징
# - 모든 구성원을 동일한 확률로 선택
# - 모집단에 사전 지식이 많지 않을 경우 선호
# - 일정 간격으로 추출
# - 모집단을 층(Strata)으로 나눔
# - 층별 무작위 추출
# - 모집단을 집단(Cluster)으로 나눔
# - 클러스터 단위로 표본을 선택
# - 모집단의 구체적 특징을 알기 어려울 때 사용
# - 장점
# - 공정하고 편향이 없음
# - 간편하고 실행이 쉬움
# - 대표성이 높음
# - 비용 효율적
# - 현장 조사에 유리
# - 단점
# - 모집단 전체 목록 필요
# - 소규모 집단에서는 대표성 부족
# - 주기성이 있을 경우 편향이 발생
# - 제대로 층을 정의하지 않으면 효과 저하
# - 표본의 대표성이 떨어질 수 있음
# - 표본의 크기가 같을 경우 단순 임의 추출보다 표본 오차가 클 수 있음
# - 2
# - 표본 추출(Sampling)
# - 확률 표본 추출법
#
# **Table 5.1**
# |   | 단순 무작위 추출
# (Simple Random Sampling) | 계통 추출
# (Systematic Sampling) | 층화 추출
# (Stratified Sampling) | 집락 추출
# (Cluster Sampling) |
# | --- | --- | --- | --- | --- |
# | 특징 | 모든 구성원을 동일한 확률로 선택
# 모집단에 사전 지식이 많지 않을 경우 선호 | 일정 간격으로 추출 | 모집단을 층(Strata)으로 나눔
# 층별 무작위 추출 | 모집단을 집단(Cluster)으로 나눔
# 클러스터 단위로 표본을 선택
# 모집단의 구체적 특징을 알기 어려울 때 사용 |
# | 장점 | 공정하고 편향이 없음 | 간편하고 실행이 쉬움 | 대표성이 높음 | 비용 효율적
# 현장 조사에 유리 |
# | 단점 | 모집단 전체 목록 필요
# 소규모 집단에서는 대표성 부족 | 주기성이 있을 경우 편향이 발생 | 제대로 층을 정의하지 않으면 효과 저하 | 표본의 대표성이 떨어질 수 있음
# 표본의 크기가 같을 경우 단순 임의 추출보다 표본 오차가 클 수 있음 |
#
# ![slide5-image1](data:image/png;base64,...)
# ![slide5-image2](data:image/png;base64,...)
# ![slide5-image3](data:image/png;base64,...)

# %% [markdown]
# ### Slide 6: (Untitled)
#
# - 비확률 표본 추출법
# - 모집단을 정확하게 규정지을 수 없는 경우
# - 표본오차가 큰 문제가 되지 않는 경우
# - 비용, 시간, 조사의 편리함 때문에 자주 사용
# - 간편 추출법
# - 자의적인 판단에 따라 추출
# - 판단 추출법
# - 조사자의 나름의 지식과 경험에 의해 모집단을 잘 대표한다고 판단되는 표본을 추출
# - 할당 추출법
# - 조사목적과 밀접하게 관련된 변수에 따라 부분집단으로 구분하고 구성 비율에 따라 추출
# - 눈덩이 추출법
# - 접근이 어렵거나 추출의 방향을 작성하기 곤란한 특정 집단에 대한 조사
# - 2
# - 표본 추출(Sampling)
# - 각 추출 대상이 표본으로 선정될 확률을 계산하지 않는 추출법
#
# **Table 6.1**
# | 간편 추출법 | 자의적인 판단에 따라 추출 |
# | --- | --- |
# | 판단 추출법 | 조사자의 나름의 지식과 경험에 의해 모집단을 잘 대표한다고 판단되는 표본을 추출 |
# | 할당 추출법 | 조사목적과 밀접하게 관련된 변수에 따라 부분집단으로 구분하고 구성 비율에 따라 추출 |
# | 눈덩이 추출법 | 접근이 어렵거나 추출의 방향을 작성하기 곤란한 특정 집단에 대한 조사 |
#
# ![slide6-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 7: (Untitled)
#
# - 중심 경향
# - (Central Tendency)
# - 집중된 위치
# - 평균, 중앙값, 최빈값
# - 산포도
# - (Measures of Dispersion)
# - 흩어진 정도
# - 분산, 표준 편차
# - 분포 형태
# - (Shape of Distribution)
# - 분포의 비대칭성, 뾰족함과 같은 분포의 경향성
# - 왜도, 첨도
# - 기술 통계
# - 3
# - 기술 통계
# - 데이터의 특징을 찾아내어 정량화
# - 데이터를 요약 하여 설명하는 통계 기법
#
# **Table 7.1**
# | 중심 경향
# (Central Tendency) | 집중된 위치 | 평균, 중앙값, 최빈값 |
# | --- | --- | --- |
# | 산포도
# (Measures of Dispersion) | 흩어진 정도 | 분산, 표준 편차 |
# | 분포 형태
# (Shape of Distribution) | 분포의 비대칭성, 뾰족함과 같은 분포의 경향성 | 왜도, 첨도 |
#
# ![slide7-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 8: (Untitled)
#
# - 산술 평균
# - (Arithmetic Mean)
# - 수치의 중간값
# - 조화 평균
# - (Harmonic Mean)
# - 효율의 중간값
# - 기하 평균
# - (Geometric Mean)
# - 비율의 중간값
# - 가중 평균
# - (Weighted Mean)
# - 비중이 다른 값의 평균
# - 절사 평균
# - (Trimmed Mean)
# - 는 정렬된 상태
# - 양끝의 극단값을 제외한 평균
# - 산술 평균
# - (Arithmetic Mean)
# - 수치의 중간값
# - 조화 평균
# - (Harmonic Mean)
# - 효율의 중간값
# - 기하 평균
# - (Geometric Mean)
# - 비율의 중간값
# - 가중 평균
# - (Weighted Mean)
# - 비중이 다른 값의 평균
# - 절사 평균
# - (Trimmed Mean)
# - 양끝의 극단값을 제외한 평균
# - 중심화 경향
# - 3
# - 기술 통계
#
# **Table 8.1**
# | 산술 평균
# (Arithmetic Mean) |   | 수치의 중간값 |
# | --- | --- | --- |
# | 조화 평균
# (Harmonic Mean) |   | 효율의 중간값 |
# | 기하 평균
# (Geometric Mean) |   | 비율의 중간값 |
# | 가중 평균
# (Weighted Mean) |   | 비중이 다른 값의 평균 |
# | 절사 평균
# (Trimmed Mean) | 는 정렬된 상태 | 양끝의 극단값을 제외한 평균 |
#
# **Table 8.2**
# | 산술 평균
# (Arithmetic Mean) |   | 수치의 중간값 |
# | --- | --- | --- |
# | 조화 평균
# (Harmonic Mean) |   | 효율의 중간값 |
# | 기하 평균
# (Geometric Mean) |   | 비율의 중간값 |
# | 가중 평균
# (Weighted Mean) |   | 비중이 다른 값의 평균 |
# | 절사 평균
# (Trimmed Mean) |   | 양끝의 극단값을 제외한 평균 |
#
# **Equation 8.1**
# $$
# 𝑥1+𝑥2+…+ 𝑥𝑛𝑛
# $$
#
# **Equation 8.2**
# $$
# 𝑛1𝑥1+1𝑥2…1𝑥𝑛
# $$
#
# **Equation 8.3**
# $$
# 𝑛𝑥1𝑥2…𝑛
# $$
#
# **Equation 8.4**
# $$
# 𝑖=1𝑛𝑤𝑖𝑥𝑖𝑖=1𝑛𝑤𝑖
# $$
#
# **Equation 8.5**
# $$
# 𝑥𝑘+𝑥2+…+ 𝑥𝑚𝑛−𝑘−𝑚, xi
# $$
#
# **Equation 8.6**
# $$
# 𝑥1+𝑥2+…+ 𝑥𝑛𝑛
# $$
#
# **Equation 8.7**
# $$
# 𝑛1𝑥1+1𝑥2…1𝑥𝑛
# $$
#
# **Equation 8.8**
# $$
# 𝑛𝑥1𝑥2…𝑛
# $$
#
# **Equation 8.9**
# $$
# 𝑖=1𝑛𝑤𝑖𝑥𝑖𝑖=1𝑛𝑤𝑖
# $$
#
# ![slide8-image1](data:image/png;base64,...)
# ![slide8-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 9: (Untitled)
#
# - 중앙값
# - (Median)
# - 순서상 중간값
# - 최빈값
# - (Mode)
# - 빈도가 가장 높은 값
# - 중앙값
# - (Median)
# - 순서상 중간값
# - 최빈값
# - (Mode)
# - 빈도가 가장 높은 값
# - 중심화 경향
# - 3
# - 기술 통계
# - 분위수: 전체를 분포상 동일한 비율로 나누었을 때의 경계값
# - 사분위수
# - (Quantile)
# - 4 등분(25% 단위)
# - Q1(25%), Q2(50%), Q3(75%)
# - 백분위수
# - (Percentile)
# - 100 등분(1% 단위)
#
# **Table 9.1**
# | 중앙값
# (Median) |   | 순서상 중간값 |
# | --- | --- | --- |
# | 최빈값
# (Mode) | 빈도가 가장 높은 값 |   |
#
# **Table 9.2**
# | 중앙값
# (Median) |   | 순서상 중간값 |
# | --- | --- | --- |
# | 최빈값
# (Mode) | 빈도가 가장 높은 값 |   |
#
# **Table 9.3**
# | 사분위수
# (Quantile) | 4 등분(25% 단위)
# Q1(25%), Q2(50%), Q3(75%) |
# | --- | --- |
# | 백분위수
# (Percentile) | 100 등분(1% 단위) |
#
# **Equation 9.1**
# $$
# 𝑛이 홀수   𝑛+12 번째 수𝑛이 짝수 𝑛2 ,𝑛+12번째 수의 평균
# $$
#
# **Equation 9.2**
# $$
# 𝑛이 홀수   𝑛+12 번째 수𝑛이 짝수 𝑛2 ,𝑛+12번째 수의 평균
# $$
#
# ![slide9-image1](data:image/png;base64,...)
# ![slide9-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 10: (Untitled)
#
# - 분산
# - (Variance)
# - 모분산
# - 표본 분산
# - 평균에서 떨어진 정도
# - 표준 편차
# - (Standard Deviation)
# - 모표준편차
# - 표본표준편차
# - 분산의 해석력을 보완
# - 산포도
# - 3
# - 기술 통계
#
# **Table 10.1**
# | 분산
# (Variance) | 모분산
# 표본 분산 | 평균에서 떨어진 정도 |
# | --- | --- | --- |
# | 표준 편차
# (Standard Deviation) | 모표준편차
# 표본표준편차 | 분산의 해석력을 보완 |
#
# **Equation 10.1**
# $$
# 𝑠2=𝑖=1𝑛(𝑥𝑖−𝑥)2𝑛−1
# $$
#
# **Equation 10.2**
# $$
# 𝜎2=𝑖=1𝑛(𝑥𝑖−𝜇)2𝑛
# $$
#
# **Equation 10.3**
# $$
# 𝜎=𝑖=1𝑛(𝑥𝑖−𝜇)2𝑛
# $$
#
# **Equation 10.4**
# $$
# 𝑠=𝑖=1𝑛(𝑥𝑖−𝑥)2𝑛−1
# $$
#
# **Equation 10.5**
# $$
# 𝑠2=𝑖=1𝑛(𝑥𝑖−𝑥)2𝑛−1
# $$
#
# **Equation 10.6**
# $$
# 𝜎2=𝑖=1𝑛(𝑥𝑖−𝜇)2𝑛
# $$
#
# **Equation 10.7**
# $$
# 𝜎=𝑖=1𝑛(𝑥𝑖−𝜇)2𝑛
# $$
#
# **Equation 10.8**
# $$
# 𝑠=𝑖=1𝑛(𝑥𝑖−𝑥)2𝑛−1
# $$
#
# ![slide10-image1](data:image/png;base64,...)
# ![slide10-image2](data:image/png;base64,...)
# ![slide10-image3](data:image/png;base64,...)
# ![slide10-image4](data:image/png;base64,...)
# ![slide10-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 11: (Untitled)
#
# - 평균 편차
# - (Mean Absolute Deviation)
# - 평균 편차 =
# - 표준 편차보다 직관적 해석 가능
# - 이상치에 덜 민감
# - 수학적 활용성이 낮음
# - 중앙값 편차
# - (Median Absolute Deviation)
# - 중앙값 편차 =
# - 평균 편차보다 이상치에 덜 민감
# - 산포도
# - 3
# - 기술 통계
#
# **Table 11.1**
# | 평균 편차
# (Mean Absolute Deviation) | 평균 편차 = | 표준 편차보다 직관적 해석 가능
# 이상치에 덜 민감
# 수학적 활용성이 낮음 |
# | --- | --- | --- |
# | 중앙값 편차
# (Median Absolute Deviation) | 중앙값 편차 = | 평균 편차보다 이상치에 덜 민감 |
#
# **Equation 11.1**
# $$
# 𝑖=1𝑛𝑥𝑖−𝑥𝑛
# $$
#
# **Equation 11.2**
# $$
# 𝑖=1𝑛𝑥𝑖−𝑥𝑛
# $$
#
# **Equation 11.3**
# $$
# 𝑖=1𝑛𝑥𝑖−𝑥𝑛
# $$
#
# **Equation 11.4**
# $$
# 𝑖=1𝑛𝑥𝑖−𝑥𝑛
# $$
#
# ![slide11-image1](data:image/png;base64,...)
# ![slide11-image2](data:image/png;base64,...)
# ![slide11-image3](data:image/png;base64,...)

# %% [markdown]
# ### Slide 12: (Untitled)
#
# - 변동계수
# - (Coefficient of Variance)
# - 평균 대비 흩어짐의 정도를 나타냄
# - 다른 단위의 데이터와 비교에 용이
# - 평균이 0 에 가까울수록 불안정
# - 사분위 범위
# - (Inter Quantile Range)
# - 중앙값 기준으로 퍼짐의 정도
# - 이상치에 둔감
# - 산포도
# - 3
# - 기술 통계
#
# **Table 12.1**
# | 변동계수
# (Coefficient of Variance) |   | 평균 대비 흩어짐의 정도를 나타냄
# 다른 단위의 데이터와 비교에 용이
# 평균이 0 에 가까울수록 불안정 |
# | --- | --- | --- |
# | 사분위 범위
# (Inter Quantile Range) |   | 중앙값 기준으로 퍼짐의 정도
# 이상치에 둔감 |
#
# **Equation 12.1**
# $$
# 𝐼𝑄𝑅=𝑄3−𝑄1
# $$
#
# **Equation 12.2**
# $$
# 𝐶𝑉=𝜎𝜇
# $$
#
# **Equation 12.3**
# $$
# 𝐼𝑄𝑅=𝑄3−𝑄1
# $$
#
# **Equation 12.4**
# $$
# 𝐶𝑉=𝜎𝜇
# $$
#
# ![slide12-image1](data:image/png;base64,...)
# ![slide12-image2](data:image/png;base64,...)
# ![slide12-image3](data:image/png;base64,...)

# %% [markdown]
# ### Slide 13: (Untitled)
#
# - 분포의 모양
# - 3
# - 기술 통계
# - 왜도(Skewness): 분포의 치우침
# - 왜도
# - 모양
# - 특징
# - 양의 왜도
# - 우측으로 긴 꼬리
# - 평균>중앙값>최빈값
# - 0
# - 칭
# - 평균=중앙값=최빈값
# - 음의 왜도
# - 좌측으로 긴 꼬리
# - 평균<중앙값<최빈값
# - 왜도
# - 모양
# - 특징
# - 양의 왜도
# - 우측으로 긴 꼬리
# - 평균>중앙값>최빈값
# - 0
# - 평균=중앙값=최빈값
# - 음의 왜도
# - 좌측으로 긴 꼬리
# - 평균<중앙값<최빈값
#
# **Table 13.1**
# | 왜도 | 모양 | 특징 |
# | --- | --- | --- |
# | 양의 왜도 | 우측으로 긴 꼬리 | 평균>중앙값>최빈값 |
# | 0 | 칭 | 평균=중앙값=최빈값 |
# | 음의 왜도 | 좌측으로 긴 꼬리 | 평균<중앙값<최빈값 |
#
# **Table 13.2**
# | 왜도 | 모양 | 특징 |
# | --- | --- | --- |
# | 양의 왜도 | 우측으로 긴 꼬리 | 평균>중앙값>최빈값 |
# | 0 |   | 평균=중앙값=최빈값 |
# | 음의 왜도 | 좌측으로 긴 꼬리 | 평균<중앙값<최빈값 |
#
# **Equation 13.1**
# $$
# 대
# $$
#
# **Equation 13.2**
# $$
# 𝑔1=1𝑛𝑖=1𝑛(𝑥𝑖−𝑥)31𝑛𝑖=1𝑛𝑥𝑖−𝑥23/2
# $$
#
# **Equation 13.3**
# $$
# 𝑔1=1𝑛𝑖=1𝑛(𝑥𝑖−𝑥)31𝑛𝑖=1𝑛𝑥𝑖−𝑥23/2
# $$
#
# ![slide13-image1](data:image/png;base64,...)
# ![slide13-image2](data:image/png;base64,...)
# ![slide13-image3](data:image/png;base64,...)
# ![slide13-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 14: (Untitled)
#
# - 분포의 모양
# - 3
# - 기술 통계
# - 첨도(Kurtosis): 응집도
# - 표준 첨도(Excess kurtosis)
# - 첨 첨도: 뾰족함, 꼬리가 두꺼움
# - 중간 첨도: 정규분포와 동일한 뾰족함
# - 완만 첨도: 평평함, 꼬리 얇음
# - 출처: https://towardsdatascience.com/skewness-kurtosis-simplified-1338e094fc85/
#
# **Equation 14.1**
# $$
# Υ2=1𝑛𝑖=1𝑛(𝑥𝑖−𝑥)41𝑛𝑖=1𝑛𝑥𝑖−𝑥22
# $$
#
# **Equation 14.2**
# $$
# 𝑔2=Υ2−3
# $$
#
# **Equation 14.3**
# $$
# Υ2=1𝑛𝑖=1𝑛(𝑥𝑖−𝑥)41𝑛𝑖=1𝑛𝑥𝑖−𝑥22
# $$
#
# **Equation 14.4**
# $$
# 𝑔2=Υ2−3
# $$
#
# ![slide14-image1](data:image/png;base64,...)
# ![slide14-image2](data:image/png;base64,...)
# ![slide14-image3](data:image/png;base64,...)
# ![slide14-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 15: (Untitled)
#
# - 용어
# - 4
# - 확률의 개념
# - 결과(Outcome): 시행을 통해 실제로 관찰된 단일 결과
# - 시행(Trial, Experiment): 결과가 우연에 의해 정해지는 행위 또는 실험
# - 표본공간(Sample Space, S or Ω): 전체 결과의 목록
# - 사건(Event): 표본 공간의 부분 집합으로, 관심의 대상
#
# ![slide15-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 16: (Untitled)
#
# - 수학적 확률
# - 실험이나 관찰을 통해 얻은 경험적 확률
# - 실험을 반복함에 따라 신뢰도 향상
# - 4
# - 확률의 개념
# - 논리와 이론적 모델에 의해 계산
# - 모든 경우가 발생할 가능성이 동일하다면,
# - 이론적으로 계산한 확률
# - 통계적 확률
#
# **Equation 16.1**
# $$
# PA=A사건의 경우의수전체 경우의 수
# $$
#
# **Equation 16.2**
# $$
# PA=A 사건의 경우의수전체 경우의 수
# $$
#
# **Equation 16.3**
# $$
# PA=A 사건의 관측수전체 관측수
# $$
#
# **Equation 16.4**
# $$
# PA=A사건의 경우의수전체 경우의 수
# $$
#
# **Equation 16.5**
# $$
# PA=A 사건의 관측수전체 관측수
# $$
#
# ![slide16-image1](data:image/png;base64,...)
# ![slide16-image2](data:image/png;base64,...)
# ![slide16-image3](data:image/png;base64,...)
# ![slide16-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 17: (Untitled)
#
# - 확률의 기본 성질
# - 4
# - 확률의 개념
# - 확률의 범위
# - 어떤 사건 A 의 확률,
# - 표본 공간 전체확률
# - 표본 공간 S 의 확률,
# - 불가능한 사건의 확률
# - 일어날 수 없는 사건의 확률,
# - 여사건 확률
# - 어떤 사건 A 가 일어나지 않을 확률,
# - 합사건
# - 사건 A 또는 B 가 일어날 확률,
# - 사건 A 와 B 가 겹치지 않을 때(배반 사건, )
# - 확률의 범위
# - 표본 공간 전체확률
# - 불가능한 사건의 확률
# - 여사건 확률
# - 합사건
#
# **Table 17.1**
# | 확률의 범위 | 어떤 사건 A 의 확률, |
# | --- | --- |
# | 표본 공간 전체확률 | 표본 공간 S 의 확률, |
# | 불가능한 사건의 확률 | 일어날 수 없는 사건의 확률, |
# | 여사건 확률 | 어떤 사건 A 가 일어나지 않을 확률, |
# | 합사건 | 사건 A 또는 B 가 일어날 확률,
# 사건 A 와 B 가 겹치지 않을 때(배반 사건, ) |
#
# **Table 17.2**
# | 확률의 범위 |   |
# | --- | --- |
# | 표본 공간 전체확률 |   |
# | 불가능한 사건의 확률 |   |
# | 여사건 확률 |   |
# | 합사건 |   |
#
# **Equation 17.1**
# $$
# 0≤𝑃(𝐴)≤1
# $$
#
# **Equation 17.2**
# $$
# 𝑃𝑆=1
# $$
#
# **Equation 17.3**
# $$
# 𝑃∅=0
# $$
#
# **Equation 17.4**
# $$
# 𝑃𝐴𝑐=1−𝑃(𝐴)
# $$
#
# **Equation 17.5**
# $$
# 𝑃𝐴∪𝐵=𝑃𝐴+𝑃𝐵−𝑃𝐴∩𝐵
# $$
#
# **Equation 17.6**
# $$
# 𝑃𝐴∩𝐵=0
# $$
#
# **Equation 17.7**
# $$
# 𝑃𝐴∪𝐵=𝑃𝐴+𝑃𝐵
# $$
#
# ![slide17-image1](data:image/png;base64,...)
# ![slide17-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 18: (Untitled)
#
# - 조건부 확률
# - 4
# - 확률의 개념
# - B 사건이 일어났을 때
# - S
# - A
# - B
# - A∩B
# - P(A)
# - S
# - A
# - B
# - P(A|B)
# - A∩B
#
# **Equation 18.1**
# $$
# 𝑃𝐴𝐵=𝑃(𝐴∩𝐵)𝑃(𝐵), 𝑃𝐵>0
# $$
#
# **Equation 18.2**
# $$
# 𝑃𝐴𝐵=𝑃(𝐴∩𝐵)𝑃(𝐵), 𝑃𝐵>0
# $$
#
# ![slide18-image1](data:image/png;base64,...)
# ![slide18-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 19: (Untitled)
#
# - 결합 확률(확률의 곱셈)
# - 4
# - 확률의 개념
# - 사건 A, B 가 서로 독립 이면,
#
# **Equation 19.1**
# $$
# 𝑃𝐴∩𝐵=𝑃𝐴𝐵𝑃𝐵=𝑃𝐵𝐴𝑃(𝐴)
# $$
#
# **Equation 19.2**
# $$
# 𝑃𝐴𝐵=𝑃𝐴, 𝑃𝐵𝐴=𝑃(𝐵)
# $$
#
# **Equation 19.3**
# $$
# 𝑃𝐴∩𝐵=𝑃(𝐴)𝑃(𝐵)
# $$
#
# **Equation 19.4**
# $$
# 𝑃𝐴∩𝐵=𝑃𝐴𝐵𝑃𝐵=𝑃𝐵𝐴𝑃(𝐴)
# $$
#
# **Equation 19.5**
# $$
# 𝑃𝐴∩𝐵=𝑃(𝐴)𝑃(𝐵)
# $$
#
# ![slide19-image1](data:image/png;base64,...)
# ![slide19-image2](data:image/png;base64,...)
# ![slide19-image3](data:image/png;base64,...)
# ![slide19-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 20: (Untitled)
#
# - 조건부 독립
# - 4
# - 확률의 개념
# - 조건부 독립의 예
# - D → S
# - D → T
# - 𝐷: 질병의 유무, 𝑆: 질병의 증상의 유무, 𝑇: 질병의 검사 결과
#
# **Equation 20.1**
# $$
# 𝑃𝐴∩𝐵|𝐶=𝑃(𝐴|𝐶)𝑃(𝐵|𝐶)
# $$
#
# **Equation 20.2**
# $$
# 𝑃𝐴𝐵,𝐶=𝑃(𝐴|𝐶)
# $$
#
# **Equation 20.3**
# $$
# 𝑃𝑆∩𝑇≠𝑃𝑆𝑃(𝑇)
# $$
#
# **Equation 20.4**
# $$
# 𝑃𝑆|𝑇,𝐷=𝑃𝑆|𝐷
# $$
#
# **Equation 20.5**
# $$
# 𝑃𝐴∩𝐵|𝐶=𝑃(𝐴|𝐶)𝑃(𝐵|𝐶)
# $$
#
# **Equation 20.6**
# $$
# 𝑃𝐴𝐵,𝐶=𝑃(𝐴|𝐶)
# $$
#
# **Equation 20.7**
# $$
# 𝑃𝑆∩𝑇≠𝑃𝑆𝑃(𝑇)
# $$
#
# **Equation 20.8**
# $$
# 𝑃𝑆|𝑇,𝐷=𝑃𝑆|𝐷
# $$
#
# ![slide20-image1](data:image/png;base64,...)
# ![slide20-image2](data:image/png;base64,...)
# ![slide20-image3](data:image/png;base64,...)
# ![slide20-image4](data:image/png;base64,...)
# ![slide20-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 21: (Untitled)
#
# - 전확률의 법칙(Law of Total Probability)
# - 4
# - 확률의 개념
# - S
# - A
# - 사건 의 표본공간이 배타적인 k 개의 공간으로 나누었을 때,
#
# **Equation 21.1**
# $$
# ∀𝑖≠𝑗 , 𝐵𝑖∩𝐵𝑗=∅,   𝑆=𝑖=1𝑘𝐵𝑖
# $$
#
# **Equation 21.2**
# $$
# 𝐵2
# $$
#
# **Equation 21.3**
# $$
# 𝐵1
# $$
#
# **Equation 21.4**
# $$
# 𝐵3…
# $$
#
# **Equation 21.5**
# $$
# 𝐵𝑘
# $$
#
# **Equation 21.6**
# $$
# 𝐴∩𝐵1
# $$
#
# **Equation 21.7**
# $$
# 𝐴∩𝐵2
# $$
#
# **Equation 21.8**
# $$
# 𝐴∩𝐵3…
# $$
#
# **Equation 21.9**
# $$
# 𝐴∩𝐵𝑘
# $$
#
# **Equation 21.10**
# $$
# 𝐵
# $$
#
# **Equation 21.11**
# $$
# 𝑃𝐴=𝑖=1𝑘𝑃(𝐴|𝐵𝑖)𝑃𝐵𝑖
# $$
#
# **Equation 21.12**
# $$
# 𝑃𝐴=𝑖=1𝑘𝑃𝐴∩𝐵𝑖
# $$
#
# **Equation 21.13**
# $$
# 𝑃𝐴=𝑖=1𝑘𝑃(𝐵𝑖|𝐴)𝑃𝐴
# $$
#
# **Equation 21.14**
# $$
# ∀𝑖≠𝑗 , 𝐵𝑖∩𝐵𝑗=∅,   𝑆=𝑖=1𝑘𝐵𝑖
# $$
#
# **Equation 21.15**
# $$
# 𝐵2
# $$
#
# **Equation 21.16**
# $$
# 𝐵1
# $$
#
# **Equation 21.17**
# $$
# 𝐵3…
# $$
#
# **Equation 21.18**
# $$
# 𝐵𝑘
# $$
#
# **Equation 21.19**
# $$
# 𝐴∩𝐵1
# $$
#
# **Equation 21.20**
# $$
# 𝐴∩𝐵2
# $$
#
# **Equation 21.21**
# $$
# 𝐴∩𝐵3…
# $$
#
# **Equation 21.22**
# $$
# 𝐴∩𝐵𝑘
# $$
#
# **Equation 21.23**
# $$
# 𝑃𝐴=𝑖=1𝑘𝑃(𝐴|𝐵𝑖)𝑃𝐵𝑖
# $$
#
# **Equation 21.24**
# $$
# 𝑃𝐴=𝑖=1𝑘𝑃𝐴∩𝐵𝑖
# $$
#
# **Equation 21.25**
# $$
# 𝑃𝐴=𝑖=1𝑘𝑃(𝐵𝑖|𝐴)𝑃𝐴
# $$
#
# ![slide21-image1](data:image/png;base64,...)
# ![slide21-image2](data:image/png;base64,...)
# ![slide21-image3](data:image/png;base64,...)
# ![slide21-image4](data:image/png;base64,...)
# ![slide21-image5](data:image/png;base64,...)
# ![slide21-image6](data:image/png;base64,...)
# ![slide21-image7](data:image/png;base64,...)
# ![slide21-image8](data:image/png;base64,...)
# ![slide21-image9](data:image/png;base64,...)
# ![slide21-image10](data:image/png;base64,...)
# ![slide21-image11](data:image/png;base64,...)
# ![slide21-image12](data:image/png;base64,...)
# ![slide21-image13](data:image/png;base64,...)
# ![slide21-image14](data:image/png;base64,...)

# %% [markdown]
# ### Slide 22: (Untitled)
#
# - 베이즈 정리(Bayes’s Theorem)
# - 4
# - 확률의 개념
# - 의 표본공간이 서로 배타적인, k 개의 공간으로 나누어졌을 때,
#
# **Equation 22.1**
# $$
# 𝑃𝐵|𝐴=𝑃𝐴𝐵𝑃(𝐴)𝑃(𝐵)
# $$
#
# **Equation 22.2**
# $$
# 𝐵
# $$
#
# **Equation 22.3**
# $$
# 𝐵𝑖
# $$
#
# **Equation 22.4**
# $$
# 𝑃𝐴∩𝐵=𝑃(𝐴|𝐵)𝑃(𝐵)
# $$
#
# **Equation 22.5**
# $$
# 𝑃𝐴∩𝐵=
# $$
#
# **Equation 22.6**
# $$
# 𝑃(𝐵|𝐴)𝑃(𝐴)
# $$
#
# **Equation 22.7**
# $$
# 𝑃(𝐵|𝐴)𝑃(𝐴)=𝑃(𝐴|𝐵)𝑃(𝐵)
# $$
#
# **Equation 22.8**
# $$
# 𝑃𝐵𝑖|𝐴=𝑃𝐴𝐵𝑖𝑃(𝐵𝑖)𝑗=1𝑘𝑃𝐴𝐵𝑗𝑃(𝐵𝑗)
# $$
#
# **Equation 22.9**
# $$
# ∀𝑖≠𝑗 , 𝐵𝑖∩𝐵𝑗=∅,   𝑆=𝑖=1𝑘𝐵𝑖
# $$
#
# **Equation 22.10**
# $$
# 𝑃𝐵|𝐴=𝑃𝐴𝐵𝑃(𝐴)𝑃(𝐵)
# $$
#
# **Equation 22.11**
# $$
# 𝑃𝐴∩𝐵=𝑃(𝐴|𝐵)𝑃(𝐵)
# $$
#
# **Equation 22.12**
# $$
# 𝑃(𝐵|𝐴)𝑃(𝐴)=𝑃(𝐴|𝐵)𝑃(𝐵)
# $$
#
# **Equation 22.13**
# $$
# 𝑃𝐵𝑖|𝐴=𝑃𝐴𝐵𝑖𝑃(𝐵𝑖)𝑗=1𝑘𝑃𝐴𝐵𝑗𝑃(𝐵𝑗)
# $$
#
# **Equation 22.14**
# $$
# ∀𝑖≠𝑗 , 𝐵𝑖∩𝐵𝑗=∅,   𝑆=𝑖=1𝑘𝐵𝑖
# $$
#
# ![slide22-image1](data:image/png;base64,...)
# ![slide22-image2](data:image/png;base64,...)
# ![slide22-image3](data:image/png;base64,...)
# ![slide22-image4](data:image/png;base64,...)
# ![slide22-image5](data:image/png;base64,...)
# ![slide22-image6](data:image/png;base64,...)
# ![slide22-image7](data:image/png;base64,...)
# ![slide22-image8](data:image/png;base64,...)

# %% [markdown]
# ### Slide 23: (Untitled)
#
# - 5
# - 문제 풀이
# - 감기에 걸린 사람은 90% 확률로 양성 판정을 받는다.
# - 감기에 걸리지 않은 사람도 20% 확률로 양성 판정을 받을 수 있다.
# - Q1. 한 마을 사람들 중 10%가 감기에 걸려 있다.
# - 감기 진단 키트는 다음과 같은 특성을 가진다.
# - 진단 키트에 양성이 나왔을 때, 실제로 감기에 걸렸을 확률은?
# - 1
# - 약 33.3%
# - 2
# - 25%
# - 3
# - 30%
# - 4
# - 35%

# %% [markdown]
# ### Slide 24: (Untitled)
#
# - 1
# - 약 33.3%
# - 2
# - 25%
# - 3
# - 30%
# - 4
# - 35%
# - 문제 풀이
# - 5
# - Q1. 한 마을 사람들 중 10%가 감기에 걸려 있다.
# - 감기 진단 키트는 다음과 같은 특성을 가진다.
# - 진단 키트에 양성이 나왔을 때, 실제로 감기에 걸렸을 확률은?
# - 감기에 걸린 사람은 90% 확률로 양성 판정을 받는다.
# - 감기에 걸리지 않은 사람도 20% 확률로 양성 판정을 받을 수 있다.
# - 9
# - 베이즈 룰 과 전확률 법칙 을 이용하여 식을 처리합니다.
#
# **Equation 24.1**
# $$
# 𝑃𝐶=1=0.1
# $$
#
# **Equation 24.2**
# $$
# 𝑃𝑇=1|𝐶=1=0.
# $$
#
# **Equation 24.3**
# $$
# 𝑃𝑇=1|𝐶=0=0.2
# $$
#
# **Equation 24.4**
# $$
# 𝑃𝐶=1|𝑇=1=𝑃𝑇=1𝐶=1𝑃(𝐶=1)𝑃(𝑇=1)
# $$
#
# **Equation 24.5**
# $$
# =0.9×0.1𝑃𝐶=0,𝑇=1+𝑃(𝐶=1,𝑇=1)
# $$
#
# **Equation 24.6**
# $$
# =0.9×0.10.2×0.9+0.9×0.1
# $$
#
# **Equation 24.7**
# $$
# 𝑃𝐶=1=0.1
# $$
#
# **Equation 24.8**
# $$
# 𝑃𝑇=1|𝐶=0=0.2
# $$
#
# **Equation 24.9**
# $$
# 𝑃𝐶=1|𝑇=1=𝑃𝑇=1𝐶=1𝑃(𝐶=1)𝑃(𝑇=1)
# $$
#
# **Equation 24.10**
# $$
# =0.9×0.1𝑃𝐶=0,𝑇=1+𝑃(𝐶=1,𝑇=1)
# $$
#
# **Equation 24.11**
# $$
# =0.9×0.10.2×0.9+0.9×0.1
# $$
#
# ![slide24-image1](data:image/png;base64,...)
# ![slide24-image2](data:image/png;base64,...)
# ![slide24-image3](data:image/png;base64,...)
# ![slide24-image4](data:image/png;base64,...)
# ![slide24-image5](data:image/png;base64,...)
# ![slide24-image6](data:image/png;base64,...)
# ![slide24-image7](data:image/png;base64,...)

# %% [markdown]
# ### Slide 25: (Untitled)
#
# - 1
# - 1/3
# - 2
# - 4/9
# - 3
# - 5/9
# - 4
# - 2/3
# - 문제 풀이
# - 5
# - Q2. 1 부터 6 까지 적힌 모든 수가 동일 확률로 나오는 정육면체 주사위를
# - 2 번 던졌을 경우, 둘 중에 적어도 한 번 3 의 배수가 나올 확률은?

# %% [markdown]
# ### Slide 26: (Untitled)
#
# - 3
# - 5/9
# - 1
# - 1/3
# - 2
# - 4/9
# - 4
# - 2/3
# - 문제 풀이
# - 5
# - Q2. 1 부터 6 까지 적힌 모든 수가 동일 확률로 나오는 정육면체 주사위를
# - 2 번 던졌을 경우, 둘 중에 적어도 한 번 3 의 배수가 나올 확률은?
# - 방법 1) P(X1=3 의 배수, X2=Not 3 의 배수) + P(X1=Not 3 의 배수, X2=3 의 배수) + P(X1=3 의 배수, X1=3 의 배수)
# - 방법 2) P(X1=3 의 배수) + P(X2=3 의 배수) – P(X1=3 의 배수, X2= 3 의 배수)
# - 방법 3) 1 – P(X1=Not 3 의 배수, X2 = Not 3 의 배수)
#
# ![slide26-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 27: (Untitled)
#
# - 문제 풀이
# - 5
# - 모집단을 구성에 차이가 없는 군집으로 나누어 추출한다.
# - 1
# - 모집단에 대한 정보가 많지 않을 경우 사용한다.
# - 2
# - 표본의 수가 같다면 단순 임의 추출보다 표본 오차가 클 여지가 크다.
# - 3
# - 모집단에 대한 기반 마련이 어려운 현장 조사에서 유리하다.
# - 4
# - Q3. 군집 추출에 대한 설명으로 틀린 것은?

# %% [markdown]
# ### Slide 28: (Untitled)
#
# - 문제 풀이
# - 5
# - 모집단에 대한 정보가 많지 않을 경우 사용한다.
# - 2
# - Q3. 군집 추출에 대한 설명으로 틀린 것은?
# - 해당 보기는 단순 임의 추출에 대한 내용입니다.
# - 모집단을 구성에 차이가 없는 군집으로 나누어 추출한다.
# - 1
# - 표본의 수가 같다면 단순 임의 추출보다 표본 오차가 클 여지가 크다.
# - 3
# - 모집단에 대한 기반 마련이 어려운 현장 조사에서 유리하다.
# - 4
#
# ![slide28-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 29: (Untitled)
#
# - # 표본 추출
# - # 기술 통계
# # 확률
# - # 조건부 확률
# - # 전확률의 법칙
# - # 베이즈 정리
# - 추후 디자인하여 PSD 로 편집될 영역입니다.
