# %% [markdown]
# # PPT → Markdown (v3: Better Text Joining + Tables + Equations)
#
# **Source**: `[9차시] LV3_2-6 선형회귀 분석_0828_완.pptx`
#
# 개선 사항:
# - **폰트/스타일로 분리된 run들을 문장 단위로 매끄럽게 연결**
# - 줄바꿈(br) 보존, 불필요한 공백 정리, 소프트 하이픈 제거
# - bullet(기본) 감지 후 접두사 적용
# - 기존 이미지/테이블/수식/헤더 로직 그대로 유지

# %% [markdown]
# ### Slide 1: (Untitled)
#
# - 09. 선형회귀 분석

# %% [markdown]
# ### Slide 2: (Untitled)
#
# - 1
# - 회귀 분석
# - 종속 변수(Y): 예측하거나 설명하고자 하는 대상
# - 독립 변수(X): 종속 변수에 영향을 줄 수 있는 변수
# - 변수 간의 관계를 파악하여 예측 과 요인 분석
# - 변수들 간의 관계를 수학적으로 모델링
#
# ![slide2-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 3: (Untitled)
#
# - 2
# - 선형회귀
# - : 절편(Intercept)
# - : 계수(기울기)
# - 오차항(Error Term)
# - 단순 선형회귀(Simple Linear Regression)
# - 종속 변수(Y)와 독립 변수(X)의 관계를 선형 함수로 나타냄
#
# **Equation 3.1**
# $$
# 𝑌=𝛽0+𝛽1𝑋+𝜖
# $$
#
# **Equation 3.2**
# $$
# 𝛽0
# $$
#
# **Equation 3.3**
# $$
# 𝛽1
# $$
#
# **Equation 3.4**
# $$
# 𝜖 :
# $$
#
# **Equation 3.5**
# $$
# 𝑌=𝛽0+𝛽1𝑋+𝜖
# $$
#
# ![slide3-image1](data:image/png;base64,...)
# ![slide3-image2](data:image/png;base64,...)
# ![slide3-image3](data:image/png;base64,...)
# ![slide3-image4](data:image/png;base64,...)
# ![slide3-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 4: (Untitled)
#
# - 2
# - 선형회귀
# - 독립성(I ndependence)
# - : 관측치는 서로 독립
# - 등분산성(Homoscedasticity)
# - 정규성
# - 등분산성
# - 0
# - 20
# - 40
# - 60
# - 100
# - X
# - Y
# - 정규성(Normality)
# - 주요 가정
# - 선형성(Linearity)
#
# **Equation 4.1**
# $$
# 𝜖~𝑁(0, 𝜎2)
# $$
#
# **Equation 4.2**
# $$
# 𝜖~𝑁(0, 𝜎2)
# $$
#
# ![slide4-image1](data:image/png;base64,...)
# ![slide4-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 5: (Untitled)
#
# - 3
# - 선형회귀 모델 추정
# - 최소제곱법(Least Square Method)
# - (오차제곱합)을 최소화하는
# 을 추정
# - 정규방정식(Normal Equation)의 해,
#
# **Equation 5.1**
# $$
# 𝑆𝑆𝐸
# $$
#
# **Equation 5.2**
# $$
# 𝛽0, 𝛽1
# $$
#
# **Equation 5.3**
# $$
# 𝑦𝑖=𝛽0+𝛽1𝑥𝑖+𝜖𝑖
# $$
#
# **Equation 5.4**
# $$
# 𝑆𝑆𝐸=𝑖=1𝑛𝑦𝑖−𝑦𝑖2
# $$
#
# **Equation 5.5**
# $$
# 𝑦𝑖=𝛽0+𝛽1𝑥𝑖
# $$
#
# **Equation 5.6**
# $$
# 𝐿(𝛽0,𝛽1)=𝑖=1𝑛𝑦𝑖−𝛽0−𝛽1𝑥𝑖2
# $$
#
# **Equation 5.7**
# $$
# 𝜕𝐿𝛽0,𝛽1𝜕𝛽0=0
# $$
#
# **Equation 5.8**
# $$
# 𝜕𝐿𝛽0,𝛽1𝜕𝛽1=0
# $$
#
# **Equation 5.9**
# $$
# 𝛽1=𝑖=1𝑛(𝑥𝑖−𝑥)(𝑦𝑖−𝑦)𝑖=1𝑛𝑥𝑖−𝑥2
# $$
#
# **Equation 5.10**
# $$
# 𝛽0=𝑦−𝛽1𝑥
# $$
#
# **Equation 5.11**
# $$
# 𝑦𝑖=𝛽0+𝛽1𝑥𝑖+𝜖𝑖
# $$
#
# **Equation 5.12**
# $$
# 𝑆𝑆𝐸=𝑖=1𝑛𝑦𝑖−𝑦𝑖2
# $$
#
# **Equation 5.13**
# $$
# 𝑦𝑖=𝛽0+𝛽1𝑥𝑖
# $$
#
# **Equation 5.14**
# $$
# 𝐿(𝛽0,𝛽1)=𝑖=1𝑛𝑦𝑖−𝛽0−𝛽1𝑥𝑖2
# $$
#
# **Equation 5.15**
# $$
# 𝜕𝐿𝛽0,𝛽1𝜕𝛽0=0
# $$
#
# **Equation 5.16**
# $$
# 𝜕𝐿𝛽0,𝛽1𝜕𝛽1=0
# $$
#
# **Equation 5.17**
# $$
# 𝛽1=𝑖=1𝑛(𝑥𝑖−𝑥)(𝑦𝑖−𝑦)𝑖=1𝑛𝑥𝑖−𝑥2
# $$
#
# **Equation 5.18**
# $$
# 𝛽0=𝑦−𝛽1𝑥
# $$
#
# ![slide5-image1](data:image/png;base64,...)
# ![slide5-image2](data:image/png;base64,...)
# ![slide5-image3](data:image/png;base64,...)
# ![slide5-image4](data:image/png;base64,...)
# ![slide5-image5](data:image/png;base64,...)
# ![slide5-image6](data:image/png;base64,...)
# ![slide5-image7](data:image/png;base64,...)
# ![slide5-image8](data:image/png;base64,...)
# ![slide5-image9](data:image/png;base64,...)
# ![slide5-image10](data:image/png;base64,...)

# %% [markdown]
# ### Slide 6: (Untitled)
#
# - 3
# - 선형회귀 모델 추정
# - 제곱합: Sum of Squares
# - 제곱합
# - 공식
# - 동의어
# - 총 제곱합
# - (Sum of Squares of Total)
# - TSS(Total Sum of Squares)
# - 회귀 제곱합
# - (Sum of Squares
# - due to Regression)
# - ESS(Explained Sum of Squares)
# - 오차 제곱합
# - (Sum of Squares of Errors)
# - RSS(Residual Sum of Squares)
# - 제곱합
# - 공식
# - 동의어
# - 총 제곱합
# - (Sum of Squares of Total)
# - TSS(Total Sum of Squares)
# - 회귀 제곱합
# - (Sum of Squares
# - due to Regression)
# - ESS(Explained Sum of Squares)
# - 오차 제곱합
# - (Sum of Squares of Errors)
# - RSS(Residual Sum of Squares)
# - 최소제곱법 으로 추정된 절편이 있는 선형회귀 모델
#
# **Table 6.1**
# | 제곱합 | 공식 | 동의어 |
# | --- | --- | --- |
# | 총 제곱합
# (Sum of Squares of Total) |   | TSS(Total Sum of Squares) |
# | 회귀 제곱합
# (Sum of Squares
# due to Regression) |   | ESS(Explained Sum of Squares) |
# | 오차 제곱합
# (Sum of Squares of Errors) |   | RSS(Residual Sum of Squares) |
#
# **Table 6.2**
# | 제곱합 | 공식 | 동의어 |
# | --- | --- | --- |
# | 총 제곱합
# (Sum of Squares of Total) |   | TSS(Total Sum of Squares) |
# | 회귀 제곱합
# (Sum of Squares
# due to Regression) |   | ESS(Explained Sum of Squares) |
# | 오차 제곱합
# (Sum of Squares of Errors) |   | RSS(Residual Sum of Squares) |
#
# **Equation 6.1**
# $$
# 𝑆𝑆𝑇=𝑖=1𝑛𝑦𝑖−𝑦2
# $$
#
# **Equation 6.2**
# $$
# 𝑆𝑆𝑅=𝑖=1𝑛𝑦𝑖−𝑦2
# $$
#
# **Equation 6.3**
# $$
# 𝑆𝑆𝐸=𝑖=1𝑛𝑦𝑖−𝑦𝑖2
# $$
#
# **Equation 6.4**
# $$
# 𝑆𝑆𝑇=𝑆𝑆𝑅+𝑆𝑆𝐸
# $$
#
# **Equation 6.5**
# $$
# 𝑆𝑆𝑇=𝑖=1𝑛𝑦𝑖−𝑦2
# $$
#
# **Equation 6.6**
# $$
# 𝑆𝑆𝑅=𝑖=1𝑛𝑦𝑖−𝑦2
# $$
#
# **Equation 6.7**
# $$
# 𝑆𝑆𝐸=𝑖=1𝑛𝑦𝑖−𝑦𝑖2
# $$
#
# **Equation 6.8**
# $$
# 𝑆𝑆𝑇=𝑆𝑆𝑅+𝑆𝑆𝐸
# $$
#
# ![slide6-image1](data:image/png;base64,...)
# ![slide6-image2](data:image/png;base64,...)
# ![slide6-image3](data:image/png;base64,...)

# %% [markdown]
# ### Slide 7: (Untitled)
#
# - 4
# - 다중 선형회귀 모델
# - : 절편(Intercept)
# - : 계수(coefficient, 기울기)
# - 오차항(error term)
# - 정의
# - 둘 이상의 독립 변수(X)를 지닌 선형회귀 모델
# - 주요 가정
# - 선형성(Linearity), 등분산성(homoscedasticity), 정규성(normality),
# - 독립성(independence), 다중공선성 없음(No multicollinearity)
#
# **Equation 7.1**
# $$
# 𝛽0
# $$
#
# **Equation 7.2**
# $$
# 𝛽1~𝛽𝑝
# $$
#
# **Equation 7.3**
# $$
# 𝜖 :
# $$
#
# **Equation 7.4**
# $$
# 𝑌=𝛽0+𝛽1𝑋1+𝛽2𝑋2+…+𝛽𝑝𝑋𝑝+𝜖
# $$
#
# **Equation 7.5**
# $$
# 𝑌=𝛽0+𝛽1𝑋1+𝛽2𝑋2+…+𝛽𝑝𝑋𝑝+𝜖
# $$
#
# ![slide7-image1](data:image/png;base64,...)
# ![slide7-image2](data:image/png;base64,...)
# ![slide7-image3](data:image/png;base64,...)
# ![slide7-image4](data:image/png;base64,...)
# ![slide7-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 8: (Untitled)
#
# - 5
# - 다중 선형회귀 모델의 추정
# - 최소제곱법
# - 1 열 벡터, 종속 변수
# - 행렬, 독립 변수에 절편(모든 값이 1) 포함
# - 열 벡터, 회귀 계수 벡터(절편 포함)
#
# **Equation 8.1**
# $$
# 𝑌=𝛽0+𝛽1𝑋1+𝛽2𝑋2+…+𝛽𝑝𝑋𝑝+𝜖
# $$
#
# **Equation 8.2**
# $$
# 𝑦=𝑋𝛃+𝜖
# $$
#
# **Equation 8.3**
# $$
# 𝑦 : n×
# $$
#
# **Equation 8.4**
# $$
# 𝑋:𝑛×𝑝+1
# $$
#
# **Equation 8.5**
# $$
# 𝛃:𝑝+1×1
# $$
#
# **Equation 8.6**
# $$
# 𝑌=𝛽0+𝛽1𝑋1+𝛽2𝑋2+…+𝛽𝑝𝑋𝑝+𝜖
# $$
#
# **Equation 8.7**
# $$
# 𝑦=𝑋𝛃+𝜖
# $$
#
# ![slide8-image1](data:image/png;base64,...)
# ![slide8-image2](data:image/png;base64,...)
# ![slide8-image3](data:image/png;base64,...)
# ![slide8-image4](data:image/png;base64,...)
# ![slide8-image5](data:image/png;base64,...)
# ![slide8-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 9: (Untitled)
#
# - 5
# - 다중 선형회귀 모델의 추정
# - 최소제곱법
# - 를 만족하는 찾기
#
# **Equation 9.1**
# $$
# 𝐲=𝑋𝛃+𝜖
# $$
#
# **Equation 9.2**
# $$
# 𝐿=𝑆𝑆𝐸=𝐲−𝑋𝛃𝑇(𝐲−𝑋𝛃)
# $$
#
# **Equation 9.3**
# $$
# 𝐲=𝑋𝛃
# $$
#
# **Equation 9.4**
# $$
# 𝐿=𝐲−𝑋𝛃𝑇(𝐲−𝑋𝛃)
# $$
#
# **Equation 9.5**
# $$
# 𝛻𝛃𝐿=𝟎
# $$
#
# **Equation 9.6**
# $$
# 𝛻𝛃𝐿=−2𝑋𝑇(𝐲−𝑋𝛃)
# $$
#
# **Equation 9.7**
# $$
# 𝑋𝑇 𝐲−𝑋𝛃=0
# $$
#
# **Equation 9.8**
# $$
# 𝛃=𝑋𝑇𝑋−1𝑋𝑇𝐲
# $$
#
# **Equation 9.9**
# $$
# 𝛃
# $$
#
# **Equation 9.10**
# $$
# 𝐲=𝑋𝛃+𝜖
# $$
#
# **Equation 9.11**
# $$
# 𝐿=𝑆𝑆𝐸=𝐲−𝑋𝛃𝑇(𝐲−𝑋𝛃)
# $$
#
# **Equation 9.12**
# $$
# 𝐲=𝑋𝛃
# $$
#
# **Equation 9.13**
# $$
# 𝐿=𝐲−𝑋𝛃𝑇(𝐲−𝑋𝛃)
# $$
#
# **Equation 9.14**
# $$
# 𝛻𝛃𝐿=𝟎
# $$
#
# **Equation 9.15**
# $$
# 𝛻𝛃𝐿=−2𝑋𝑇(𝐲−𝑋𝛃)
# $$
#
# **Equation 9.16**
# $$
# 𝑋𝑇 𝐲−𝑋𝛃=0
# $$
#
# **Equation 9.17**
# $$
# 𝛃=𝑋𝑇𝑋−1𝑋𝑇𝐲
# $$
#
# ![slide9-image1](data:image/png;base64,...)
# ![slide9-image2](data:image/png;base64,...)
# ![slide9-image3](data:image/png;base64,...)
# ![slide9-image4](data:image/png;base64,...)
# ![slide9-image5](data:image/png;base64,...)
# ![slide9-image6](data:image/png;base64,...)
# ![slide9-image7](data:image/png;base64,...)
# ![slide9-image8](data:image/png;base64,...)
# ![slide9-image9](data:image/png;base64,...)
# ![slide9-image10](data:image/png;base64,...)

# %% [markdown]
# ### Slide 10: (Untitled)
#
# - 5
# - 다중 선형회귀 모델의 추정
# - 증명
# - ,
# - ,
#
# **Equation 10.1**
# $$
# 𝑆𝑆𝑇=𝑆𝑆𝑅+𝑆𝑆𝐸
# $$
#
# **Equation 10.2**
# $$
# 𝜕𝑆𝑆𝐸𝜕𝛽0=𝜕𝐲−𝑋𝛃𝑇𝐲−𝑋𝛃𝜕𝛽0=0
# $$
#
# **Equation 10.3**
# $$
# 𝐲=𝑋𝛃
# $$
#
# **Equation 10.4**
# $$
# 𝑆𝑆𝑇=𝐲−𝐲𝟏2
# $$
#
# **Equation 10.5**
# $$
# 𝛃=𝑋𝑇𝑋−1𝑋𝑇𝐲
# $$
#
# **Equation 10.6**
# $$
# =𝐲−𝐲𝟏+𝐲−𝐲2
# $$
#
# **Equation 10.7**
# $$
# =𝐲−𝐲𝟏+𝒚−𝐲2
# $$
#
# **Equation 10.8**
# $$
# =𝐲−𝐲𝟏2+𝝐2+2𝛜𝐓𝐲−𝐲𝟏
# $$
#
# **Equation 10.9**
# $$
# =𝑆𝑆𝑅+𝑆𝑆𝐸+2𝛜𝐓𝑋𝛃
# $$
#
# **Equation 10.10**
# $$
# −2𝐲𝛜𝐓𝟏
# $$
#
# **Equation 10.11**
# $$
# 2𝐲−𝑋𝛃𝟏=0
# $$
#
# **Equation 10.12**
# $$
# 𝛜𝐓𝟏=0
# $$
#
# **Equation 10.13**
# $$
# 𝛜𝐓𝑋=𝐲−𝐲𝑇𝑋=𝐲−𝑋𝑋𝑇𝑋−1𝑋𝑇𝐲𝑇𝑋
# $$
#
# **Equation 10.14**
# $$
# =𝐲𝑇𝐼−𝑋𝑋𝑇𝑋−1𝑋𝑇𝑇𝑋
# $$
#
# **Equation 10.15**
# $$
# =𝐲𝑇𝑋𝑇−𝑋𝑇𝑋𝑋𝑇𝑋−1𝑋𝑇𝑇
# $$
#
# **Equation 10.16**
# $$
# =𝐲𝑇𝑋𝑇−𝑋𝑇𝑇=0
# $$
#
# **Equation 10.17**
# $$
# 𝜕𝑆𝑆𝐸𝜕𝛽0=𝜕𝐲−𝑋𝛃𝑇𝐲−𝑋𝛃𝜕𝛽0=0
# $$
#
# **Equation 10.18**
# $$
# 𝑆𝑆𝑇=𝐲−𝐲𝟏2
# $$
#
# **Equation 10.19**
# $$
# =𝐲−𝐲𝟏+𝐲−𝐲2
# $$
#
# **Equation 10.20**
# $$
# =𝐲−𝐲𝟏+𝒚−𝐲2
# $$
#
# **Equation 10.21**
# $$
# =𝐲−𝐲𝟏2+𝝐2+2𝛜𝐓𝐲−𝐲𝟏
# $$
#
# **Equation 10.22**
# $$
# 2𝐲−𝑋𝛃𝟏=0
# $$
#
# **Equation 10.23**
# $$
# 𝛜𝐓𝟏=0
# $$
#
# **Equation 10.24**
# $$
# 𝛜𝐓𝑋=𝐲−𝐲𝑇𝑋=𝐲−𝑋𝑋𝑇𝑋−1𝑋𝑇𝐲𝑇𝑋
# $$
#
# **Equation 10.25**
# $$
# =𝐲𝑇𝐼−𝑋𝑋𝑇𝑋−1𝑋𝑇𝑇𝑋
# $$
#
# **Equation 10.26**
# $$
# =𝐲𝑇𝑋𝑇−𝑋𝑇𝑋𝑋𝑇𝑋−1𝑋𝑇𝑇
# $$
#
# **Equation 10.27**
# $$
# =𝐲𝑇𝑋𝑇−𝑋𝑇𝑇=0
# $$
#
# ![slide10-image1](data:image/png;base64,...)
# ![slide10-image2](data:image/png;base64,...)
# ![slide10-image3](data:image/png;base64,...)
# ![slide10-image4](data:image/png;base64,...)
# ![slide10-image5](data:image/png;base64,...)
# ![slide10-image6](data:image/png;base64,...)
# ![slide10-image7](data:image/png;base64,...)
# ![slide10-image8](data:image/png;base64,...)
# ![slide10-image9](data:image/png;base64,...)
# ![slide10-image10](data:image/png;base64,...)
# ![slide10-image11](data:image/png;base64,...)
# ![slide10-image12](data:image/png;base64,...)
# ![slide10-image13](data:image/png;base64,...)
# ![slide10-image14](data:image/png;base64,...)
# ![slide10-image15](data:image/png;base64,...)
# ![slide10-image16](data:image/png;base64,...)

# %% [markdown]
# ### Slide 11: (Untitled)
#
# - 6
# - 선형회귀 모델의 적합성(goodness-of-fit)
# - 의미
# - 조정된 결정계수(Adjusted, Coefficient of Determinations)
# - : 절편이 있을 경우, 없을 경우
# - 에 자유도를 반영
# - : 표본수
# - 모델에 의해 설명된 종속 변수의 변동성
# - 결정계수(, Coefficient of Determinations)
# - 선형회귀 모델이 데이터를 얼마나 잘 설명하고 있는지를 나타냄
# - 기준
#
# **Equation 11.1**
# $$
# 𝑅2=1−𝑆𝑆𝐸𝑆𝑆𝑇
# $$
#
# **Equation 11.2**
# $$
# 𝑅2
# $$
#
# **Equation 11.3**
# $$
# 𝐴𝑑𝑗𝑢𝑠𝑡𝑒𝑑 𝑅2=1−𝑆𝑆𝐸/(𝑛−𝑘)𝑆𝑆𝑇/(𝑛−1)
# $$
#
# **Equation 11.4**
# $$
# 𝑘
# $$
#
# **Equation 11.5**
# $$
# 𝑝+1
# $$
#
# **Equation 11.6**
# $$
# 𝑝
# $$
#
# **Equation 11.7**
# $$
# 𝑅2
# $$
#
# **Equation 11.8**
# $$
# 𝑛
# $$
#
# **Equation 11.9**
# $$
# 𝑅2
# $$
#
# **Equation 11.10**
# $$
# 𝑅2=1−𝑆𝑆𝐸𝑆𝑆𝑇
# $$
#
# **Equation 11.11**
# $$
# 𝐴𝑑𝑗𝑢𝑠𝑡𝑒𝑑 𝑅2=1−𝑆𝑆𝐸/(𝑛−𝑘)𝑆𝑆𝑇/(𝑛−1)
# $$
#
# ![slide11-image1](data:image/png;base64,...)
# ![slide11-image2](data:image/png;base64,...)
# ![slide11-image3](data:image/png;base64,...)
# ![slide11-image4](data:image/png;base64,...)
# ![slide11-image5](data:image/png;base64,...)
# ![slide11-image6](data:image/png;base64,...)
# ![slide11-image7](data:image/png;base64,...)
# ![slide11-image8](data:image/png;base64,...)

# %% [markdown]
# ### Slide 12: (Untitled)
#
# - 6
# - 선형회귀 모델의 적합성(goodness-of-fit)
# - AIC(Akaike Information Criterion)
# - : 모델의 표본 X 에 대한 최대 우도
# - : 절편이 있을 경우, 없을 경우
# - 가 작을수록 모델이 데이터를 잘 설명
# - 선형회귀 모델의
#
# **Equation 12.1**
# $$
# 𝐴𝐼𝐶=2𝑘−2ln⁡(𝐿)
# $$
#
# **Equation 12.2**
# $$
# 𝐿=𝐿𝜃𝑋
# $$
#
# **Equation 12.3**
# $$
# 𝑘
# $$
#
# **Equation 12.4**
# $$
# 𝑝+1
# $$
#
# **Equation 12.5**
# $$
# 𝑝
# $$
#
# **Equation 12.6**
# $$
# 𝐴𝐼𝐶
# $$
#
# **Equation 12.7**
# $$
# 𝐴𝐼𝐶
# $$
#
# **Equation 12.8**
# $$
# 𝐴𝐼𝐶𝑙𝑚=2𝑘−nln𝑆𝑆𝐸𝑛
# $$
#
# **Equation 12.9**
# $$
# 𝐴𝐼𝐶=2𝑘−2ln⁡(𝐿)
# $$
#
# **Equation 12.10**
# $$
# 𝐴𝐼𝐶𝑙𝑚=2𝑘−nln𝑆𝑆𝐸𝑛
# $$
#
# ![slide12-image1](data:image/png;base64,...)
# ![slide12-image2](data:image/png;base64,...)
# ![slide12-image3](data:image/png;base64,...)
# ![slide12-image4](data:image/png;base64,...)
# ![slide12-image5](data:image/png;base64,...)
# ![slide12-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 13: (Untitled)
#
# - 6
# - 선형회귀 모델의 적합성(goodness-of-fit)
# - BIC(Bayesian Information Criterion)
# - : 모델의 표본 X 에 대한 최대 우도
# - : 절편이 있을 경우, 없을 경우
# - 는 보다 모수가 많을수록 더 많은 패널티를 받음
# - 선형회귀 모델의
#
# **Equation 13.1**
# $$
# 𝐵𝐼𝐶=𝑘log𝑛−2ln⁡(𝐿)
# $$
#
# **Equation 13.2**
# $$
# 𝐿=𝐿𝜃𝑋
# $$
#
# **Equation 13.3**
# $$
# 𝑘
# $$
#
# **Equation 13.4**
# $$
# 𝑝+1
# $$
#
# **Equation 13.5**
# $$
# 𝑝
# $$
#
# **Equation 13.6**
# $$
# 𝐵𝐼𝐶
# $$
#
# **Equation 13.7**
# $$
# 𝐴𝐼𝐶
# $$
#
# **Equation 13.8**
# $$
# 𝐵𝐼𝐶
# $$
#
# **Equation 13.9**
# $$
# 𝐵𝐼𝐶𝑙𝑚=𝑘ln𝑛−nln𝑆𝑆𝐸𝑛
# $$
#
# **Equation 13.10**
# $$
# 𝐵𝐼𝐶=𝑘log𝑛−2ln⁡(𝐿)
# $$
#
# **Equation 13.11**
# $$
# 𝐵𝐼𝐶𝑙𝑚=𝑘ln𝑛−nln𝑆𝑆𝐸𝑛
# $$
#
# ![slide13-image1](data:image/png;base64,...)
# ![slide13-image2](data:image/png;base64,...)
# ![slide13-image3](data:image/png;base64,...)
# ![slide13-image4](data:image/png;base64,...)
# ![slide13-image5](data:image/png;base64,...)
# ![slide13-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 14: (Untitled)
#
# - 6
# - 선형회귀 모델의 적합성(goodness-of-fit)
# - 정규성
# - 등분산성
# - 0
# - 20
# - 40
# - 60
# - 100
# - X
# - Y
# - 검정통계량
# - : 절편이 있을 경우, 없을 경우
# - : 표본수
# - 검정의 종류: 우측 꼬리 검정
# - 선형회귀 모델의 유의미성 검정
# - (선형회귀 모델은 유의미)
# - (선형회귀 모델은 무의미)
#
# **Equation 14.1**
# $$
# 𝑘
# $$
#
# **Equation 14.2**
# $$
# 𝑝+1
# $$
#
# **Equation 14.3**
# $$
# 𝑝
# $$
#
# **Equation 14.4**
# $$
# 𝑛
# $$
#
# **Equation 14.5**
# $$
# 𝐻1:𝛽1≠0 𝑜𝑟 𝛽2≠0 𝑜𝑟…𝛽𝑝≠0
# $$
#
# **Equation 14.6**
# $$
# 𝐻0:𝛽1=𝛽2=…=𝛽𝑝=0
# $$
#
# **Equation 14.7**
# $$
# 𝐹=𝑀𝑆𝑅𝑀𝑆𝐸=𝑆𝑆𝑅/(𝑘−1)𝑆𝑆𝐸/(𝑛−𝑘)~𝐹(𝑘−1,𝑛−𝑘)
# $$
#
# **Equation 14.8**
# $$
# 𝐹=𝑀𝑆𝑅𝑀𝑆𝐸=𝑆𝑆𝑅/(𝑘−1)𝑆𝑆𝐸/(𝑛−𝑘)~𝐹(𝑘−1,𝑛−𝑘)
# $$
#
# ![slide14-image1](data:image/png;base64,...)
# ![slide14-image2](data:image/png;base64,...)
# ![slide14-image3](data:image/png;base64,...)
# ![slide14-image4](data:image/png;base64,...)
# ![slide14-image5](data:image/png;base64,...)
# ![slide14-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 15: (Untitled)
#
# - 6
# - 선형회귀 모델의 적합성(goodness-of-fit)
# - Jarque-Bera, Shapiro-Wilk,…
# - Q-Q Plot
# - 잔차 플롯
# - 잔차의 정규성
# - 등분산성
#
# ![slide15-image1](data:image/png;base64,...)
# ![slide15-image2](data:image/png;base64,...)
# ![slide15-image3](data:image/png;base64,...)

# %% [markdown]
# ### Slide 16: (Untitled)
#
# - 6
# - 선형회귀 모델의 적합성(goodness-of-fit)
# - 적합성에서 벗어난 경우
#
# ![slide16-image1](data:image/png;base64,...)
# ![slide16-image2](data:image/png;base64,...)
# ![slide16-image3](data:image/png;base64,...)

# %% [markdown]
# ### Slide 17: (Untitled)
#
# - 7
# - 선형회귀: 계수 분석
# - 독립 변수의 표준편차 와 종속 변수의 표준편차의 비율을 곱해서 구함
# - 표준화 회귀 계수
# - 다중 회귀 모델에서, 단위가 다른 변수 간의 영향력 비교
#
# **Equation 17.1**
# $$
# 𝛽𝑗∗=𝛽𝑗𝑆𝐷(𝑋𝑗)𝑆𝐷(𝑌)
# $$
#
# **Equation 17.2**
# $$
# 𝛽𝑗∗=𝛽𝑗𝑆𝐷(𝑋𝑗)𝑆𝐷(𝑌)
# $$
#
# ![slide17-image1](data:image/png;base64,...)
# ![slide17-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 18: (Untitled)
#
# - 7
# - 선형회귀: 계수 분석
# - 검정통계량
# - : 절편이 있을 경우, 없을 경우
# - : 표본수
# - 검정의 종류: 양측 꼬리 검정
# - (독립 변수 j 는 유의미)
# - 선형회귀 계수의 유의미성 검정
# - (독립 변수 j 는 무의미)
# - :j 번째 대각원소
#
# **Equation 18.1**
# $$
# 𝑘
# $$
#
# **Equation 18.2**
# $$
# 𝑝+1
# $$
#
# **Equation 18.3**
# $$
# 𝑝
# $$
#
# **Equation 18.4**
# $$
# 𝑛
# $$
#
# **Equation 18.5**
# $$
# 𝐻1:𝛽𝑗≠0
# $$
#
# **Equation 18.6**
# $$
# 𝐻0:𝛽𝑗=0
# $$
#
# **Equation 18.7**
# $$
# 𝑡𝑗=𝛽𝑗𝑆𝐸(𝛽𝑗)~𝑡(𝑛−𝑘)
# $$
#
# **Equation 18.8**
# $$
# 𝑆𝐸𝛽𝑗=𝜎2𝑋𝑇𝑋−1𝑗𝑗
# $$
#
# **Equation 18.9**
# $$
# 𝜎2=𝑆𝑆𝐸𝑛−𝑘
# $$
#
# **Equation 18.10**
# $$
# ∙𝑗𝑗
# $$
#
# **Equation 18.11**
# $$
# 𝑡𝑗=𝛽𝑗𝑆𝐸(𝛽𝑗)~𝑡(𝑛−𝑘)
# $$
#
# **Equation 18.12**
# $$
# 𝑆𝐸𝛽𝑗=𝜎2𝑋𝑇𝑋−1𝑗𝑗
# $$
#
# **Equation 18.13**
# $$
# 𝜎2=𝑆𝑆𝐸𝑛−𝑘
# $$
#
# ![slide18-image1](data:image/png;base64,...)
# ![slide18-image2](data:image/png;base64,...)
# ![slide18-image3](data:image/png;base64,...)
# ![slide18-image4](data:image/png;base64,...)
# ![slide18-image5](data:image/png;base64,...)
# ![slide18-image6](data:image/png;base64,...)
# ![slide18-image7](data:image/png;base64,...)
# ![slide18-image8](data:image/png;base64,...)
# ![slide18-image9](data:image/png;base64,...)

# %% [markdown]
# ### Slide 19: (Untitled)
#
# - 8
# - 다중공선성
# - 둘 이상의 독립 변수 사이에 높은 상관 관계 존재
#
# **Equation 19.1**
# $$
# 변수 해석 어려움
# $$
#
# **Equation 19.2**
# $$
# 회귀 계수 불안정
# $$
#
# **Equation 19.3**
# $$
# 변수 해석 어려움
# $$
#
# **Equation 19.4**
# $$
# 회귀 계수 불안정
# $$
#
# ![slide19-image1](data:image/png;base64,...)
# ![slide19-image2](data:image/png;base64,...)
# ![slide19-image3](data:image/png;base64,...)
# ![slide19-image4](data:image/png;base64,...)
# ![slide19-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 20: (Untitled)
#
# - 8
# - 다중공선성
# - 2) VIF(Variance Inflation Factor)
# - : 독립 변수 j 를 나머지 독립 변수로 회귀했을 때
# - 진단 방법
# - 1) 상관계수 행렬
# - 상관계수 이면 다중공선성 의심
# - 두 변수 간 상관성만 보기 때문에 제한적
# - 값이 5~10 이면 다중공선성 의심
# - 값이 ≥ 10 이면 심각한 다중공선성
#
# **Equation 20.1**
# $$
# 𝑉𝐼𝐹𝑗=11−𝑅𝑗2
# $$
#
# **Equation 20.2**
# $$
# 𝑅𝑗2
# $$
#
# **Equation 20.3**
# $$
# 𝑅2
# $$
#
# **Equation 20.4**
# $$
# 𝑟>0.8
# $$
#
# **Equation 20.5**
# $$
# 𝑉𝐼𝐹
# $$
#
# **Equation 20.6**
# $$
# 𝑉𝐼𝐹
# $$
#
# **Equation 20.7**
# $$
# 𝑉𝐼𝐹𝑗=11−𝑅𝑗2
# $$
#
# ![slide20-image1](data:image/png;base64,...)
# ![slide20-image2](data:image/png;base64,...)
# ![slide20-image3](data:image/png;base64,...)
# ![slide20-image4](data:image/png;base64,...)
# ![slide20-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 21: (Untitled)
#
# - 8
# - 다중공선성
# - 차원 축소: 주성분 분석(PCA), PLS 회귀 등으로 상관 줄이기
# - 회귀계수 규제: Ridge, Lasso
# - 대응 방법
# - 합
#
# **Equation 21.1**
# $$
# 변수 제거 : 𝑉𝐼𝐹𝑗 가 높은 변수를 제거
# $$
#
# **Equation 21.2**
# $$
# 변수 결
# $$
#
# **Equation 21.3**
# $$
# 변수 제거 : 𝑉𝐼𝐹𝑗 가 높은 변수를 제거
# $$
#
# ![slide21-image1](data:image/png;base64,...)
# ![slide21-image2](data:image/png;base64,...)
# ![slide21-image3](data:image/png;base64,...)

# %% [markdown]
# ### Slide 22: (Untitled)
#
# - 9
# - 이상점과 영향점
# - 이상점(Outlier)
# - 영향점(Influential Point)
#
# **Equation 22.1**
# $$
# 다른 데이터들과 현저히 다른 값을 가진 관측값
# $$
#
# **Equation 22.2**
# $$
# 회귀 모델에 포함될 경우 회귀 계수에 영향을 주는 점
# $$
#
# **Equation 22.3**
# $$
# 다른 데이터들과 현저히 다른 값을 가진 관측값
# $$
#
# **Equation 22.4**
# $$
# 회귀 모델에 포함될 경우 회귀 계수에 영향을 주는 점
# $$
#
# ![slide22-image1](data:image/png;base64,...)
# ![slide22-image2](data:image/png;base64,...)
# ![slide22-image3](data:image/png;base64,...)
# ![slide22-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 23: (Untitled)
#
# - 9
# - 이상점과 영향점
# - 영향점 판단 지표
# - 지표
# - 의미
# - 공식
# - 지렛값
# - (Leverage)
# - 관측값 i 의 독립 변수가 얼마나 떨어져
# - 회귀선의 위치와 기울기를 끌어당기는지 나타냄
# - t-표준화 잔차
# - (Studentized Residual)
# - n-k-1 자유도의 t-분포를 따름
# - 가설검정을 통한 영향점 판단
# - 지표
# - 의미
# - 공식
# - 지렛값
# - (Leverage)
# - t-표준화 잔차
# - (Studentized Residual)
# - n-k-1 자유도의 t-분포를 따름
# - 가설검정을 통한 영향점 판단
# - : 를 제외한 회귀모델의 오차제곱합
#
# **Table 23.1**
# | 지표 | 의미 | 공식 |
# | --- | --- | --- |
# | 지렛값
# (Leverage) | 관측값 i 의 독립 변수가 얼마나 떨어져
# 회귀선의 위치와 기울기를 끌어당기는지 나타냄 |   |
# | t-표준화 잔차
# (Studentized Residual) | n-k-1 자유도의 t-분포를 따름
# 가설검정을 통한 영향점 판단 |   |
#
# **Table 23.2**
# | 지표 | 의미 | 공식 |
# | --- | --- | --- |
# | 지렛값
# (Leverage) |   |   |
# | t-표준화 잔차
# (Studentized Residual) | n-k-1 자유도의 t-분포를 따름
# 가설검정을 통한 영향점 판단 |   |
#
# **Equation 23.1**
# $$
# MSE(−𝑖)=𝑆𝑆𝐸(−𝑖)𝑛−𝑘−1
# $$
#
# **Equation 23.2**
# $$
# 0<h𝑖𝑖<1
# $$
#
# **Equation 23.3**
# $$
# h𝑖𝑖=𝑥𝑖𝑇𝑋𝑇𝑋−1𝑥𝑖
# $$
#
# **Equation 23.4**
# $$
# 𝑡𝑖=𝑒𝑖𝑀𝑆𝐸(−𝑖)(1−h𝑖𝑖)
# $$
#
# **Equation 23.5**
# $$
# 𝑆𝑆𝐸(−𝑖)
# $$
#
# **Equation 23.6**
# $$
# 𝑖
# $$
#
# **Equation 23.7**
# $$
# MSE(−𝑖)=𝑆𝑆𝐸(−𝑖)𝑛−𝑘−1
# $$
#
# **Equation 23.8**
# $$
# 0<h𝑖𝑖<1
# $$
#
# **Equation 23.9**
# $$
# h𝑖𝑖=𝑥𝑖𝑇𝑋𝑇𝑋−1𝑥𝑖
# $$
#
# **Equation 23.10**
# $$
# 𝑡𝑖=𝑒𝑖𝑀𝑆𝐸(−𝑖)(1−h𝑖𝑖)
# $$
#
# ![slide23-image1](data:image/png;base64,...)
# ![slide23-image2](data:image/png;base64,...)
# ![slide23-image3](data:image/png;base64,...)
# ![slide23-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 24: (Untitled)
#
# - 9
# - 이상점과 영향점
# - 지표
# - 의미
# - 공식
# - DFFITS
# - 관측값이 예측값에 영향을 주는 정도
# - DFBETAS
# - 관측값이 회귀 계수에 영향을 주는 정도
# - 지표
# - 의미
# - 공식
# - DFFITS
# - 관측값이 예측값에 영향을 주는 정도
# - DFBETAS
# - 관측값이 회귀 계수에 영향을 주는 정도
# - : 를 제외한 회귀모델의 의 예측값
# - : 를 제외한 회귀모델의 의 추정값
# - : j 번째 대각원소
# - 영향점 판단 지표
# - : 를 제외한 회귀모델의 오차제곱합
#
# **Table 24.1**
# | 지표 | 의미 | 공식 |
# | --- | --- | --- |
# | DFFITS | 관측값이 예측값에 영향을 주는 정도 |   |
# | DFBETAS | 관측값이 회귀 계수에 영향을 주는 정도 |   |
#
# **Table 24.2**
# | 지표 | 의미 | 공식 |
# | --- | --- | --- |
# | DFFITS | 관측값이 예측값에 영향을 주는 정도 |   |
# | DFBETAS | 관측값이 회귀 계수에 영향을 주는 정도 |   |
#
# **Equation 24.1**
# $$
# 𝐷𝐹𝐹𝐼𝑇𝑆𝑖=𝑦𝑖−𝑦𝑖(−𝑖)𝑀𝑆𝐸(−𝑖)h𝑖𝑖
# $$
#
# **Equation 24.2**
# $$
# 𝐷𝐹𝐵𝐸𝑇𝐴𝑆𝑖𝑗=𝑒𝑖𝑀𝑆𝐸(−𝑖)𝑋𝑇𝑋−1𝑗𝑗
# $$
#
# **Equation 24.3**
# $$
# 𝑦𝑖(−𝑖)
# $$
#
# **Equation 24.4**
# $$
# 𝑖
# $$
#
# **Equation 24.5**
# $$
# 𝑦𝑖
# $$
#
# **Equation 24.6**
# $$
# 𝛽𝑗(−𝑖)
# $$
#
# **Equation 24.7**
# $$
# 𝑖
# $$
#
# **Equation 24.8**
# $$
# 𝛽𝑗
# $$
#
# **Equation 24.9**
# $$
# ∙𝑗𝑗
# $$
#
# **Equation 24.10**
# $$
# MSE(−𝑖)=𝑆𝑆𝐸(−𝑖)𝑛−𝑘−1
# $$
#
# **Equation 24.11**
# $$
# 𝑆𝑆𝐸(−𝑖)
# $$
#
# **Equation 24.12**
# $$
# 𝑖
# $$
#
# **Equation 24.13**
# $$
# 𝐷𝐹𝐹𝐼𝑇𝑆𝑖=𝑦𝑖−𝑦𝑖(−𝑖)𝑀𝑆𝐸(−𝑖)h𝑖𝑖
# $$
#
# **Equation 24.14**
# $$
# 𝐷𝐹𝐵𝐸𝑇𝐴𝑆𝑖𝑗=𝑒𝑖𝑀𝑆𝐸(−𝑖)𝑋𝑇𝑋−1𝑗𝑗
# $$
#
# **Equation 24.15**
# $$
# MSE(−𝑖)=𝑆𝑆𝐸(−𝑖)𝑛−𝑘−1
# $$
#
# ![slide24-image1](data:image/png;base64,...)
# ![slide24-image2](data:image/png;base64,...)
# ![slide24-image3](data:image/png;base64,...)
# ![slide24-image4](data:image/png;base64,...)
# ![slide24-image5](data:image/png;base64,...)
# ![slide24-image6](data:image/png;base64,...)
# ![slide24-image7](data:image/png;base64,...)

# %% [markdown]
# ### Slide 25: (Untitled)
#
# - 로지스틱 회귀
# - 10
# - 로지스틱 회귀
# - 를 추정
# - 로짓 함수(Logit Function): 확률(p)을 전체 실수 영역으로 변환
# - 로지스틱 함수(Logistic Function): 로짓을 로 변환
# - 종속변수(Y)가 0 또는 1 이진형 변수
#
# **Equation 25.1**
# $$
# 𝑝=𝑃(𝑌=1)
# $$
#
# **Equation 25.2**
# $$
# 𝑝
# $$
#
# **Equation 25.3**
# $$
# 𝑝=𝜎(𝑍)=11+𝑒−𝑍
# $$
#
# **Equation 25.4**
# $$
# Logit𝑝=log𝑝1−𝑝=𝑍=𝛽0+𝛽1𝑋1+…+𝛽𝑝𝑋𝑝
# $$
#
# **Equation 25.5**
# $$
# 𝑝=𝜎(𝑍)=11+𝑒−𝑍
# $$
#
# **Equation 25.6**
# $$
# Logit𝑝=log𝑝1−𝑝=𝑍=𝛽0+𝛽1𝑋1+…+𝛽𝑝𝑋𝑝
# $$
#
# ![slide25-image1](data:image/png;base64,...)
# ![slide25-image2](data:image/png;base64,...)
# ![slide25-image3](data:image/png;base64,...)
# ![slide25-image4](data:image/png;base64,...)
# ![slide25-image5](data:image/png;base64,...)
# ![slide25-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 26: (Untitled)
#
# - 10
# - 로지스틱 회귀
# - 최대 우도 추정(Maximum Likelihood Estimation)
# - 절편은 모든 변수가 1 인 상수항을 추가하여 처리
# - 해석적 방법으로는 불가
# - 추정 방법
#
# **Equation 26.1**
# $$
# 𝑃𝑌=1𝑋=𝐱𝐢=𝜎𝑧𝑖=11+𝑒−𝑧𝑖
# $$
#
# **Equation 26.2**
# $$
# ,𝑤h𝑒𝑟𝑒 𝑧𝑖=𝛃𝐱𝑖
# $$
#
# **Equation 26.3**
# $$
# 𝐿(𝛃)=𝑖=1𝑛𝜎𝑧𝑖𝑦𝑖1−𝜎𝑧𝑖1−𝑦𝑖
# $$
#
# **Equation 26.4**
# $$
# 𝑃𝑌=𝑦𝑖𝑋=𝐱𝑖=𝜎𝑧𝑖𝑦𝑖1−𝜎𝑧𝑖1−𝑦𝑖
# $$
#
# **Equation 26.5**
# $$
# log⁡𝐿(𝛃)=𝑖=1𝑛𝑦𝑖log𝜎𝑧𝑖+1−𝑦𝑖log1−𝜎𝑧𝑖
# $$
#
# **Equation 26.6**
# $$
# 𝛃=argmax𝛽𝐿(𝛽)
# $$
#
# **Equation 26.7**
# $$
# 𝑃𝑌=1𝑋=𝐱=𝜎𝑧=11+𝑒−𝑧
# $$
#
# **Equation 26.8**
# $$
# ,𝑤h𝑒𝑟𝑒 𝑧=𝛽0+𝛽1𝑥𝑖+…+𝛽𝑝𝑥𝑝
# $$
#
# **Equation 26.9**
# $$
# 𝑃𝑌=1𝑋=𝐱𝐢=𝜎𝑧𝑖=11+𝑒−𝑧𝑖
# $$
#
# **Equation 26.10**
# $$
# ,𝑤h𝑒𝑟𝑒 𝑧𝑖=𝛃𝐱𝑖
# $$
#
# **Equation 26.11**
# $$
# 𝐿(𝛃)=𝑖=1𝑛𝜎𝑧𝑖𝑦𝑖1−𝜎𝑧𝑖1−𝑦𝑖
# $$
#
# **Equation 26.12**
# $$
# 𝑃𝑌=𝑦𝑖𝑋=𝐱𝑖=𝜎𝑧𝑖𝑦𝑖1−𝜎𝑧𝑖1−𝑦𝑖
# $$
#
# **Equation 26.13**
# $$
# log⁡𝐿(𝛃)=𝑖=1𝑛𝑦𝑖log𝜎𝑧𝑖+1−𝑦𝑖log1−𝜎𝑧𝑖
# $$
#
# **Equation 26.14**
# $$
# 𝛃=argmax𝛽𝐿(𝛽)
# $$
#
# **Equation 26.15**
# $$
# 𝑃𝑌=1𝑋=𝐱=𝜎𝑧=11+𝑒−𝑧
# $$
#
# **Equation 26.16**
# $$
# ,𝑤h𝑒𝑟𝑒 𝑧=𝛽0+𝛽1𝑥𝑖+…+𝛽𝑝𝑥𝑝
# $$
#
# ![slide26-image1](data:image/png;base64,...)
# ![slide26-image2](data:image/png;base64,...)
# ![slide26-image3](data:image/png;base64,...)
# ![slide26-image4](data:image/png;base64,...)
# ![slide26-image5](data:image/png;base64,...)
# ![slide26-image6](data:image/png;base64,...)
# ![slide26-image7](data:image/png;base64,...)
# ![slide26-image8](data:image/png;base64,...)
# ![slide26-image9](data:image/png;base64,...)

# %% [markdown]
# ### Slide 27: (Untitled)
#
# - 회귀 계수의 해석
# - 10
# - 로지스틱 회귀
# - 종속변수 가 1 증가할 때 승산(odd)의 변화율
# - 승산비
#
# **Equation 27.1**
# $$
# 𝑋𝑗
# $$
#
# **Equation 27.2**
# $$
# Logit𝑝=log𝑝1−𝑝=𝛽0+𝛽1𝑋1+…+𝛽𝑝𝑋𝑝
# $$
#
# **Equation 27.3**
# $$
# =exp⁡(𝛽0+𝛽1𝑋1+…+𝛽𝑗(𝑋𝑗+1)+…+𝛽𝑝𝑋𝑝) exp⁡(𝛽0+𝛽1𝑋1+…+𝛽𝑗𝑋𝑗+…+𝛽𝑝𝑋𝑝)
# $$
#
# **Equation 27.4**
# $$
# =𝑒𝛽𝑗
# $$
#
# **Equation 27.5**
# $$
# Logit𝑝=log𝑝1−𝑝=𝛽0+𝛽1𝑋1+…+𝛽𝑝𝑋𝑝
# $$
#
# **Equation 27.6**
# $$
# =exp⁡(𝛽0+𝛽1𝑋1+…+𝛽𝑗(𝑋𝑗+1)+…+𝛽𝑝𝑋𝑝) exp⁡(𝛽0+𝛽1𝑋1+…+𝛽𝑗𝑋𝑗+…+𝛽𝑝𝑋𝑝)
# $$
#
# **Equation 27.7**
# $$
# =𝑒𝛽𝑗
# $$
#
# ![slide27-image1](data:image/png;base64,...)
# ![slide27-image2](data:image/png;base64,...)
# ![slide27-image3](data:image/png;base64,...)
# ![slide27-image4](data:image/png;base64,...)
# ![slide27-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 28: (Untitled)
#
# - Soft max 회귀
# - One-vs-Rest
# - One-vs-One
# - 방법
# - 클래스별 확률을 Softmax 함수로 계산
# - 하나의 클래스 vs 나머지 K 개의
# 이진 로지스틱 회귀 모델 생성
# - 가장 확률이 높은 클래스 선택
# - K 개의 클래스에 대해 개의
# 이진 분류기 생성
# - 다수결 투표 방식으로 예측
# - 장점
# - 이론적으로 정밀도가 높음
# - 클래스 간 관계를 반영
# - 단순하고 구현이 쉬움
# - 복잡한 경계 학습 가능
# - 단점
# - 계산 복잡도 증가
# - 편향된 결과
# - 계산 복잡도의 증가
# - 전체 확률 추정 어려움
# - Soft max 회귀
# - One-vs-Rest
# - One-vs-One
# - 방법
# - 하나의 클래스 vs 나머지 K 개의
# 이진 로지스틱 회귀 모델 생성
# - 가장 확률이 높은 클래스 선택
# - 장점
# - 이론적으로 정밀도가 높음
# - 클래스 간 관계를 반영
# - 단순하고 구현이 쉬움
# - 복잡한 경계 학습 가능
# - 단점
# - 계산 복잡도 증가
# - 편향된 결과
# - 계산 복잡도의 증가
# - 전체 확률 추정 어려움
# - 다중 클래스에 적용
# - 10
# - 로지스틱 회귀
#
# **Table 28.1**
# |   | Soft max 회귀 | One-vs-Rest | One-vs-One |
# | --- | --- | --- | --- |
# | 방법 | 클래스별 확률을 Softmax 함수로 계산 | 하나의 클래스 vs 나머지 K 개의
# 이진 로지스틱 회귀 모델 생성
# 가장 확률이 높은 클래스 선택 | K 개의 클래스에 대해 개의
# 이진 분류기 생성
# 다수결 투표 방식으로 예측 |
# | 장점 | 이론적으로 정밀도가 높음
# 클래스 간 관계를 반영 | 단순하고 구현이 쉬움 | 복잡한 경계 학습 가능 |
# | 단점 | 계산 복잡도 증가 | 편향된 결과 | 계산 복잡도의 증가
# 전체 확률 추정 어려움 |
#
# **Table 28.2**
# |   | Soft max 회귀 | One-vs-Rest | One-vs-One |
# | --- | --- | --- | --- |
# | 방법 |   | 하나의 클래스 vs 나머지 K 개의
# 이진 로지스틱 회귀 모델 생성
# 가장 확률이 높은 클래스 선택 |   |
# | 장점 | 이론적으로 정밀도가 높음
# 클래스 간 관계를 반영 | 단순하고 구현이 쉬움 | 복잡한 경계 학습 가능 |
# | 단점 | 계산 복잡도 증가 | 편향된 결과 | 계산 복잡도의 증가
# 전체 확률 추정 어려움 |
#
# **Equation 28.1**
# $$
# 𝑃𝑦=𝑘𝐱=𝑒𝛽𝑘𝑇𝐱𝑗=1𝐾𝑒𝛽𝑗𝑇𝐱
# $$
#
# **Equation 28.2**
# $$
# 𝐾(𝐾−1)2
# $$
#
# ![slide28-image1](data:image/png;base64,...)
# ![slide28-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 29: (Untitled)
#
# - Ex) Softmax 방식과 OVR 방식의 차이
# - 10
# - 로지스틱 회귀
# - 출처: https://scikit-learn.org/stable/auto_examples/linear_model/plot_logistic_multinomial.html
#
# ![slide29-image1](data:image/png;base64,...)
# ![slide29-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 30: (Untitled)
#
# - 11
# - 문제 풀이
# - Q1. 우측은 집값(price)과 면적(area), 준공시점(age),
# - 조명의 수(lights)와 의 선형회귀 모델을 통한
# - 분석 결과이다. 다음 중 적합한 분석은?
# - 선형회귀 모델의 유의미성에 대한 검정의 검정 통계량은 908.0 이다.
# - 1
# - 조명의 수는 집값과 밀접한 관련이 있다.
# - 2
# - 집값과 면적은 상관이 없다.
# - 3
# - 준공시점이 1 년 지남에 따라 집값은 평균 0.7397 줄어든다.
# - 4
#
# ![slide30-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 31: (Untitled)
#
# - 11
# - 문제 풀이
# - 4
# - 1) F-statistic: 408.5
# - 2) 회귀 계수 검정(H0: 회귀계수 = 0, H1: 회귀계수≠0) P-value(P > |t|) 가 0.181
# - 3) 회귀 계수 검정 P-value(P > |t|) 가 0 4) age 의 회귀 계수가 -0.7397
# - Q1. 우측은 집값(price)과 면적(area), 준공시점(age),
# - 조명의 수(lights)과의 선형회귀 모델을 통한
# - 분석 결과이다. 다음 중 적합한 분석은?
# - 선형회귀 모델의 유의미성에 대한 검정의 검정 통계량은 908.0 이다.
# - 1
# - 조명의 수는 집값과 밀접한 관련이 있다.
# - 2
# - 집값과 면적은 상관이 없다.
# - 3
# - 준공시점이 1 년 지남에 따라 집값은 평균 0.7397 줄어든다.
#
# ![slide31-image1](data:image/png;base64,...)
# ![slide31-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 32: (Untitled)
#
# - 회귀 계수와 종속 변수 사이에는 선형적인 관계가 존재해야 한다.
# - 1
# - 오차(잔차)는 서로 독립이고 평균이 0 인 정규분포를 따라야 한다.
# - 2
# - 독립 변수 간의 강한 다중공선성은 표준화 처리를 통해 완화시킬 수 있다.
# - 3
# - 오차의 분산은 모든 수준의 독립 변수에서 일정해야 한다.
# - 4
# - Q2. 다음 중 선형회귀 분석에 대한 설명으로 틀린 것은?
# - 11
# - 문제 풀이

# %% [markdown]
# ### Slide 33: (Untitled)
#
# - 3
# - Q2. 다음 중 선형회귀 분석에 대한 설명으로 틀린 것은?
# - 11
# - 문제 풀이
# - 3) 강한 다중 공선성은 설명력에 악영향을 주고, 표준화는 조치 방법으로 부적합합니다.
# - 차원 축소, 규제, 변수 제외 등이 유효합니다.
# - 회귀 계수와 종속 변수 사이에는 선형적인 관계가 존재해야 한다.
# - 1
# - 오차(잔차)는 서로 독립이고 평균이 0 인 정규분포를 따라야 한다.
# - 2
# - 독립 변수 간의 강한 다중공선성은 표준화 처리를 통해 완화시킬 수 있다.
# - 오차의 분산은 모든 수준의 독립 변수에서 일정해야 한다.
# - 4
#
# ![slide33-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 34: (Untitled)
#
# - Q3. 다음 중 로지스틱 회귀 분석에 대한 설명으로 올바른 것은?
# - 11
# - 문제 풀이
# - 1
# - 2
# - 3
# - 4
# - 로지스틱 회귀 모델의 계수가 𝛽 일때, 해당 독립 변수가 1 증가할 때의 승산의 증가율 은 이다.
# - 로지스틱 함수는 로짓을 로 변환시키는 링크 함수이다.
# - 다중 클래스 로지스틱 회귀 함수는 로짓 함수를 통해 확률을 계산한다.
# - 다중 클래스 분류 때, One-vs-Rest 방식은 클래스 간의 상호 작용을 잘 반영한다.
#
# **Equation 34.1**
# $$
# e𝛽
# $$
#
# **Equation 34.2**
# $$
# −∞, +∞
# $$
#
# ![slide34-image1](data:image/png;base64,...)
# ![slide34-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 35: (Untitled)
#
# - 1
# - Q3. 다음 중 로지스틱 회귀 분석에 대한 설명으로 올바른 것은?
# - 11
# - 문제 풀이
# - 1)
# - 2
# - 3
# - 4
# - 로지스틱 회귀 모델의 계수가 𝛽 일때, 해당 독립 변수가 1 증가할 때의 승산의 증가율 은 이다.
# - 로지스틱 함수는 로짓을 로 변환시키는 링크 함수이다.
# - 다중 클래스 로지스틱 회귀 함수는 로짓 함수를 통해 확률을 계산한다.
# - 다중 클래스 분류 때, One-vs-Rest 방식은 클래스 간의 상호 작용을 잘 반영한다.
#
# **Equation 35.1**
# $$
# Logit𝑝=log𝑝1−𝑝=𝛽0+𝛽1𝑋1+…+𝛽𝑝𝑋𝑝,
# $$
#
# **Equation 35.2**
# $$
# exp⁡(𝛽0+𝛽1𝑋1+…+𝛽𝑗(𝑋𝑗+1)+…+𝛽𝑝𝑋𝑝) exp⁡(𝛽0+𝛽1𝑋1+…+𝛽𝑗𝑋𝑗+…+𝛽𝑝𝑋𝑝) =𝑒𝛽
# $$
#
# **Equation 35.3**
# $$
# e𝛽
# $$
#
# **Equation 35.4**
# $$
# −∞, +∞
# $$
#
# **Equation 35.5**
# $$
# Logit𝑝=log𝑝1−𝑝=𝛽0+𝛽1𝑋1+…+𝛽𝑝𝑋𝑝,
# $$
#
# ![slide35-image1](data:image/png;base64,...)
# ![slide35-image2](data:image/png;base64,...)
# ![slide35-image3](data:image/png;base64,...)

# %% [markdown]
# ### Slide 36: (Untitled)
#
# - # 선형 회귀 모델
# - # 최소제곱법
# - # 정규방정식
# - # 유의미성 검정
# - # 이상점과 영향점
# - # 로지스틱 회귀
# - 추후 디자인하여 PSD 로 편집될 영역입니다.
