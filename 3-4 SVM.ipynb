# %% [markdown]
# # PPT → Markdown (v3: Better Text Joining + Tables + Equations)
#
# **Source**: `[14차시] LV3_3-4 SVM_0905수정.pptx`
#
# 개선 사항:
# - **폰트/스타일로 분리된 run들을 문장 단위로 매끄럽게 연결**
# - 줄바꿈(br) 보존, 불필요한 공백 정리, 소프트 하이픈 제거
# - bullet(기본) 감지 후 접두사 적용
# - 기존 이미지/테이블/수식/헤더 로직 그대로 유지

# %% [markdown]
# ### Slide 1: (Untitled)
#
# - 14. SVM

# %% [markdown]
# ### Slide 2: (Untitled)
#
# - 1
# - 선형 마진 분류기(Linear Discriminant)
# - 선형 함수를 이용한 클래스 분류 모델
# - 상수
#
# **Equation 2.1**
# $$
# 𝑓(𝐱𝐢)=𝐰𝑇𝐱𝐢+𝑏
# $$
#
# **Equation 2.2**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑘
# $$
#
# **Equation 2.3**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑘
# $$
#
# **Equation 2.4**
# $$
# 𝑏 :
# $$
#
# **Equation 2.5**
# $$
# 𝑦𝑖=𝑠𝑖𝑔𝑛𝑦𝑖=𝑖𝑓 𝑓(𝐱𝐢)≥0, 1𝑖𝑓 𝑓(𝐱𝐢)<0, −1
# $$
#
# **Equation 2.6**
# $$
# 𝑦𝑖∈{−1, 1}
# $$
#
# **Equation 2.7**
# $$
# 𝑓(𝐱𝐢)=𝐰𝑇𝐱𝐢+𝑏
# $$
#
# **Equation 2.8**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑘
# $$
#
# **Equation 2.9**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑘
# $$
#
# **Equation 2.10**
# $$
# 𝑦𝑖=𝑠𝑖𝑔𝑛𝑦𝑖=𝑖𝑓 𝑓(𝐱𝐢)≥0, 1𝑖𝑓 𝑓(𝐱𝐢)<0, −1
# $$
#
# **Equation 2.11**
# $$
# 𝑦𝑖∈{−1, 1}
# $$
#
# ![slide2-image1](data:image/png;base64,...)
# ![slide2-image2](data:image/png;base64,...)
# ![slide2-image3](data:image/png;base64,...)
# ![slide2-image4](data:image/png;base64,...)
# ![slide2-image5](data:image/png;base64,...)
# ![slide2-image6](data:image/png;base64,...)
# ![slide2-image7](data:image/png;base64,...)

# %% [markdown]
# ### Slide 3: (Untitled)
#
# - 1
# - 선형 마진 분류기(Linear Discriminant)
# - 학습: 최대 마진 분류
# - 상수
# - 를 찾는 것
# - 모든 에 대해,
# - 기하학적 마진을 최대화하는
#
# **Equation 3.1**
# $$
# 𝑓(𝐱𝐢)=𝐰𝑇𝐱𝑖+𝑏
# $$
#
# **Equation 3.2**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑘
# $$
#
# **Equation 3.3**
# $$
# 𝐱𝑖=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑘
# $$
#
# **Equation 3.4**
# $$
# 𝑏 :
# $$
#
# **Equation 3.5**
# $$
# 𝑖𝑓 𝑦𝑖=1,𝐰𝑇𝐱𝑖+𝑏≥1
# $$
#
# **Equation 3.6**
# $$
# 𝑖𝑓 𝑦𝑖=−1,𝐰𝑇𝐱𝑖+𝑏≤−1
# $$
#
# **Equation 3.7**
# $$
# 𝐰,𝑏
# $$
#
# **Equation 3.8**
# $$
# 𝑖
# $$
#
# **Equation 3.9**
# $$
# 𝑓(𝐱𝐢)=𝐰𝑇𝐱𝑖+𝑏
# $$
#
# **Equation 3.10**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑘
# $$
#
# **Equation 3.11**
# $$
# 𝐱𝑖=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑘
# $$
#
# **Equation 3.12**
# $$
# 𝑖𝑓 𝑦𝑖=1,𝐰𝑇𝐱𝑖+𝑏≥1
# $$
#
# **Equation 3.13**
# $$
# 𝑖𝑓 𝑦𝑖=−1,𝐰𝑇𝐱𝑖+𝑏≤−1
# $$
#
# ![slide3-image1](data:image/png;base64,...)
# ![slide3-image2](data:image/png;base64,...)
# ![slide3-image3](data:image/png;base64,...)
# ![slide3-image4](data:image/png;base64,...)
# ![slide3-image5](data:image/png;base64,...)
# ![slide3-image6](data:image/png;base64,...)
# ![slide3-image7](data:image/png;base64,...)
# ![slide3-image8](data:image/png;base64,...)
# ![slide3-image9](data:image/png;base64,...)

# %% [markdown]
# ### Slide 4: (Untitled)
#
# - 최대 마진 분류
# - 기하학적 마진
# - 유도 과정
# - λ: 기하학적 마진
# - 는 두 평면에 수직인 벡터에서,
# - 아래와 같은 관계를 지님
# - 2
#
# **Equation 4.1**
# $$
# 𝐰𝑇𝐱+𝑏=1
# $$
#
# **Equation 4.2**
# $$
# 𝐰𝑇𝐱+𝑏=−1
# $$
#
# **Equation 4.3**
# $$
# 2𝐰𝑇𝐰
# $$
#
# **Equation 4.4**
# $$
# 𝐱+=𝐱−+𝜆𝐰
# $$
#
# **Equation 4.5**
# $$
# 𝐰
# $$
#
# **Equation 4.6**
# $$
# 𝐱+,𝐱−는
# $$
#
# **Equation 4.7**
# $$
# 𝐰𝑇𝐱++𝑏=1𝐰𝑇𝐱−+𝑏=−1
# $$
#
# **Equation 4.8**
# $$
# 𝐰𝑇(𝐱−+𝝀𝐰)+𝑏=1𝐰𝑇𝐱−+𝑏=−1
# $$
#
# **Equation 4.9**
# $$
# 𝒘𝑻𝒙−+𝝀𝐰𝐓𝐰+𝑏=1𝐰𝑇𝐱−+𝑏=−1
# $$
#
# **Equation 4.10**
# $$
# 𝜆=2𝐰𝑇𝐰
# $$
#
# **Equation 4.11**
# $$
# 𝐰𝑇𝐱+𝑏=1
# $$
#
# **Equation 4.12**
# $$
# 𝐰𝑇𝐱+𝑏=−1
# $$
#
# **Equation 4.13**
# $$
# 2𝐰𝑇𝐰
# $$
#
# **Equation 4.14**
# $$
# 𝐱+=𝐱−+𝜆𝐰
# $$
#
# **Equation 4.15**
# $$
# 𝐰𝑇𝐱++𝑏=1𝐰𝑇𝐱−+𝑏=−1
# $$
#
# **Equation 4.16**
# $$
# 𝐰𝑇(𝐱−+𝝀𝐰)+𝑏=1𝐰𝑇𝐱−+𝑏=−1
# $$
#
# **Equation 4.17**
# $$
# 𝒘𝑻𝒙−+𝝀𝐰𝐓𝐰+𝑏=1𝐰𝑇𝐱−+𝑏=−1
# $$
#
# **Equation 4.18**
# $$
# 𝜆=2𝐰𝑇𝐰
# $$
#
# ![slide4-image1](data:image/png;base64,...)
# ![slide4-image2](data:image/png;base64,...)
# ![slide4-image3](data:image/png;base64,...)
# ![slide4-image4](data:image/png;base64,...)
# ![slide4-image5](data:image/png;base64,...)
# ![slide4-image6](data:image/png;base64,...)
# ![slide4-image7](data:image/png;base64,...)
# ![slide4-image8](data:image/png;base64,...)
# ![slide4-image9](data:image/png;base64,...)
# ![slide4-image10](data:image/png;base64,...)
# ![slide4-image11](data:image/png;base64,...)

# %% [markdown]
# ### Slide 5: (Untitled)
#
# - 최대 마진 분류
# - 2
# - 선형 분류기 학습: 최대 마진 분류
# - 모든 에 대해,
# - 기하학적 마진을 최대화하는 찾는 것
# - 를 최소화하는 를 찾는 것
# - 를 최대화하는 를 찾는 것
#
# **Equation 5.1**
# $$
# 𝑖
# $$
#
# **Equation 5.2**
# $$
# 𝐰,b를
# $$
#
# **Equation 5.3**
# $$
# 𝑖𝑓 𝑦𝑖=1,𝐰𝑇𝐱𝐢+𝑏≥1
# $$
#
# **Equation 5.4**
# $$
# 𝑖𝑓 𝑦𝑖=−1,𝐰𝑇𝐱𝐢+𝑏<−1
# $$
#
# **Equation 5.5**
# $$
# 𝑦𝑖𝐰𝑇𝐱𝐢+𝑏−1≥0
# $$
#
# **Equation 5.6**
# $$
# 12𝐰𝑇𝐰
# $$
#
# **Equation 5.7**
# $$
# 𝐰,b
# $$
#
# **Equation 5.8**
# $$
# 2𝐰𝑇𝐰
# $$
#
# **Equation 5.9**
# $$
# 𝐰,b
# $$
#
# **Equation 5.10**
# $$
# 𝑖𝑓 𝑦𝑖=1,𝐰𝑇𝐱𝐢+𝑏≥1
# $$
#
# **Equation 5.11**
# $$
# 𝑖𝑓 𝑦𝑖=−1,𝐰𝑇𝐱𝐢+𝑏<−1
# $$
#
# **Equation 5.12**
# $$
# 𝑦𝑖𝐰𝑇𝐱𝐢+𝑏−1≥0
# $$
#
# **Equation 5.13**
# $$
# 12𝐰𝑇𝐰
# $$
#
# **Equation 5.14**
# $$
# 2𝐰𝑇𝐰
# $$
#
# ![slide5-image1](data:image/png;base64,...)
# ![slide5-image2](data:image/png;base64,...)
# ![slide5-image3](data:image/png;base64,...)
# ![slide5-image4](data:image/png;base64,...)
# ![slide5-image5](data:image/png;base64,...)
# ![slide5-image6](data:image/png;base64,...)
# ![slide5-image7](data:image/png;base64,...)
# ![slide5-image8](data:image/png;base64,...)
# ![slide5-image9](data:image/png;base64,...)
# ![slide5-image10](data:image/png;base64,...)

# %% [markdown]
# ### Slide 6: (Untitled)
#
# - 최대 마진 분류
# - 모든 에 대해 일 때,
# - 를 최소화하는 를 찾는 것
# - 제약이 있는 최적화 문제의 해를 찾는 방법
# - 라그랑지안(Lagrangian) 승수법
# - 2
# - 선형 분류기 학습법: 최대 마진 분류
#
# **Equation 6.1**
# $$
# 𝑖
# $$
#
# **Equation 6.2**
# $$
# 𝑦𝑖(𝐰𝑇𝐱𝑖+𝑏)≥1
# $$
#
# **Equation 6.3**
# $$
# 𝐰,b
# $$
#
# **Equation 6.4**
# $$
# 12𝐰𝑇𝐰
# $$
#
# **Equation 6.5**
# $$
# 12𝐰𝑇𝐰
# $$
#
# ![slide6-image1](data:image/png;base64,...)
# ![slide6-image2](data:image/png;base64,...)
# ![slide6-image3](data:image/png;base64,...)
# ![slide6-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 7: (Untitled)
#
# - 최대 마진 분류
# - 라그랑지안(Lagrangian) 승수법
# - 2
# - 정상점(Stationary point)
# - 때,(
# - 최적점의(필요)조건
# - 라그랑지안 승수
# - 정상 조건(Stationarity)
# - 원 조건(Primal feasibility)
#
# **Equation 7.1**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝜽𝑓(𝛉)
# $$
#
# **Equation 7.2**
# $$
# h𝑖𝛉=0 일
# $$
#
# **Equation 7.3**
# $$
# 𝑖=1,…𝑚)
# $$
#
# **Equation 7.4**
# $$
# 𝐿𝛉, 𝛍=𝑓𝛉+𝛍,h(𝛉)
# $$
#
# **Equation 7.5**
# $$
# 𝛍=𝜇1𝜇2…𝜇𝑚
# $$
#
# **Equation 7.6**
# $$
# h(𝛉)=h1(𝛉)h2(𝛉)…h𝑚(𝛉)
# $$
#
# **Equation 7.7**
# $$
# 𝛉=𝜃1𝜃2…𝜃𝑛
# $$
#
# **Equation 7.8**
# $$
# 𝛻𝛉𝑓𝛉∗+𝛻𝛉𝛍,h(𝛉∗)=𝟎
# $$
#
# **Equation 7.9**
# $$
# h𝛉∗=𝟎
# $$
#
# **Equation 7.10**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝜽𝑓(𝛉)
# $$
#
# **Equation 7.11**
# $$
# 𝐿𝛉, 𝛍=𝑓𝛉+𝛍,h(𝛉)
# $$
#
# **Equation 7.12**
# $$
# 𝛍=𝜇1𝜇2…𝜇𝑚
# $$
#
# **Equation 7.13**
# $$
# h(𝛉)=h1(𝛉)h2(𝛉)…h𝑚(𝛉)
# $$
#
# **Equation 7.14**
# $$
# 𝛉=𝜃1𝜃2…𝜃𝑛
# $$
#
# **Equation 7.15**
# $$
# 𝛻𝛉𝑓𝛉∗+𝛻𝛉𝛍,h(𝛉∗)=𝟎
# $$
#
# **Equation 7.16**
# $$
# h𝛉∗=𝟎
# $$
#
# ![slide7-image1](data:image/png;base64,...)
# ![slide7-image2](data:image/png;base64,...)
# ![slide7-image3](data:image/png;base64,...)
# ![slide7-image4](data:image/png;base64,...)
# ![slide7-image5](data:image/png;base64,...)
# ![slide7-image6](data:image/png;base64,...)
# ![slide7-image7](data:image/png;base64,...)
# ![slide7-image8](data:image/png;base64,...)
# ![slide7-image9](data:image/png;base64,...)
# ![slide7-image10](data:image/png;base64,...)

# %% [markdown]
# ### Slide 8: (Untitled)
#
# - 최대 마진 분류
# - KKT(Karush-Kuhn-Turker) 조건
# - 2
# - 최대 마진 분류에서의 조건
# - 조건이 등호만으로 구성된 라그랑지안 승수법에 그대로 적용 불가능
# - KKT(Karush-Kuhn-Turker) 조건 적용
# - 충족을 한다면, 라그랑지안 승수법에 부등호 까지 적용할 수 있음
# - 일 때,(
# - 일 때,(
#
# **Equation 8.1**
# $$
# 𝑦𝑖𝐰𝑇𝐱𝐢+𝑏−1≥0
# $$
#
# **Equation 8.2**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝛉𝑓(𝛉)
# $$
#
# **Equation 8.3**
# $$
# 𝑔𝑖𝛉≤0
# $$
#
# **Equation 8.4**
# $$
# 𝑖=1,…𝑚)
# $$
#
# **Equation 8.5**
# $$
# h𝑖𝛉=0
# $$
#
# **Equation 8.6**
# $$
# 𝑖=1,…𝑛)
# $$
#
# **Equation 8.7**
# $$
# 𝝀=𝜆1𝜆2…𝜆𝑚
# $$
#
# **Equation 8.8**
# $$
# 𝑔(𝛉)=𝑔1(𝛉)𝑔2(𝛉)…𝑔𝑚(𝛉)
# $$
#
# **Equation 8.9**
# $$
# 𝛉=𝜃1𝜃2…𝜃𝑛
# $$
#
# **Equation 8.10**
# $$
# 𝛍=𝜇1𝜇2…𝜇𝑘
# $$
#
# **Equation 8.11**
# $$
# h(𝛉)=h1(𝛉)h2(𝛉)…h𝑘(𝛉)
# $$
#
# **Equation 8.12**
# $$
# 𝐿𝛉, 𝛌, 𝛍=𝑓𝐱+𝛌,𝑔(𝛉)+𝝁,h(𝛉)
# $$
#
# **Equation 8.13**
# $$
# 𝑦𝑖𝐰𝑇𝐱𝐢+𝑏−1≥0
# $$
#
# **Equation 8.14**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝛉𝑓(𝛉)
# $$
#
# **Equation 8.15**
# $$
# 𝝀=𝜆1𝜆2…𝜆𝑚
# $$
#
# **Equation 8.16**
# $$
# 𝑔(𝛉)=𝑔1(𝛉)𝑔2(𝛉)…𝑔𝑚(𝛉)
# $$
#
# **Equation 8.17**
# $$
# 𝛉=𝜃1𝜃2…𝜃𝑛
# $$
#
# **Equation 8.18**
# $$
# 𝛍=𝜇1𝜇2…𝜇𝑘
# $$
#
# **Equation 8.19**
# $$
# h(𝛉)=h1(𝛉)h2(𝛉)…h𝑘(𝛉)
# $$
#
# **Equation 8.20**
# $$
# 𝐿𝛉, 𝛌, 𝛍=𝑓𝐱+𝛌,𝑔(𝛉)+𝝁,h(𝛉)
# $$
#
# ![slide8-image1](data:image/png;base64,...)
# ![slide8-image2](data:image/png;base64,...)
# ![slide8-image3](data:image/png;base64,...)
# ![slide8-image4](data:image/png;base64,...)
# ![slide8-image5](data:image/png;base64,...)
# ![slide8-image6](data:image/png;base64,...)
# ![slide8-image7](data:image/png;base64,...)
# ![slide8-image8](data:image/png;base64,...)
# ![slide8-image9](data:image/png;base64,...)
# ![slide8-image10](data:image/png;base64,...)
# ![slide8-image11](data:image/png;base64,...)

# %% [markdown]
# ### Slide 9: (Untitled)
#
# - 최대 마진 분류
# - 2
# - 라그랑지안(Lagrangian) 승수법+KKT 조건
# - 원 조건(Primal feasibility)
# - 쌍대 조건(Dual feasibility)
# - 여부등 조건(Complementary slackness)
# - 일 때,(
# - 일 때,(
# - 정상 조건(Stationarity)
#
# **Equation 9.1**
# $$
# 𝛻𝐱𝑓𝐱∗+𝛻𝐱𝛌,𝑔(𝐱∗)+𝛻𝐱𝝁,h(𝐱∗)=𝟎
# $$
#
# **Equation 9.2**
# $$
# 𝑔𝐱∗≤𝟎
# $$
#
# **Equation 9.3**
# $$
# h𝐱∗=𝟎
# $$
#
# **Equation 9.4**
# $$
# 𝛌≥𝟎
# $$
#
# **Equation 9.5**
# $$
# 𝛌∘𝐠(𝐱∗)=0
# $$
#
# **Equation 9.6**
# $$
# 𝝀=𝜆1𝜆2…𝜆𝑚
# $$
#
# **Equation 9.7**
# $$
# 𝑔(𝛉)=𝑔1(𝛉)𝑔2(𝛉)…𝑔𝑚(𝛉)
# $$
#
# **Equation 9.8**
# $$
# 𝛉=𝜃1𝜃2…𝜃𝑛
# $$
#
# **Equation 9.9**
# $$
# 𝛍=𝜇1𝜇2…𝜇𝑘
# $$
#
# **Equation 9.10**
# $$
# h(𝛉)=h1(𝛉)h2(𝛉)…h𝑘(𝛉)
# $$
#
# **Equation 9.11**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝛉𝑓(𝛉)
# $$
#
# **Equation 9.12**
# $$
# 𝑔𝑖𝛉≤0
# $$
#
# **Equation 9.13**
# $$
# 𝑖=1,…𝑚)
# $$
#
# **Equation 9.14**
# $$
# h𝑖𝛉=0
# $$
#
# **Equation 9.15**
# $$
# 𝑖=1,…𝑛)
# $$
#
# **Equation 9.16**
# $$
# 𝐿𝛉, 𝜆=𝑓𝛉+𝛌,𝑔(𝛉)+𝝁,h(𝛉)
# $$
#
# **Equation 9.17**
# $$
# 𝛻𝐱𝑓𝐱∗+𝛻𝐱𝛌,𝑔(𝐱∗)+𝛻𝐱𝝁,h(𝐱∗)=𝟎
# $$
#
# **Equation 9.18**
# $$
# 𝑔𝐱∗≤𝟎
# $$
#
# **Equation 9.19**
# $$
# h𝐱∗=𝟎
# $$
#
# **Equation 9.20**
# $$
# 𝛌≥𝟎
# $$
#
# **Equation 9.21**
# $$
# 𝛌∘𝐠(𝐱∗)=0
# $$
#
# **Equation 9.22**
# $$
# 𝝀=𝜆1𝜆2…𝜆𝑚
# $$
#
# **Equation 9.23**
# $$
# 𝑔(𝛉)=𝑔1(𝛉)𝑔2(𝛉)…𝑔𝑚(𝛉)
# $$
#
# **Equation 9.24**
# $$
# 𝛉=𝜃1𝜃2…𝜃𝑛
# $$
#
# **Equation 9.25**
# $$
# 𝛍=𝜇1𝜇2…𝜇𝑘
# $$
#
# **Equation 9.26**
# $$
# h(𝛉)=h1(𝛉)h2(𝛉)…h𝑘(𝛉)
# $$
#
# **Equation 9.27**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝛉𝑓(𝛉)
# $$
#
# **Equation 9.28**
# $$
# 𝐿𝛉, 𝜆=𝑓𝛉+𝛌,𝑔(𝛉)+𝝁,h(𝛉)
# $$
#
# ![slide9-image1](data:image/png;base64,...)
# ![slide9-image2](data:image/png;base64,...)
# ![slide9-image3](data:image/png;base64,...)
# ![slide9-image4](data:image/png;base64,...)
# ![slide9-image5](data:image/png;base64,...)
# ![slide9-image6](data:image/png;base64,...)
# ![slide9-image7](data:image/png;base64,...)
# ![slide9-image8](data:image/png;base64,...)
# ![slide9-image9](data:image/png;base64,...)
# ![slide9-image10](data:image/png;base64,...)
# ![slide9-image11](data:image/png;base64,...)
# ![slide9-image12](data:image/png;base64,...)
# ![slide9-image13](data:image/png;base64,...)
# ![slide9-image14](data:image/png;base64,...)
# ![slide9-image15](data:image/png;base64,...)

# %% [markdown]
# ### Slide 10: (Untitled)
#
# - 최대 마진 분류
# - 2
# - 라그랑지안(Lagrangian) 승수법+KKT 조건 적용
# - 일 때,(
# - 일 때,(
# - 일 때,(
#
# **Equation 10.1**
# $$
# 𝐿𝐰, 𝑏, 𝛂=𝑓𝐱+𝛂,𝑔(𝐰,𝑏)
# $$
#
# **Equation 10.2**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 10.3**
# $$
# 𝑔𝑖𝐰,𝑏≤0
# $$
#
# **Equation 10.4**
# $$
# 𝑖=1,…𝑚)
# $$
#
# **Equation 10.5**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 10.6**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝐰,𝑏12𝐰𝑇𝐰
# $$
#
# **Equation 10.7**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 10.8**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 10.9**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝛉𝑓(𝛉)
# $$
#
# **Equation 10.10**
# $$
# 𝑔𝑖𝛉≤0
# $$
#
# **Equation 10.11**
# $$
# 𝑖=1,…𝑚)
# $$
#
# **Equation 10.12**
# $$
# h𝑖𝛉=0
# $$
#
# **Equation 10.13**
# $$
# 𝑖=1,…𝑛)
# $$
#
# **Equation 10.14**
# $$
# 𝐿𝛉, 𝜆=𝑓𝛉+𝛌,𝑔(𝛉)+𝝁,h(𝛉)
# $$
#
# **Equation 10.15**
# $$
# 𝝀=𝜆1𝜆2…𝜆𝑚
# $$
#
# **Equation 10.16**
# $$
# 𝑔(𝛉)=𝑔1(𝛉)𝑔2(𝛉)…𝑔𝑚(𝛉)
# $$
#
# **Equation 10.17**
# $$
# 𝛉=𝜃1𝜃2…𝜃𝑛
# $$
#
# **Equation 10.18**
# $$
# 𝛍=𝜇1𝜇2…𝜇𝑘
# $$
#
# **Equation 10.19**
# $$
# h(𝛉)=h1(𝛉)h2(𝛉)…h𝑘(𝛉)
# $$
#
# **Equation 10.20**
# $$
# 𝐿𝐰, 𝑏, 𝛂=𝑓𝐱+𝛂,𝑔(𝐰,𝑏)
# $$
#
# **Equation 10.21**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 10.22**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 10.23**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝐰,𝑏12𝐰𝑇𝐰
# $$
#
# **Equation 10.24**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 10.25**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 10.26**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝛉𝑓(𝛉)
# $$
#
# **Equation 10.27**
# $$
# 𝐿𝛉, 𝜆=𝑓𝛉+𝛌,𝑔(𝛉)+𝝁,h(𝛉)
# $$
#
# **Equation 10.28**
# $$
# 𝝀=𝜆1𝜆2…𝜆𝑚
# $$
#
# **Equation 10.29**
# $$
# 𝑔(𝛉)=𝑔1(𝛉)𝑔2(𝛉)…𝑔𝑚(𝛉)
# $$
#
# **Equation 10.30**
# $$
# 𝛉=𝜃1𝜃2…𝜃𝑛
# $$
#
# **Equation 10.31**
# $$
# 𝛍=𝜇1𝜇2…𝜇𝑘
# $$
#
# **Equation 10.32**
# $$
# h(𝛉)=h1(𝛉)h2(𝛉)…h𝑘(𝛉)
# $$
#
# ![slide10-image1](data:image/png;base64,...)
# ![slide10-image2](data:image/png;base64,...)
# ![slide10-image3](data:image/png;base64,...)
# ![slide10-image4](data:image/png;base64,...)
# ![slide10-image5](data:image/png;base64,...)
# ![slide10-image6](data:image/png;base64,...)
# ![slide10-image7](data:image/png;base64,...)
# ![slide10-image8](data:image/png;base64,...)
# ![slide10-image9](data:image/png;base64,...)
# ![slide10-image10](data:image/png;base64,...)
# ![slide10-image11](data:image/png;base64,...)
# ![slide10-image12](data:image/png;base64,...)
# ![slide10-image13](data:image/png;base64,...)
# ![slide10-image14](data:image/png;base64,...)
# ![slide10-image15](data:image/png;base64,...)
# ![slide10-image16](data:image/png;base64,...)
# ![slide10-image17](data:image/png;base64,...)

# %% [markdown]
# ### Slide 11: (Untitled)
#
# - 최대 마진 분류
# - 2
# - 라그랑지안(Lagrangian) 승수법+KKT 조건 적용
# - 일 때,(
# - 원 조건(Primal feasibility)
# - 쌍대 조건(Dual feasibility)
# - 여부등 조건(Complementary slackness)
# - 정상 조건(Stationarity)
#
# **Equation 11.1**
# $$
# 𝐿𝐰, 𝑏, 𝛂=12𝐰𝑇𝐰+𝛂,𝑔(𝐰,𝑏)
# $$
#
# **Equation 11.2**
# $$
# 𝑔𝑖𝐰,𝑏≤0
# $$
#
# **Equation 11.3**
# $$
# 𝑖=1,…𝑚)
# $$
#
# **Equation 11.4**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝐰,𝑏12𝐰𝑇𝐰
# $$
#
# **Equation 11.5**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 11.6**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 11.7**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 11.8**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 11.9**
# $$
# 𝛻𝐰12𝐰∗𝑇𝐰∗+𝛻𝐰𝛂,𝑔(𝐰∗,𝑏)=𝟎
# $$
#
# **Equation 11.10**
# $$
# 𝑔𝐰∗,𝑏∗≤𝟎
# $$
#
# **Equation 11.11**
# $$
# 𝛂≥𝟎
# $$
#
# **Equation 11.12**
# $$
# 𝛂∘𝐠(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 11.13**
# $$
# 𝑑12𝐰∗𝑇𝐰∗𝑑𝑏+𝑑𝛂,𝑔𝐰∗,𝑏𝑑𝑏=𝟎
# $$
#
# **Equation 11.14**
# $$
# 𝐿𝐰, 𝑏, 𝛂=12𝐰𝑇𝐰+𝛂,𝑔(𝐰,𝑏)
# $$
#
# **Equation 11.15**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝐰,𝑏12𝐰𝑇𝐰
# $$
#
# **Equation 11.16**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 11.17**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 11.18**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 11.19**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 11.20**
# $$
# 𝛻𝐰12𝐰∗𝑇𝐰∗+𝛻𝐰𝛂,𝑔(𝐰∗,𝑏)=𝟎
# $$
#
# **Equation 11.21**
# $$
# 𝑔𝐰∗,𝑏∗≤𝟎
# $$
#
# **Equation 11.22**
# $$
# 𝛂≥𝟎
# $$
#
# **Equation 11.23**
# $$
# 𝛂∘𝐠(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 11.24**
# $$
# 𝑑12𝐰∗𝑇𝐰∗𝑑𝑏+𝑑𝛂,𝑔𝐰∗,𝑏𝑑𝑏=𝟎
# $$
#
# ![slide11-image1](data:image/png;base64,...)
# ![slide11-image2](data:image/png;base64,...)
# ![slide11-image3](data:image/png;base64,...)
# ![slide11-image4](data:image/png;base64,...)
# ![slide11-image5](data:image/png;base64,...)
# ![slide11-image6](data:image/png;base64,...)
# ![slide11-image7](data:image/png;base64,...)
# ![slide11-image8](data:image/png;base64,...)
# ![slide11-image9](data:image/png;base64,...)
# ![slide11-image10](data:image/png;base64,...)
# ![slide11-image11](data:image/png;base64,...)
# ![slide11-image12](data:image/png;base64,...)
# ![slide11-image13](data:image/png;base64,...)

# %% [markdown]
# ### Slide 12: (Untitled)
#
# - 최대 마진 분류
# - 2
# - 정상 조건(Stationarity)
#
# **Equation 12.1**
# $$
# 𝛻𝐰12𝐰∗𝑇𝐰∗+𝛻𝐰𝛂,𝑔(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 12.2**
# $$
# 𝑑12𝐰∗𝑇𝐰∗𝑑𝑏+𝑑𝛂,𝑔𝐰∗,𝑏∗𝑑𝑏=𝟎
# $$
#
# **Equation 12.3**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 12.4**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 12.5**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 12.6**
# $$
# 𝐰∗−𝑋T(𝛂∘𝐲)=𝟎
# $$
#
# **Equation 12.7**
# $$
# 𝐰∗=𝑿𝐓(𝛂∘𝐲)
# $$
#
# **Equation 12.8**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 12.9**
# $$
# 𝑋=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 12.10**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 12.11**
# $$
# 𝛻𝐰12𝐰∗𝑇𝐰∗+𝛻𝐰𝛂,𝑔(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 12.12**
# $$
# 𝑑12𝐰∗𝑇𝐰∗𝑑𝑏+𝑑𝛂,𝑔𝐰∗,𝑏∗𝑑𝑏=𝟎
# $$
#
# **Equation 12.13**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 12.14**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 12.15**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 12.16**
# $$
# 𝐰∗−𝑋T(𝛂∘𝐲)=𝟎
# $$
#
# **Equation 12.17**
# $$
# 𝐰∗=𝑿𝐓(𝛂∘𝐲)
# $$
#
# **Equation 12.18**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 12.19**
# $$
# 𝑋=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 12.20**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# ![slide12-image1](data:image/png;base64,...)
# ![slide12-image2](data:image/png;base64,...)
# ![slide12-image3](data:image/png;base64,...)
# ![slide12-image4](data:image/png;base64,...)
# ![slide12-image5](data:image/png;base64,...)
# ![slide12-image6](data:image/png;base64,...)
# ![slide12-image7](data:image/png;base64,...)
# ![slide12-image8](data:image/png;base64,...)
# ![slide12-image9](data:image/png;base64,...)
# ![slide12-image10](data:image/png;base64,...)
# ![slide12-image11](data:image/png;base64,...)

# %% [markdown]
# ### Slide 13: (Untitled)
#
# - 최대 마진 분류
# - 정상 조건(Stationarity)
# - 원 조건(Primal Feasibility)
# - 쌍대 조건(Dual Feasibility)
# - 여부등 조건(Complementary Slackness)
# - 위 5 가지 요건을 만족하는 α 는 어떻게 찾는가?
# - 일일이 대입할 것인가?
# - 쌍대 문제(Dual Problem)로 전환
# - 2
# - 조건 정리
#
# **Equation 13.1**
# $$
# 𝐰∗=𝑿𝐓(𝛂∘𝐲)
# $$
#
# **Equation 13.2**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 13.3**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 13.4**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 13.5**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 13.6**
# $$
# 𝐗=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 13.7**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 13.8**
# $$
# 𝑔𝐰∗,𝑏∗≤𝟎
# $$
#
# **Equation 13.9**
# $$
# 𝛂≥𝟎
# $$
#
# **Equation 13.10**
# $$
# 𝛂∘𝐠(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 13.11**
# $$
# 𝐰∗=𝑿𝐓(𝛂∘𝐲)
# $$
#
# **Equation 13.12**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 13.13**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 13.14**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 13.15**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 13.16**
# $$
# 𝐗=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 13.17**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 13.18**
# $$
# 𝑔𝐰∗,𝑏∗≤𝟎
# $$
#
# **Equation 13.19**
# $$
# 𝛂≥𝟎
# $$
#
# **Equation 13.20**
# $$
# 𝛂∘𝐠(𝐰∗,𝑏∗)=𝟎
# $$
#
# ![slide13-image1](data:image/png;base64,...)
# ![slide13-image2](data:image/png;base64,...)
# ![slide13-image3](data:image/png;base64,...)
# ![slide13-image4](data:image/png;base64,...)
# ![slide13-image5](data:image/png;base64,...)
# ![slide13-image6](data:image/png;base64,...)
# ![slide13-image7](data:image/png;base64,...)
# ![slide13-image8](data:image/png;base64,...)
# ![slide13-image9](data:image/png;base64,...)
# ![slide13-image10](data:image/png;base64,...)
# ![slide13-image11](data:image/png;base64,...)

# %% [markdown]
# ### Slide 14: (Untitled)
#
# - 최대 마진 분류
# - 원문제(Primal Problem)
# - 쌍대 문제(Dual Problem)
# - 2
# - 쌍대 문제(Dual Problem)
# - 정상 조건(Stationarity)에서 유도된 식을
# - 에 대입
# - 의 유도
#
# **Equation 14.1**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝐰,𝐛𝑓(𝐰,𝑏)
# $$
#
# **Equation 14.2**
# $$
# 𝑚𝑎𝑥𝑖𝑚𝑖𝑧𝑒𝛂𝐿𝐷(𝛂)
# $$
#
# **Equation 14.3**
# $$
# 𝐰∗=𝑋T(𝛂∘𝐲)
# $$
#
# **Equation 14.4**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 14.5**
# $$
# 𝐿(𝐰,𝑏, 𝛂)
# $$
#
# **Equation 14.6**
# $$
# 𝐿𝐷(𝛂)
# $$
#
# **Equation 14.7**
# $$
# 𝐿𝐰, 𝑏, 𝛂=12𝐰𝑇𝐰+𝛂,𝑔(𝐰,𝑏)
# $$
#
# **Equation 14.8**
# $$
# 𝐿𝐷𝛼=12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲−𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲+𝒊=𝟏𝒎𝜶𝒊
# $$
#
# **Equation 14.9**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 14.10**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 14.11**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 14.12**
# $$
# 𝐗=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 14.13**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 14.14**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝐰,𝐛𝑓(𝐰,𝑏)
# $$
#
# **Equation 14.15**
# $$
# 𝑚𝑎𝑥𝑖𝑚𝑖𝑧𝑒𝛂𝐿𝐷(𝛂)
# $$
#
# **Equation 14.16**
# $$
# 𝐰∗=𝑋T(𝛂∘𝐲)
# $$
#
# **Equation 14.17**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 14.18**
# $$
# 𝐿𝐰, 𝑏, 𝛂=12𝐰𝑇𝐰+𝛂,𝑔(𝐰,𝑏)
# $$
#
# **Equation 14.19**
# $$
# 𝐿𝐷𝛼=12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲−𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲+𝒊=𝟏𝒎𝜶𝒊
# $$
#
# **Equation 14.20**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 14.21**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 14.22**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 14.23**
# $$
# 𝐗=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 14.24**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# ![slide14-image1](data:image/png;base64,...)
# ![slide14-image2](data:image/png;base64,...)
# ![slide14-image3](data:image/png;base64,...)
# ![slide14-image4](data:image/png;base64,...)
# ![slide14-image5](data:image/png;base64,...)
# ![slide14-image6](data:image/png;base64,...)
# ![slide14-image7](data:image/png;base64,...)
# ![slide14-image8](data:image/png;base64,...)
# ![slide14-image9](data:image/png;base64,...)
# ![slide14-image10](data:image/png;base64,...)
# ![slide14-image11](data:image/png;base64,...)
# ![slide14-image12](data:image/png;base64,...)
# ![slide14-image13](data:image/png;base64,...)
# ![slide14-image14](data:image/png;base64,...)

# %% [markdown]
# ### Slide 15: (Untitled)
#
# - 최대 마진 분류
# - 2
# - 쌍대 문제(Dual Problem)
# - 원 조건(Primal feasibility)
# - 쌍대 조건(Dual feasibility)
# - 여부등 조건(Complementary slackness)
# - 정상 조건(Stationarity)
#
# **Equation 15.1**
# $$
# 𝛂≥𝟎
# $$
#
# **Equation 15.2**
# $$
# 𝛂∘𝐠(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 15.3**
# $$
# 𝐰∗=𝑋T(𝛂∘𝐲)
# $$
#
# **Equation 15.4**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 15.5**
# $$
# maximize𝛼𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝐗𝐗𝐓𝛂∘𝐲
# $$
#
# **Equation 15.6**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 15.7**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 15.8**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 15.9**
# $$
# 𝐗=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 15.10**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 15.11**
# $$
# 𝑔𝐰∗,𝑏∗≤𝟎
# $$
#
# **Equation 15.12**
# $$
# 𝛂≥𝟎
# $$
#
# **Equation 15.13**
# $$
# 𝛂∘𝐠(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 15.14**
# $$
# 𝐰∗=𝑋T(𝛂∘𝐲)
# $$
#
# **Equation 15.15**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 15.16**
# $$
# maximize𝛼𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝐗𝐗𝐓𝛂∘𝐲
# $$
#
# **Equation 15.17**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 15.18**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 15.19**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 15.20**
# $$
# 𝐗=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 15.21**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 15.22**
# $$
# 𝑔𝐰∗,𝑏∗≤𝟎
# $$
#
# ![slide15-image1](data:image/png;base64,...)
# ![slide15-image2](data:image/png;base64,...)
# ![slide15-image3](data:image/png;base64,...)
# ![slide15-image4](data:image/png;base64,...)
# ![slide15-image5](data:image/png;base64,...)
# ![slide15-image6](data:image/png;base64,...)
# ![slide15-image7](data:image/png;base64,...)
# ![slide15-image8](data:image/png;base64,...)
# ![slide15-image9](data:image/png;base64,...)
# ![slide15-image10](data:image/png;base64,...)
# ![slide15-image11](data:image/png;base64,...)
# ![slide15-image12](data:image/png;base64,...)

# %% [markdown]
# ### Slide 16: (Untitled)
#
# - 최대 마진 분류
# - 2
# - 0
# - 임의의,
#
# **Equation 16.1**
# $$
# 𝑔𝐰∗,𝑏∗≤𝟎
# $$
#
# **Equation 16.2**
# $$
# 𝛂≥𝟎
# $$
#
# **Equation 16.3**
# $$
# 𝛂∘𝐠(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 16.4**
# $$
# 𝐰∗=𝑋T(𝛂∘𝐲)
# $$
#
# **Equation 16.5**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 16.6**
# $$
# =−𝑦𝑖𝐰∗𝑻𝐱𝑖+𝑏+1
# $$
#
# **Equation 16.7**
# $$
# 𝑖∈𝑆𝑉
# $$
#
# **Equation 16.8**
# $$
# 𝑔𝑖(𝐰∗,𝑏∗)=0
# $$
#
# **Equation 16.9**
# $$
# 𝑏∗=𝑦𝑖−𝛂∘𝐲𝐓𝑋𝐱𝐢
# $$
#
# **Equation 16.10**
# $$
# 𝑏∗=1𝑁𝑖∈𝑆𝑉𝑦𝑖−𝛂∘𝐲𝐓𝑋𝐱𝐢
# $$
#
# **Equation 16.11**
# $$
# 𝑆𝑉(𝑆𝑢𝑝𝑝𝑜𝑟𝑡 𝑉𝑒𝑐𝑡𝑜𝑟𝑠)={𝐱𝑖|𝛼𝑖>0}
# $$
#
# **Equation 16.12**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 16.13**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 16.14**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 16.15**
# $$
# 𝐗=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 16.16**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 16.17**
# $$
# maximize𝛼𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲
# $$
#
# **Equation 16.18**
# $$
# 𝑔𝐰∗,𝑏∗≤𝟎
# $$
#
# **Equation 16.19**
# $$
# 𝛂≥𝟎
# $$
#
# **Equation 16.20**
# $$
# 𝛂∘𝐠(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 16.21**
# $$
# 𝐰∗=𝑋T(𝛂∘𝐲)
# $$
#
# **Equation 16.22**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 16.23**
# $$
# 𝑔𝑖(𝐰∗,𝑏∗)=0
# $$
#
# **Equation 16.24**
# $$
# 𝑏∗=𝑦𝑖−𝛂∘𝐲𝐓𝑋𝐱𝐢
# $$
#
# **Equation 16.25**
# $$
# 𝑏∗=1𝑁𝑖∈𝑆𝑉𝑦𝑖−𝛂∘𝐲𝐓𝑋𝐱𝐢
# $$
#
# **Equation 16.26**
# $$
# 𝑆𝑉(𝑆𝑢𝑝𝑝𝑜𝑟𝑡 𝑉𝑒𝑐𝑡𝑜𝑟𝑠)={𝐱𝑖|𝛼𝑖>0}
# $$
#
# **Equation 16.27**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 16.28**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 16.29**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 16.30**
# $$
# 𝐗=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 16.31**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 16.32**
# $$
# maximize𝛼𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲
# $$
#
# ![slide16-image1](data:image/png;base64,...)
# ![slide16-image2](data:image/png;base64,...)
# ![slide16-image3](data:image/png;base64,...)
# ![slide16-image4](data:image/png;base64,...)
# ![slide16-image5](data:image/png;base64,...)
# ![slide16-image6](data:image/png;base64,...)
# ![slide16-image7](data:image/png;base64,...)
# ![slide16-image8](data:image/png;base64,...)
# ![slide16-image9](data:image/png;base64,...)
# ![slide16-image10](data:image/png;base64,...)
# ![slide16-image11](data:image/png;base64,...)
# ![slide16-image12](data:image/png;base64,...)
# ![slide16-image13](data:image/png;base64,...)
# ![slide16-image14](data:image/png;base64,...)
# ![slide16-image15](data:image/png;base64,...)
# ![slide16-image16](data:image/png;base64,...)
# ![slide16-image17](data:image/png;base64,...)
# ![slide16-image18](data:image/png;base64,...)

# %% [markdown]
# ### Slide 17: (Untitled)
#
# - 소프트 마진 분류
# - 모든 에 대해,:슬랙 변수(Slack Variable)
# - 기하학적 마진을 최대화하는 찾는 것
# - 을 최소화하는 를 찾는 것
# - C: 규제 계수
# - C 가 클수록 기하학적 마진은 좁아지며 학습 데이터의 반영 정도가 높아짐
# - C 가 작을수록 기하학적 마진은 넓어지며 학습 데이터의 반영 정도가 낮아짐
# - 3
# - 선형 분리가 되지 않을 때, 마진 기준 완화
#
# **Equation 17.1**
# $$
# 𝑖
# $$
#
# **Equation 17.2**
# $$
# 𝜉𝑖
# $$
#
# **Equation 17.3**
# $$
# 𝐰,b를
# $$
#
# **Equation 17.4**
# $$
# 12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖
# $$
#
# **Equation 17.5**
# $$
# 𝐰,b,𝜉𝑖
# $$
#
# **Equation 17.6**
# $$
# 𝑖𝑓 𝑦𝑖=1,𝐰𝑇𝐱𝐢+𝑏≥1−𝜉𝑖
# $$
#
# **Equation 17.7**
# $$
# 𝑖𝑓 𝑦𝑖=−1,𝐰𝑇𝐱𝐢+𝑏<−1+𝜉𝑖
# $$
#
# **Equation 17.8**
# $$
# 𝜉𝑖≥0
# $$
#
# **Equation 17.9**
# $$
# 𝑦𝑖𝐰𝑇𝐱𝐢+𝑏−1+𝜉𝑖≥0
# $$
#
# **Equation 17.10**
# $$
# 𝜉𝑖≥0
# $$
#
# **Equation 17.11**
# $$
# 12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖
# $$
#
# **Equation 17.12**
# $$
# 𝑖𝑓 𝑦𝑖=1,𝐰𝑇𝐱𝐢+𝑏≥1−𝜉𝑖
# $$
#
# **Equation 17.13**
# $$
# 𝑖𝑓 𝑦𝑖=−1,𝐰𝑇𝐱𝐢+𝑏<−1+𝜉𝑖
# $$
#
# **Equation 17.14**
# $$
# 𝜉𝑖≥0
# $$
#
# **Equation 17.15**
# $$
# 𝑦𝑖𝐰𝑇𝐱𝐢+𝑏−1+𝜉𝑖≥0
# $$
#
# **Equation 17.16**
# $$
# 𝜉𝑖≥0
# $$
#
# ![slide17-image1](data:image/png;base64,...)
# ![slide17-image2](data:image/png;base64,...)
# ![slide17-image3](data:image/png;base64,...)
# ![slide17-image4](data:image/png;base64,...)
# ![slide17-image5](data:image/png;base64,...)
# ![slide17-image6](data:image/png;base64,...)
# ![slide17-image7](data:image/png;base64,...)
# ![slide17-image8](data:image/png;base64,...)
# ![slide17-image9](data:image/png;base64,...)
# ![slide17-image10](data:image/png;base64,...)

# %% [markdown]
# ### Slide 18: (Untitled)
#
# - 소프트 마진 분류
# - 3
# - 일 때,(
# - 정상 조건(Stationarity)
# - 원 조건(Primal feasibility)
# - 쌍대 조건(Dual feasibility)
# - 여부등 조건(Complementary slackness)
#
# **Equation 18.1**
# $$
# 𝐿𝐰, 𝑏, 𝛂,𝛏 =12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖 +𝛂,𝑔(𝐰,𝑏,𝛏)−𝛍, 𝛏
# $$
#
# **Equation 18.2**
# $$
# 𝑔(𝐰,𝑏,𝜉)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝜉1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1−𝜉2…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1−𝜉𝑚
# $$
#
# **Equation 18.3**
# $$
# 𝑔𝑖𝐰,𝑏,𝛏≤0
# $$
#
# **Equation 18.4**
# $$
# 𝑖=1,…𝑚)
# $$
#
# **Equation 18.5**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 18.6**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝐰,𝑏,𝛏 12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖
# $$
#
# **Equation 18.7**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 18.8**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 18.9**
# $$
# 𝛻𝐰12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖 +𝛂,𝑔(𝐰∗,𝑏∗,𝛏∗)−𝛍, 𝛏=𝟎
# $$
#
# **Equation 18.10**
# $$
# 𝑔𝐰∗,𝑏∗,𝛏∗≤𝟎, 𝛏≥𝟎
# $$
#
# **Equation 18.11**
# $$
# 𝛂≥𝟎, 𝛍≥𝟎
# $$
#
# **Equation 18.12**
# $$
# 𝛂∘𝐠𝐰∗,𝑏∗,𝛏∗=𝟎, 𝛍∘𝛏=𝟎
# $$
#
# **Equation 18.13**
# $$
# 𝛏=𝜉1𝜉2…𝜉𝑚
# $$
#
# **Equation 18.14**
# $$
# 𝛻𝛏12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖 +𝛂,𝑔(𝐰∗,𝑏∗,𝛏∗)−𝛍, 𝛏=𝟎
# $$
#
# **Equation 18.15**
# $$
# 𝑑12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖 +𝛂,𝑔(𝐰∗,𝑏∗,𝛏∗)−𝛍, 𝛏/𝑑𝑏=𝟎
# $$
#
# **Equation 18.16**
# $$
# 𝛍=𝜇1𝜇2…𝜇𝑚
# $$
#
# **Equation 18.17**
# $$
# 𝐿𝐰, 𝑏, 𝛂,𝛏 =12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖 +𝛂,𝑔(𝐰,𝑏,𝛏)−𝛍, 𝛏
# $$
#
# **Equation 18.18**
# $$
# 𝑔(𝐰,𝑏,𝜉)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝜉1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1−𝜉2…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1−𝜉𝑚
# $$
#
# **Equation 18.19**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 18.20**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝐰,𝑏,𝛏 12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖
# $$
#
# **Equation 18.21**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 18.22**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 18.23**
# $$
# 𝛻𝐰12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖 +𝛂,𝑔(𝐰∗,𝑏∗,𝛏∗)−𝛍, 𝛏=𝟎
# $$
#
# **Equation 18.24**
# $$
# 𝑔𝐰∗,𝑏∗,𝛏∗≤𝟎, 𝛏≥𝟎
# $$
#
# **Equation 18.25**
# $$
# 𝛂≥𝟎, 𝛍≥𝟎
# $$
#
# **Equation 18.26**
# $$
# 𝛂∘𝐠𝐰∗,𝑏∗,𝛏∗=𝟎, 𝛍∘𝛏=𝟎
# $$
#
# **Equation 18.27**
# $$
# 𝛏=𝜉1𝜉2…𝜉𝑚
# $$
#
# **Equation 18.28**
# $$
# 𝛻𝛏12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖 +𝛂,𝑔(𝐰∗,𝑏∗,𝛏∗)−𝛍, 𝛏=𝟎
# $$
#
# **Equation 18.29**
# $$
# 𝑑12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖 +𝛂,𝑔(𝐰∗,𝑏∗,𝛏∗)−𝛍, 𝛏/𝑑𝑏=𝟎
# $$
#
# **Equation 18.30**
# $$
# 𝛍=𝜇1𝜇2…𝜇𝑚
# $$
#
# ![slide18-image1](data:image/png;base64,...)
# ![slide18-image2](data:image/png;base64,...)
# ![slide18-image3](data:image/png;base64,...)
# ![slide18-image4](data:image/png;base64,...)
# ![slide18-image5](data:image/png;base64,...)
# ![slide18-image6](data:image/png;base64,...)
# ![slide18-image7](data:image/png;base64,...)
# ![slide18-image8](data:image/png;base64,...)
# ![slide18-image9](data:image/png;base64,...)
# ![slide18-image10](data:image/png;base64,...)
# ![slide18-image11](data:image/png;base64,...)
# ![slide18-image12](data:image/png;base64,...)
# ![slide18-image13](data:image/png;base64,...)
# ![slide18-image14](data:image/png;base64,...)
# ![slide18-image15](data:image/png;base64,...)
# ![slide18-image16](data:image/png;base64,...)

# %% [markdown]
# ### Slide 19: (Untitled)
#
# - 소프트 마진 분류
# - 3
# - 정상 조건(Stationarity)
#
# **Equation 19.1**
# $$
# 𝐰∗−𝑋T(𝛂∘𝐲)=𝟎
# $$
#
# **Equation 19.2**
# $$
# 𝐰∗=𝑋T(𝛂∘𝐲)
# $$
#
# **Equation 19.3**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 19.4**
# $$
# 𝛻𝐰12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖 +𝛂,𝑔(𝐰∗,𝑏∗,𝛏∗)−𝛍, 𝛏=𝟎
# $$
#
# **Equation 19.5**
# $$
# 𝛻𝛏12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖 +𝛂,𝑔(𝐰∗,𝑏∗,𝛏∗)−𝛍, 𝛏=𝟎
# $$
#
# **Equation 19.6**
# $$
# 𝐂−𝛂−𝛍=0
# $$
#
# **Equation 19.7**
# $$
# 𝛂+𝛍=𝐂
# $$
#
# **Equation 19.8**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 19.9**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 19.10**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 19.11**
# $$
# 𝐗=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 19.12**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 19.13**
# $$
# 𝑑12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖 +𝛂,𝑔(𝐰∗,𝑏∗,𝛏∗)−𝛍, 𝛏/𝑑𝑏=𝟎
# $$
#
# **Equation 19.14**
# $$
# 𝐰∗−𝑋T(𝛂∘𝐲)=𝟎
# $$
#
# **Equation 19.15**
# $$
# 𝐰∗=𝑋T(𝛂∘𝐲)
# $$
#
# **Equation 19.16**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 19.17**
# $$
# 𝛻𝐰12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖 +𝛂,𝑔(𝐰∗,𝑏∗,𝛏∗)−𝛍, 𝛏=𝟎
# $$
#
# **Equation 19.18**
# $$
# 𝛻𝛏12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖 +𝛂,𝑔(𝐰∗,𝑏∗,𝛏∗)−𝛍, 𝛏=𝟎
# $$
#
# **Equation 19.19**
# $$
# 𝐂−𝛂−𝛍=0
# $$
#
# **Equation 19.20**
# $$
# 𝛂+𝛍=𝐂
# $$
#
# **Equation 19.21**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 19.22**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 19.23**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 19.24**
# $$
# 𝐗=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 19.25**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 19.26**
# $$
# 𝑑12𝐰𝑇𝐰+𝐶𝑖=1𝑛𝜉𝑖 +𝛂,𝑔(𝐰∗,𝑏∗,𝛏∗)−𝛍, 𝛏/𝑑𝑏=𝟎
# $$
#
# ![slide19-image1](data:image/png;base64,...)
# ![slide19-image2](data:image/png;base64,...)
# ![slide19-image3](data:image/png;base64,...)
# ![slide19-image4](data:image/png;base64,...)
# ![slide19-image5](data:image/png;base64,...)
# ![slide19-image6](data:image/png;base64,...)
# ![slide19-image7](data:image/png;base64,...)
# ![slide19-image8](data:image/png;base64,...)
# ![slide19-image9](data:image/png;base64,...)
# ![slide19-image10](data:image/png;base64,...)
# ![slide19-image11](data:image/png;base64,...)
# ![slide19-image12](data:image/png;base64,...)
# ![slide19-image13](data:image/png;base64,...)
# ![slide19-image14](data:image/png;base64,...)

# %% [markdown]
# ### Slide 20: (Untitled)
#
# - 소프트 마진 분류
# - 3
# - 쌍대 문제(Dual Problem)
# - 정상 조건(Stationarity)에서 유도된 식을
# - 에 대입하면
# - 의 유도
# - 원문제(Primal Problem)
# - 쌍대 문제(Dual Problem)
#
# **Equation 20.1**
# $$
# 𝐰∗=𝑋T(𝛂∘𝐲)
# $$
#
# **Equation 20.2**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 20.3**
# $$
# 𝐿(𝐰,𝑏, 𝛂,𝛏,𝛍)
# $$
#
# **Equation 20.4**
# $$
# 𝐿𝐷(𝛂,𝛏)
# $$
#
# **Equation 20.5**
# $$
# 𝐿𝐰, 𝑏, 𝛂,𝛏,𝛍=12𝐰𝑇𝐰+𝐶𝑖=1𝑚𝜉𝑖+𝛂,𝑔(𝐰,𝑏,𝛏)−𝛍, 𝛏
# $$
#
# **Equation 20.6**
# $$
# 𝐿𝐷𝛂,𝛍=𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲+𝐶𝑖=1𝑚𝜉𝑖+𝛍,𝛏−𝐶𝑖=1𝑚𝜉𝑖−𝛍,𝛏
# $$
#
# **Equation 20.7**
# $$
# 𝛂+𝛍=𝐂
# $$
#
# **Equation 20.8**
# $$
# 𝑔(𝐰,𝑏,𝜉)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝜉1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1−𝜉2…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1−𝜉𝑚
# $$
#
# **Equation 20.9**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝐰,𝑏,𝛏𝑓(𝐰,𝑏,𝛏)
# $$
#
# **Equation 20.10**
# $$
# 𝑚𝑎𝑥𝑖𝑚𝑖𝑧𝑒𝛂,𝛍𝐿𝐷(𝛂,𝛍)
# $$
#
# **Equation 20.11**
# $$
# 𝐰∗=𝑋T(𝛂∘𝐲)
# $$
#
# **Equation 20.12**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 20.13**
# $$
# 𝐿𝐰, 𝑏, 𝛂,𝛏,𝛍=12𝐰𝑇𝐰+𝐶𝑖=1𝑚𝜉𝑖+𝛂,𝑔(𝐰,𝑏,𝛏)−𝛍, 𝛏
# $$
#
# **Equation 20.14**
# $$
# 𝐿𝐷𝛂,𝛍=𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲+𝐶𝑖=1𝑚𝜉𝑖+𝛍,𝛏−𝐶𝑖=1𝑚𝜉𝑖−𝛍,𝛏
# $$
#
# **Equation 20.15**
# $$
# 𝛂+𝛍=𝐂
# $$
#
# **Equation 20.16**
# $$
# 𝑔(𝐰,𝑏,𝜉)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝜉1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1−𝜉2…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1−𝜉𝑚
# $$
#
# **Equation 20.17**
# $$
# 𝑚𝑖𝑛𝑖𝑚𝑖𝑧𝑒𝐰,𝑏,𝛏𝑓(𝐰,𝑏,𝛏)
# $$
#
# **Equation 20.18**
# $$
# 𝑚𝑎𝑥𝑖𝑚𝑖𝑧𝑒𝛂,𝛍𝐿𝐷(𝛂,𝛍)
# $$
#
# ![slide20-image1](data:image/png;base64,...)
# ![slide20-image2](data:image/png;base64,...)
# ![slide20-image3](data:image/png;base64,...)
# ![slide20-image4](data:image/png;base64,...)
# ![slide20-image5](data:image/png;base64,...)
# ![slide20-image6](data:image/png;base64,...)
# ![slide20-image7](data:image/png;base64,...)
# ![slide20-image8](data:image/png;base64,...)
# ![slide20-image9](data:image/png;base64,...)
# ![slide20-image10](data:image/png;base64,...)
# slide20-image11

# %% [markdown]
# ### Slide 21: (Untitled)
#
# - 소프트 마진 분류
# - 3
# - 쌍대 문제(Dual Problem) 정리
# - 정상 조건(Stationarity)
# - 원 조건(Primal feasibility)
# - 쌍대 조건(Dual feasibility)
# - 여부등 조건(Complementary slackness)
#
# **Equation 21.1**
# $$
# maximize𝛂𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲
# $$
#
# **Equation 21.2**
# $$
# 𝐰∗=𝑋T(𝛂∘𝐲)
# $$
#
# **Equation 21.3**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 21.4**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 21.5**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 21.6**
# $$
# 𝐗=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 21.7**
# $$
# 𝑔(𝐰,𝑏,𝜉)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝜉1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1−𝜉2…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1−𝜉𝑚
# $$
#
# **Equation 21.8**
# $$
# 𝛏=𝜉1𝜉2…𝜉𝑚
# $$
#
# **Equation 21.9**
# $$
# 𝛂+𝛍=𝐂
# $$
#
# **Equation 21.10**
# $$
# 𝑔𝐰∗,𝑏∗,𝛏∗≤𝟎, 𝛏≥𝟎
# $$
#
# **Equation 21.11**
# $$
# 𝛂≥𝟎, 𝛍≥𝟎
# $$
#
# **Equation 21.12**
# $$
# 𝛂∘𝐠𝐰∗,𝑏∗,𝛏∗=𝟎, 𝛍∘𝛏=𝟎
# $$
#
# **Equation 21.13**
# $$
# 𝟎≤𝛂≤𝐂
# $$
#
# **Equation 21.14**
# $$
# maximize𝛂𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲
# $$
#
# **Equation 21.15**
# $$
# 𝐰∗=𝑋T(𝛂∘𝐲)
# $$
#
# **Equation 21.16**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 21.17**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 21.18**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 21.19**
# $$
# 𝐗=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 21.20**
# $$
# 𝑔(𝐰,𝑏,𝜉)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝜉1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1−𝜉2…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1−𝜉𝑚
# $$
#
# **Equation 21.21**
# $$
# 𝛏=𝜉1𝜉2…𝜉𝑚
# $$
#
# **Equation 21.22**
# $$
# 𝛂+𝛍=𝐂
# $$
#
# **Equation 21.23**
# $$
# 𝑔𝐰∗,𝑏∗,𝛏∗≤𝟎, 𝛏≥𝟎
# $$
#
# **Equation 21.24**
# $$
# 𝛂≥𝟎, 𝛍≥𝟎
# $$
#
# **Equation 21.25**
# $$
# 𝛂∘𝐠𝐰∗,𝑏∗,𝛏∗=𝟎, 𝛍∘𝛏=𝟎
# $$
#
# **Equation 21.26**
# $$
# 𝟎≤𝛂≤𝐂
# $$
#
# ![slide21-image1](data:image/png;base64,...)
# ![slide21-image2](data:image/png;base64,...)
# ![slide21-image3](data:image/png;base64,...)
# ![slide21-image4](data:image/png;base64,...)
# ![slide21-image5](data:image/png;base64,...)
# ![slide21-image6](data:image/png;base64,...)
# ![slide21-image7](data:image/png;base64,...)
# ![slide21-image8](data:image/png;base64,...)
# ![slide21-image9](data:image/png;base64,...)
# ![slide21-image10](data:image/png;base64,...)
# ![slide21-image11](data:image/png;base64,...)
# ![slide21-image12](data:image/png;base64,...)
# ![slide21-image13](data:image/png;base64,...)
# ![slide21-image14](data:image/png;base64,...)

# %% [markdown]
# ### Slide 22: (Untitled)
#
# - 소프트 마진 분류
# - 3
# - 정리
#
# **Equation 22.1**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 22.2**
# $$
# maximize𝛼𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲
# $$
#
# **Equation 22.3**
# $$
# 𝑔𝐰∗,𝑏∗≤𝟎
# $$
#
# **Equation 22.4**
# $$
# 𝟎≤𝛂≤𝐂
# $$
#
# **Equation 22.5**
# $$
# 𝛂∘𝐠(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 22.6**
# $$
# 𝐰∗=𝑋𝑇(𝛂∘𝐲)
# $$
#
# **Equation 22.7**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 22.8**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 22.9**
# $$
# maximize𝛼𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲
# $$
#
# **Equation 22.10**
# $$
# 𝑔𝐰∗,𝑏∗≤𝟎
# $$
#
# **Equation 22.11**
# $$
# 𝟎≤𝛂≤𝐂
# $$
#
# **Equation 22.12**
# $$
# 𝛂∘𝐠(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 22.13**
# $$
# 𝐰∗=𝑋𝑇(𝛂∘𝐲)
# $$
#
# **Equation 22.14**
# $$
# 𝛂,𝐲=0
# $$
#
# ![slide22-image1](data:image/png;base64,...)
# ![slide22-image2](data:image/png;base64,...)
# ![slide22-image3](data:image/png;base64,...)
# ![slide22-image4](data:image/png;base64,...)
# ![slide22-image5](data:image/png;base64,...)
# ![slide22-image6](data:image/png;base64,...)
# ![slide22-image7](data:image/png;base64,...)
# ![slide22-image8](data:image/png;base64,...)

# %% [markdown]
# ### Slide 23: (Untitled)
#
# - 소프트 마진 분류
# - 3
# - 서포트 벡터(Support Vector)
#
# **Equation 23.1**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 23.2**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 23.3**
# $$
# 𝑋=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 23.4**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 23.5**
# $$
# maximize𝛼𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲
# $$
#
# **Equation 23.6**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 23.7**
# $$
# 𝑔𝐰∗,𝑏∗≤𝟎
# $$
#
# **Equation 23.8**
# $$
# 𝟎≤𝛂≤𝐂
# $$
#
# **Equation 23.9**
# $$
# 𝛂∘𝐠(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 23.10**
# $$
# 𝑆𝑢𝑝𝑝𝑜𝑟𝑡 𝑉𝑒𝑐𝑡𝑜𝑟𝑠={𝐱𝑖|𝛼𝑖>0}
# $$
#
# **Equation 23.11**
# $$
# 𝟎<𝛂𝐢<𝐂
# $$
#
# **Equation 23.12**
# $$
# 𝛂𝐢=𝐂
# $$
#
# **Equation 23.13**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 23.14**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 23.15**
# $$
# 𝑋=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 23.16**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 23.17**
# $$
# maximize𝛼𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲
# $$
#
# **Equation 23.18**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 23.19**
# $$
# 𝑔𝐰∗,𝑏∗≤𝟎
# $$
#
# **Equation 23.20**
# $$
# 𝟎≤𝛂≤𝐂
# $$
#
# **Equation 23.21**
# $$
# 𝛂∘𝐠(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 23.22**
# $$
# 𝑆𝑢𝑝𝑝𝑜𝑟𝑡 𝑉𝑒𝑐𝑡𝑜𝑟𝑠={𝐱𝑖|𝛼𝑖>0}
# $$
#
# **Equation 23.23**
# $$
# 𝟎<𝛂𝐢<𝐂
# $$
#
# **Equation 23.24**
# $$
# 𝛂𝐢=𝐂
# $$
#
# ![slide23-image1](data:image/png;base64,...)
# ![slide23-image2](data:image/png;base64,...)
# ![slide23-image3](data:image/png;base64,...)
# ![slide23-image4](data:image/png;base64,...)
# ![slide23-image5](data:image/png;base64,...)
# ![slide23-image6](data:image/png;base64,...)
# ![slide23-image7](data:image/png;base64,...)
# ![slide23-image8](data:image/png;base64,...)
# ![slide23-image9](data:image/png;base64,...)
# ![slide23-image10](data:image/png;base64,...)
# ![slide23-image11](data:image/png;base64,...)
# ![slide23-image12](data:image/png;base64,...)
# ![slide23-image13](data:image/png;base64,...)
# ![slide23-image14](data:image/png;base64,...)

# %% [markdown]
# ### Slide 24: (Untitled)
#
# - 소프트 마진 분류
# - 3
# - 0
# - 임의의,
#
# **Equation 24.1**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 24.2**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 24.3**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 24.4**
# $$
# 𝐗=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 24.5**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 24.6**
# $$
# maximize𝛼𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲
# $$
#
# **Equation 24.7**
# $$
# 𝑔𝐰∗,𝑏∗≤𝟎
# $$
#
# **Equation 24.8**
# $$
# 𝛂≥𝟎
# $$
#
# **Equation 24.9**
# $$
# 𝛂∘𝐠(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 24.10**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 24.11**
# $$
# 𝑏∗=1𝑁𝑖∈𝑆𝑉𝑀𝑃𝑦𝑖−𝛂∘𝐲𝐓𝑋𝐱𝐢
# $$
#
# **Equation 24.12**
# $$
# 𝐰∗=𝑋𝐓(𝛂∘𝐲)
# $$
#
# **Equation 24.13**
# $$
# =−𝑦𝑖𝐰∗𝑻𝐱𝑖+𝑏+1
# $$
#
# **Equation 24.14**
# $$
# 𝑖∈𝑆𝑉𝑀𝑃
# $$
#
# **Equation 24.15**
# $$
# 𝑔𝑖(𝐰∗,𝑏∗)=0
# $$
#
# **Equation 24.16**
# $$
# 𝑏∗=𝑦𝑖−𝛂∘𝐲𝐓𝑋𝐱𝐢
# $$
#
# **Equation 24.17**
# $$
# 𝑆𝑉𝑀𝑃(𝑆𝑢𝑝𝑝𝑜𝑟𝑡 𝑉𝑒𝑐𝑡𝑜𝑟𝑠 𝑜𝑛 𝑀𝑎𝑔𝑖𝑛 𝑃𝑙𝑎𝑛𝑒)={𝐱𝑖|0<𝛼𝑖<𝐶}
# $$
#
# **Equation 24.18**
# $$
# 𝑔(𝐰,𝑏)=−𝑦1𝐰𝑇𝐱𝟏+𝑏+1−𝑦2𝐰𝑇𝐱𝟐+𝑏+1…−𝑦𝑚𝐰𝑇𝐱𝒎+𝑏+1
# $$
#
# **Equation 24.19**
# $$
# 𝛂=𝛼1𝛼2…𝛼𝑚
# $$
#
# **Equation 24.20**
# $$
# 𝐰=𝑤1𝑤2…𝑤𝑛
# $$
#
# **Equation 24.21**
# $$
# 𝐗=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑚1⋯𝑥𝑚𝑛
# $$
#
# **Equation 24.22**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 24.23**
# $$
# maximize𝛼𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲
# $$
#
# **Equation 24.24**
# $$
# 𝑔𝐰∗,𝑏∗≤𝟎
# $$
#
# **Equation 24.25**
# $$
# 𝛂≥𝟎
# $$
#
# **Equation 24.26**
# $$
# 𝛂∘𝐠(𝐰∗,𝑏∗)=𝟎
# $$
#
# **Equation 24.27**
# $$
# 𝛂,𝐲=0
# $$
#
# **Equation 24.28**
# $$
# 𝑏∗=1𝑁𝑖∈𝑆𝑉𝑀𝑃𝑦𝑖−𝛂∘𝐲𝐓𝑋𝐱𝐢
# $$
#
# **Equation 24.29**
# $$
# 𝐰∗=𝑋𝐓(𝛂∘𝐲)
# $$
#
# **Equation 24.30**
# $$
# 𝑔𝑖(𝐰∗,𝑏∗)=0
# $$
#
# **Equation 24.31**
# $$
# 𝑏∗=𝑦𝑖−𝛂∘𝐲𝐓𝑋𝐱𝐢
# $$
#
# **Equation 24.32**
# $$
# 𝑆𝑉𝑀𝑃(𝑆𝑢𝑝𝑝𝑜𝑟𝑡 𝑉𝑒𝑐𝑡𝑜𝑟𝑠 𝑜𝑛 𝑀𝑎𝑔𝑖𝑛 𝑃𝑙𝑎𝑛𝑒)={𝐱𝑖|0<𝛼𝑖<𝐶}
# $$
#
# ![slide24-image1](data:image/png;base64,...)
# ![slide24-image2](data:image/png;base64,...)
# ![slide24-image3](data:image/png;base64,...)
# ![slide24-image4](data:image/png;base64,...)
# ![slide24-image5](data:image/png;base64,...)
# ![slide24-image6](data:image/png;base64,...)
# ![slide24-image7](data:image/png;base64,...)
# ![slide24-image8](data:image/png;base64,...)
# ![slide24-image9](data:image/png;base64,...)
# ![slide24-image10](data:image/png;base64,...)
# ![slide24-image11](data:image/png;base64,...)
# ![slide24-image12](data:image/png;base64,...)
# ![slide24-image13](data:image/png;base64,...)
# ![slide24-image14](data:image/png;base64,...)
# ![slide24-image15](data:image/png;base64,...)
# ![slide24-image16](data:image/png;base64,...)
# ![slide24-image17](data:image/png;base64,...)
# ![slide24-image18](data:image/png;base64,...)

# %% [markdown]
# ### Slide 25: (Untitled)
#
# - 커널 트릭(Kernel Trick)
# - 커널 행렬(Kernel Matrix)
# - 주어진 데이터 X 와 Y 의 커널 행렬은
# - 4
# - 커널(Kernel):
# - 하나의 데이터 포인트가 다른 데이터 포인트와의 관계성을 정량화하는 함수
#
# **Equation 25.1**
# $$
# 𝐾:𝜒×𝜒→𝑅
# $$
#
# **Equation 25.2**
# $$
# 𝜒∈𝑅𝑛
# $$
#
# **Equation 25.3**
# $$
# 𝑋=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑎1⋯𝑥𝑎𝑛
# $$
#
# **Equation 25.4**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 25.5**
# $$
# 𝑋=𝐱1𝑇𝐱2𝑇…𝐱𝑎𝑇
# $$
#
# **Equation 25.6**
# $$
# 𝐊(𝑋,𝑌)=𝐾(𝐱𝟏,𝐲𝟏)𝐾(𝐱𝟐,𝐲𝟏)⋯𝐾(𝐱𝟏,𝐲𝒃)𝐾(𝐱𝟐,𝐲𝒃)⋮⋱⋮𝐾(𝐱𝒂,𝐲𝟏)⋯𝐾(𝐱𝒂,𝐲𝒃)
# $$
#
# **Equation 25.7**
# $$
# 𝑌=𝑦11⋯𝑦1𝑛⋮⋱⋮𝑦𝑏1⋯𝑦𝑏𝑛
# $$
#
# **Equation 25.8**
# $$
# 𝐲𝐢=𝑦𝑖1𝑦𝑖2…𝑦𝑖𝑛
# $$
#
# **Equation 25.9**
# $$
# 𝑌=𝐲1𝑇𝐲2𝑇…𝐲𝑏𝑇
# $$
#
# **Equation 25.10**
# $$
# 𝐾:𝜒×𝜒→𝑅
# $$
#
# **Equation 25.11**
# $$
# 𝜒∈𝑅𝑛
# $$
#
# **Equation 25.12**
# $$
# 𝑋=𝑥11⋯𝑥1𝑛⋮⋱⋮𝑥𝑎1⋯𝑥𝑎𝑛
# $$
#
# **Equation 25.13**
# $$
# 𝐱𝐢=𝑥𝑖1𝑥𝑖2…𝑥𝑖𝑛
# $$
#
# **Equation 25.14**
# $$
# 𝑋=𝐱1𝑇𝐱2𝑇…𝐱𝑎𝑇
# $$
#
# **Equation 25.15**
# $$
# 𝐊(𝑋,𝑌)=𝐾(𝐱𝟏,𝐲𝟏)𝐾(𝐱𝟐,𝐲𝟏)⋯𝐾(𝐱𝟏,𝐲𝒃)𝐾(𝐱𝟐,𝐲𝒃)⋮⋱⋮𝐾(𝐱𝒂,𝐲𝟏)⋯𝐾(𝐱𝒂,𝐲𝒃)
# $$
#
# **Equation 25.16**
# $$
# 𝑌=𝑦11⋯𝑦1𝑛⋮⋱⋮𝑦𝑏1⋯𝑦𝑏𝑛
# $$
#
# **Equation 25.17**
# $$
# 𝐲𝐢=𝑦𝑖1𝑦𝑖2…𝑦𝑖𝑛
# $$
#
# **Equation 25.18**
# $$
# 𝑌=𝐲1𝑇𝐲2𝑇…𝐲𝑏𝑇
# $$
#
# ![slide25-image1](data:image/png;base64,...)
# ![slide25-image2](data:image/png;base64,...)
# ![slide25-image3](data:image/png;base64,...)
# ![slide25-image4](data:image/png;base64,...)
# ![slide25-image5](data:image/png;base64,...)
# ![slide25-image6](data:image/png;base64,...)
# ![slide25-image7](data:image/png;base64,...)
# ![slide25-image8](data:image/png;base64,...)
# ![slide25-image9](data:image/png;base64,...)
# ![slide25-image10](data:image/png;base64,...)

# %% [markdown]
# ### Slide 26: (Untitled)
#
# - 커널 트릭(Kernel Trick)
# - 4
# - 은 K 가 두 벡터의 내적인 커널 행렬(Kernel Matrix)
#
# **Equation 26.1**
# $$
# 𝐾:𝐱,𝐲
# $$
#
# **Equation 26.2**
# $$
# 𝜒∈𝑅𝑛
# $$
#
# **Equation 26.3**
# $$
# maximize𝛼𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲
# $$
#
# **Equation 26.4**
# $$
# 𝑋𝑋𝑇=𝑥11, 𝑥11⋯𝑥11, 𝑥𝑚1⋮⋱⋮𝑥𝑚1, 𝑥11⋯𝑥𝑚𝑛, 𝑥𝑛𝑚
# $$
#
# **Equation 26.5**
# $$
# 𝑋𝑋𝑇
# $$
#
# **Equation 26.6**
# $$
# 𝐾:𝐱,𝐲
# $$
#
# **Equation 26.7**
# $$
# 𝜒∈𝑅𝑛
# $$
#
# **Equation 26.8**
# $$
# maximize𝛼𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲
# $$
#
# **Equation 26.9**
# $$
# 𝑋𝑋𝑇=𝑥11, 𝑥11⋯𝑥11, 𝑥𝑚1⋮⋱⋮𝑥𝑚1, 𝑥11⋯𝑥𝑚𝑛, 𝑥𝑛𝑚
# $$
#
# ![slide26-image1](data:image/png;base64,...)
# ![slide26-image2](data:image/png;base64,...)
# ![slide26-image3](data:image/png;base64,...)
# ![slide26-image4](data:image/png;base64,...)
# ![slide26-image5](data:image/png;base64,...)
# ![slide26-image6](data:image/png;base64,...)

# %% [markdown]
# ### Slide 27: (Untitled)
#
# - 커널 트릭(Kernel Trick)
# - 2 차 다항 속성 맵핑
# - (2 nd order Polynomial Feature mapping)
# - 변수의 수와 차수가 커질수록 맵핑된 공간의 차원은 급격히 커짐
# - 4
# - 선형 판별기가 Feature Mapping 을 통해
# - 부적합한 데이터를 적합한 형태로 변환
#
# **Equation 27.1**
# $$
# (𝑥1,𝑥2)
# $$
#
# **Equation 27.2**
# $$
# (𝑥1,𝑥2,𝑥12,𝑥1𝑥2,𝑥22)
# $$
#
# **Equation 27.3**
# $$
# (𝑥1,𝑥2)
# $$
#
# **Equation 27.4**
# $$
# (𝑥1,𝑥2,𝑥12,𝑥1𝑥2,𝑥22)
# $$
#
# ![slide27-image1](data:image/png;base64,...)
# ![slide27-image2](data:image/png;base64,...)
# ![slide27-image3](data:image/png;base64,...)
# ![slide27-image4](data:image/png;base64,...)
# ![slide27-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 28: (Untitled)
#
# - 커널 트릭(Kernel Trick)
# - 2 차 다항 속성 맵핑
# - (2 nd Order Polynomial Feature Mapping)
# - 4
# - 커널 트릭(Kernel Trick):
# - 고차원의 속성을 만들지 않고도 고차원 속성의 효과를 유도
#
# **Equation 28.1**
# $$
# (𝑥1,𝑥2)
# $$
#
# **Equation 28.2**
# $$
# (𝑥1,𝑥2,𝑥12,𝑥1𝑥2,𝑥22)
# $$
#
# **Equation 28.3**
# $$
# (𝑎1,𝑎2,…,𝑎𝑛),(𝑏1,𝑏2,…,𝑏𝑛)2
# $$
#
# **Equation 28.4**
# $$
# =𝑎1𝑏1+𝑎2𝑏2+…+𝑎𝑛𝑏𝑛2
# $$
#
# **Equation 28.5**
# $$
# =𝑎12𝑏12+2𝑎1𝑏1𝑎2𝑏2+…+𝑎22𝑏22+…𝑎𝑛2𝑏𝑛2
# $$
#
# **Equation 28.6**
# $$
# =(𝑎12,2𝑎1𝑎2,…,𝑎𝑛2),(𝑏12,2𝑏1𝑏2,…,𝑏𝑛2)
# $$
#
# **Equation 28.7**
# $$
# 𝐾:𝐱,𝐲2
# $$
#
# **Equation 28.8**
# $$
# (𝑥1,𝑥2)
# $$
#
# **Equation 28.9**
# $$
# (𝑥1,𝑥2,𝑥12,𝑥1𝑥2,𝑥22)
# $$
#
# **Equation 28.10**
# $$
# (𝑎1,𝑎2,…,𝑎𝑛),(𝑏1,𝑏2,…,𝑏𝑛)2
# $$
#
# **Equation 28.11**
# $$
# =𝑎1𝑏1+𝑎2𝑏2+…+𝑎𝑛𝑏𝑛2
# $$
#
# **Equation 28.12**
# $$
# =𝑎12𝑏12+2𝑎1𝑏1𝑎2𝑏2+…+𝑎22𝑏22+…𝑎𝑛2𝑏𝑛2
# $$
#
# **Equation 28.13**
# $$
# =(𝑎12,2𝑎1𝑎2,…,𝑎𝑛2),(𝑏12,2𝑏1𝑏2,…,𝑏𝑛2)
# $$
#
# **Equation 28.14**
# $$
# 𝐾:𝐱,𝐲2
# $$
#
# ![slide28-image1](data:image/png;base64,...)
# ![slide28-image2](data:image/png;base64,...)
# ![slide28-image3](data:image/png;base64,...)
# ![slide28-image4](data:image/png;base64,...)
# ![slide28-image5](data:image/png;base64,...)
# ![slide28-image6](data:image/png;base64,...)
# ![slide28-image7](data:image/png;base64,...)
# ![slide28-image8](data:image/png;base64,...)

# %% [markdown]
# ### Slide 29: (Untitled)
#
# - 커널 트릭(Kernel Trick)
# - 양의 준정성(Positive Semi-Definite)
# - 이 성립
# - 임의의 입력 집합 의 커널 행렬 K 에 대해
# - 커널에 의해 유도되는 공간 내적이 성립함을 의미
# - 대칭성
# - 4
# - 커널의 요건
#
# **Equation 29.1**
# $$
# 𝐾𝐱,𝐲=𝐾(𝐲,𝐱)
# $$
#
# **Equation 29.2**
# $$
# ∀𝐜∈𝑅𝒏,𝐜𝑻𝐊𝐜≥𝟎
# $$
#
# **Equation 29.3**
# $$
# {𝐱𝟏, …,𝐱𝒏}
# $$
#
# **Equation 29.4**
# $$
# 𝐾𝐱,𝐲=𝐾(𝐲,𝐱)
# $$
#
# ![slide29-image1](data:image/png;base64,...)
# ![slide29-image2](data:image/png;base64,...)
# ![slide29-image3](data:image/png;base64,...)
# ![slide29-image4](data:image/png;base64,...)

# %% [markdown]
# ### Slide 30: (Untitled)
#
# - 커널 트릭(Kernel Trick)
# - 커널
# - 비고
# - 선형 커널
# - (Linear Kernel)
# - 다항 커널
# - (Polynomial Kernel)
# - 가 클수록 보다 복잡한 가설공간이 만들어짐
# - : 비동차 다항 커널
# - : 동차 다항 커널
# - 방사 기저 함수 커널
# - (Radial Base Function)
# - 가 클수록 보다 복잡한 가설공간 이 만들어짐
# - 시그모이드 커널
# - (Sigmoid Kernel)
# - 𝛾가 클수록 보다 복잡한 가설공간이 만들어짐
# - 커널
# - 비고
# - 선형 커널
# - (Linear Kernel)
# - 다항 커널
# - (Polynomial Kernel)
# - 방사 기저 함수 커널
# - (Radial Base Function)
# - 시그모이드 커널
# - (Sigmoid Kernel)
# - 𝛾가 클수록 보다 복잡한 가설공간이 만들어짐
# - 4
# - 커널(Kernel)
#
# **Table 30.1**
# |   | 커널 | 비고 |
# | --- | --- | --- |
# | 선형 커널
# (Linear Kernel) |   |   |
# | 다항 커널
# (Polynomial Kernel) |   | 가 클수록 보다 복잡한 가설공간이 만들어짐
# : 비동차 다항 커널
# : 동차 다항 커널 |
# | 방사 기저 함수 커널
# (Radial Base Function) |   | 가 클수록 보다 복잡한 가설공간 이 만들어짐 |
# | 시그모이드 커널
# (Sigmoid Kernel) |   | 𝛾가 클수록 보다 복잡한 가설공간이 만들어짐 |
#
# **Table 30.2**
# |   | 커널 | 비고 |
# | --- | --- | --- |
# | 선형 커널
# (Linear Kernel) |   |   |
# | 다항 커널
# (Polynomial Kernel) |   |   |
# | 방사 기저 함수 커널
# (Radial Base Function) |   |   |
# | 시그모이드 커널
# (Sigmoid Kernel) |   | 𝛾가 클수록 보다 복잡한 가설공간이 만들어짐 |
#
# **Equation 30.1**
# $$
# 𝐱,𝐲
# $$
#
# **Equation 30.2**
# $$
# (𝛾𝐱,𝐲+𝑏)𝑑
# $$
#
# **Equation 30.3**
# $$
# 𝛾
# $$
#
# **Equation 30.4**
# $$
# 𝑏>0
# $$
#
# **Equation 30.5**
# $$
# 𝑏=0
# $$
#
# **Equation 30.6**
# $$
# exp−𝛾𝐱−𝐲2
# $$
#
# **Equation 30.7**
# $$
# 𝛾
# $$
#
# **Equation 30.8**
# $$
# tanh⁡(𝛾𝐱,𝐲+𝑏)
# $$
#
# **Equation 30.9**
# $$
# 𝐱,𝐲
# $$
#
# **Equation 30.10**
# $$
# exp−𝛾𝐱−𝐲2
# $$
#
# **Equation 30.11**
# $$
# tanh⁡(𝛾𝐱,𝐲+𝑏)
# $$
#
# ![slide30-image1](data:image/png;base64,...)
# ![slide30-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 31: (Untitled)
#
# - Support Vector Machine
# - 5
# - 최대 마진 분류 + 커널(Kernel)
# - 선형 커널일 경우,
#
# **Equation 31.1**
# $$
# 𝐰∗=𝑿𝐓(𝛂∘𝐲)
# $$
#
# **Equation 31.2**
# $$
# 𝑏∗=1𝑁𝑖∈𝑆𝑉𝑀𝑃𝑦𝑖−𝛂∘𝐲𝐓𝑲(𝑋,𝐱𝐢)
# $$
#
# **Equation 31.3**
# $$
# 𝑆𝑉𝑀𝑃(𝑆𝑢𝑝𝑝𝑜𝑟𝑡 𝑉𝑒𝑐𝑡𝑜𝑟𝑠 𝑜𝑛 𝑀𝑎𝑔𝑖𝑛 𝑃𝑙𝑎𝑛𝑒)={𝐱𝑖|0<𝛼𝑖<𝐶}
# $$
#
# **Equation 31.4**
# $$
# 𝑓(𝐱)=𝛂∘𝐲𝐓𝑲(𝑋,𝐱)+𝒃∗
# $$
#
# **Equation 31.5**
# $$
# maximize𝛂𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝐊(𝑋,𝑋)𝛂∘𝐲
# $$
#
# **Equation 31.6**
# $$
# maximize𝛼𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲
# $$
#
# **Equation 31.7**
# $$
# 𝑓(𝐱)=𝐰∗𝑻𝐱+𝒃∗
# $$
#
# **Equation 31.8**
# $$
# 𝐰∗=𝑿𝐓(𝛂∘𝐲)
# $$
#
# **Equation 31.9**
# $$
# 𝑏∗=1𝑁𝑖∈𝑆𝑉𝑀𝑃𝑦𝑖−𝛂∘𝐲𝐓𝑲(𝑋,𝐱𝐢)
# $$
#
# **Equation 31.10**
# $$
# 𝑆𝑉𝑀𝑃(𝑆𝑢𝑝𝑝𝑜𝑟𝑡 𝑉𝑒𝑐𝑡𝑜𝑟𝑠 𝑜𝑛 𝑀𝑎𝑔𝑖𝑛 𝑃𝑙𝑎𝑛𝑒)={𝐱𝑖|0<𝛼𝑖<𝐶}
# $$
#
# **Equation 31.11**
# $$
# maximize𝛂𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝐊(𝑋,𝑋)𝛂∘𝐲
# $$
#
# **Equation 31.12**
# $$
# maximize𝛼𝒊=𝟏𝒎𝜶𝒊−12𝛂∘𝐲𝐓𝑋𝑋𝑇𝛂∘𝐲
# $$
#
# ![slide31-image1](data:image/png;base64,...)
# ![slide31-image2](data:image/png;base64,...)
# ![slide31-image3](data:image/png;base64,...)
# ![slide31-image4](data:image/png;base64,...)
# ![slide31-image5](data:image/png;base64,...)
# ![slide31-image6](data:image/png;base64,...)
# ![slide31-image7](data:image/png;base64,...)
# ![slide31-image8](data:image/png;base64,...)

# %% [markdown]
# ### Slide 32: (Untitled)
#
# - Support Vector Machine
# - 여러 SVM 을 통해 다중 클래스 문제에 대응
# - 단일 SVM 은 이진 분류만 가능
# - 5
# - 다중 클래스 분류
# - One-Vs-Rest(OVR)
# - One-Vs- One(OVO)
#
# ![slide32-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 33: (Untitled)
#
# - Support Vector Machine
# - 5
# - 장단점
# - 장점
# - 단점
# - 차원이 높은 데이터에서 효과적인 과적합 대응
# - 이론적 기반 견고
# - 대용량 데이터에 부적합
# - 하이퍼 파라미터 튜닝 필요
# - 설명력이 떨어짐
# - 다중 클래스 문제에서 효율성이 떨어지는 OVR, OVO 방식 필수
#
# **Table 33.1**
# | 장점 | 단점 |
# | --- | --- |
# | 차원이 높은 데이터에서 효과적인 과적합 대응
# 이론적 기반 견고 | 대용량 데이터에 부적합
# 하이퍼 파라미터 튜닝 필요
# 설명력이 떨어짐
# 다중 클래스 문제에서 효율성이 떨어지는 OVR, OVO 방식 필수 |
#
# ![slide33-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 34: (Untitled)
#
# - 6
# - 문제 풀이
# - Support Vector 는 총 2 개이다.
# - 1
# - 인 데이터 포인트의 수는 총 4 개이다.
# - 2
# - C 를 낮출수록 기하학적 마진의 폭은 좁아진다.
# - 4
# - Q1. 다음은 SVM 의 학습 결과를 시각화한 것이다. 올바르게 설명한 것은?
# - (C: SVM 의 규제 파라미터,: 라그랑지안 승수, 커널: 선형)
# - Support Vector 와 해당 벡터의 라그랑지안 승수로
# - 결정 경계 직선을 유도할 수 있다.
# - 3
#
# **Equation 34.1**
# $$
# 0<𝛼𝑖<𝐶
# $$
#
# **Equation 34.2**
# $$
# 𝛼𝑖
# $$
#
# ![slide34-image1](data:image/png;base64,...)
# ![slide34-image2](data:image/png;base64,...)
# ![slide34-image3](data:image/png;base64,...)

# %% [markdown]
# ### Slide 35: (Untitled)
#
# - 6
# - 문제 풀이
# - Q1. 다음은 SVM 의 학습 결과를 시각화한 것이다. 올바르게 설명한 것은?
# - (C: SVM 의 규제 파라미터,: 라그랑지안 승수, 커널: 선형)
# - 1) Support Vector 의 수는 총 4 개입니다.
# - 2) (마진 경계 위의 데이터 포인트) 2 개이며 =𝐶(마진 경 계 안쪽) 2 개입니다.
# - 4) C 를 낮출수록 기하학적 마진의 폭은 넓어집니다.
# - Support Vector 는 총 2 개이다.
# - 1
# - 인 데이터 포인트의 수는 총 4 개이다.
# - 2
# - C 를 낮출수록 기하학적 마진의 폭은 좁아진다.
# - 4
# - 3
# - Support Vector 와 해당 벡터의 라그랑지안 승수로
# - 결정 경계 직선을 유도할 수 있다.
#
# **Equation 35.1**
# $$
# 𝛼𝑖
# $$
#
# **Equation 35.2**
# $$
# 0<𝛼𝑖<𝐶
# $$
#
# **Equation 35.3**
# $$
# 𝛼𝑖
# $$
#
# **Equation 35.4**
# $$
# 0<𝛼𝑖<𝐶
# $$
#
# ![slide35-image1](data:image/png;base64,...)
# ![slide35-image2](data:image/png;base64,...)
# ![slide35-image3](data:image/png;base64,...)
# ![slide35-image4](data:image/png;base64,...)
# ![slide35-image5](data:image/png;base64,...)

# %% [markdown]
# ### Slide 36: (Untitled)
#
# - 6
# - 문제 풀이
# - 고차원 특징을 사용하기 위해 다항식 특성 변환을 직접 수행하면 메모리 문제가 발생할 수 있다.
# - 1
# - SVM 은 라그랑지안 승수를 도입하여 쌍대 문제(Dual Problem)로 변환한 후 학습을 수행한다.
# - 2
# - SVM 은 기하학적 마진을 최대화함으로써 모델의 일반화 성능을 높이는 것을 목표로 한다.
# - 3
# - 슬랙 변수(ξ)를 도입하여 완전한 선형 분리가 불가능한 경우에도 유연하게 학습할 수 있도록 한다.
# - 4
# - Q2. 다음 중 Support Vector Machine 에 대한 설명으로 틀린 것은?

# %% [markdown]
# ### Slide 37: (Untitled)
#
# - 6
# - 문제 풀이
# - 1
# - Q2. 다음 중 Support Vector Machine 에 대한 설명으로 틀린 것은?
# - 1) Kernel Trick 을 통해 다항 특성을 직접 만들지 않고 사용할 수 있습니다.
# - 고차원 특징을 사용하기 위해 다항식 특성 변환을 직접 수행하면 메모리 문제가 발생할 수 있다.
# - SVM 은 라그랑지안 승수를 도입하여 쌍대 문제(Dual Problem)로 변환한 후 학습을 수행한다.
# - 2
# - SVM 은 기하학적 마진을 최대화함으로써 모델의 일반화 성능을 높이는 것을 목표로 한다.
# - 3
# - 슬랙 변수(ξ)를 도입하여 완전한 선형 분리가 불가능한 경우에도 유연하게 학습할 수 있도록 한다.
# - 4
#
# ![slide37-image1](data:image/png;base64,...)

# %% [markdown]
# ### Slide 38: (Untitled)
#
# - 6
# - 문제 풀이
# - 𝛾 를 높이면 편향(Bias)이 높아진다.
# - 1
# - 𝛾 를 높이면 복잡한 결정면이 만들어진다.
# - 2
# - 𝛾 를 높이면 기하학적 마진이 넓어진다.
# - 3
# - 𝛾가 음수여도 양의 준정성을 만족하므로,
# - 커널 함수로는 문제 없다.
# - 4
# - Q3. 다음은 오른쪽 커널 함수로 SVM 의 학습 결과를
# - 시각화한 것이다. 올바르게 설명한 것은?
#
# **Equation 38.1**
# $$
# exp−𝛾𝐱−𝐲2
# $$
#
# **Equation 38.2**
# $$
# exp−𝛾𝐱−𝐲2
# $$
#
# ![slide38-image1](data:image/png;base64,...)
# ![slide38-image2](data:image/png;base64,...)

# %% [markdown]
# ### Slide 39: (Untitled)
#
# - 6
# - 문제 풀이
# - 2
# - Q3. 다음은 오른쪽 커널 함수로 SVM 의 학습 결과를
# - 시각화한 것이다. 올바르게 설명한 것은?
# - 2) 학습 데이터의 영향도가 커지므로 복잡한 결정면이 만들어집니다.
# - 𝛾 를 높이면 편향(Bias)이 높아진다.
# - 1
# - 𝛾 를 높이면 복잡한 결정면이 만들어진다.
# - 𝛾 를 높이면 기하학적 마진이 넓어진다.
# - 3
# - 𝛾가 음수여도 양의 준정성을 만족하므로,
# - 커널 함수로는 문제 없다.
# - 4
#
# **Equation 39.1**
# $$
# exp−𝛾𝐱−𝐲2
# $$
#
# **Equation 39.2**
# $$
# exp−𝛾𝐱−𝐲2
# $$
#
# ![slide39-image1](data:image/png;base64,...)
# ![slide39-image2](data:image/png;base64,...)
# ![slide39-image3](data:image/png;base64,...)

# %% [markdown]
# ### Slide 40: (Untitled)
#
# - # 최대 마진 분류
# - # 소프트 마진 분류
# - # 커널 트릭
# - 추후 디자인하여 PSD 로 편집될 영역입니다.
